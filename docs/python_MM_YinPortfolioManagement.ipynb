# %% [markdown]
# # Yin's Capital Product
#
# This notebook walks readers through the procedure of installing *YinPortfolioManagement*. Here we introduce the following usages.
#
# - Installation
# - Use RNN3 Regressor
#
# All rights reserved to Yiqiao Yin.

# %% [markdown]
# ## Installation

# %%
# !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git

# %% [markdown]
# ## Usage of RNN3 Regressor
#
# What is LSTM or RNN?
#
# ## Recurrent Neural Network (a sequential model)
#
# Given data $X$ and $Y$, we want to feed information forward into a time stamp. Then we form some belief and we make some initial predictions. We investigate our beliefs by looking at the loss function of the initial guesses and the real value. We update our model according to error we observed.
#
# ## Architecture: Feed-forward
#
# Consider data with time stamp
# $$X_{\langle 1 \rangle} \rightarrow X_{\langle 2 \rangle} \rightarrow \dots \rightarrow X_{\langle T \rangle}$$
# and feed-forward architecture pass information through exactly as the following:
# $$
# \text{Information in:} \rightarrow
# \begin{matrix}
# Y_{\langle 1 \rangle}, \hat{Y}_{\langle 1 \rangle} & Y_{\langle 2 \rangle}, \hat{Y}_{\langle 2 \rangle} &       & Y_{\langle T \rangle}, \hat{Y}_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# X_{\langle 1 \rangle} \rightarrow    & X_{\langle 2 \rangle} \rightarrow    & \dots \rightarrow & X_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# w_{\langle 1 \rangle}, b_{0, \langle 1 \rangle}    & w_{\langle 2 \rangle}, b_{0, \langle 2 \rangle}    &       & w_{\langle T \rangle}, b_{0, \langle T \rangle} \\
# \end{matrix}
# \rightarrow
# \text{Form beliefs about } Y_{\angle T \rangle}
# $$
# while the educated guesses $\hat{Y}_{\langle T \rangle}$ are our beliefs about real $Y$ at time stamp $T$.
#
# ## Architecture: Feed-backward
#
# Let us clearly define our loss function to make sure we have a proper grip of our mistakes.
# $$\mathcal{L} = \sum_t L(\hat{y}_{\langle t \rangle} - y_t)^2$$
# and we can compute the gradient
# $$\triangledown = \frac{\partial \mathcal{L}}{\partial a}$$
# and then with respect with parameters $w$ and $b$
# $$\frac{\partial \triangledown}{\partial w}, \frac{\partial \triangledown}{\partial a}$$
# and now with perspective of where we make our mistakes according to our parameters we can go backward
# $$
# \text{Information in:} \leftarrow
# \underbrace{
# \begin{matrix}
# Y_{\langle 1 \rangle}, \hat{Y}_{\langle 1 \rangle} & Y_{\langle 2 \rangle}, \hat{Y}_{\langle 2 \rangle} &       & Y_{\langle T \rangle}, \hat{Y}_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# X_{\langle 1 \rangle} \leftarrow    & X_{\langle 2 \rangle} \leftarrow    & \dots \leftarrow & X_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# w'_{\langle 1 \rangle}, b'_{0, \langle 1 \rangle}    & w'_{\langle 2 \rangle}, b'_{0, \langle 2 \rangle}    &       & w'_{\langle T \rangle}, b'_{0, \langle T \rangle} \\
# \end{matrix}}_{\text{Update: } w, b \text{ with } w', b'}
# \leftarrow
# \text{Total Loss: } \mathcal{L} (\hat{y}, y)
# $$
# and the *update* action in the above architecture is dependent on your optimizer specified in the algorithm.

# %%
from YinCapital_forecast.RNN_Regressor import RNN_Regressor

# %%
tmp = RNN_Regressor(
    start_date =   '2013-01-01',
    end_date   =   '2021-07-14',
    tickers    =   'AAPL',
    cutoff     =   0.9,
    numOfHiddenLayer = 2,
    l1_units   =   50,
    l2_units   =   50,
    l3_units   =   50,
    dropOutRate = 0.3,
    optimizer  =   'adam',
    loss       =   'mean_squared_error',
    epochs     =   15,
    batch_size =   64,
    plotGraph  =   True,
    verbose    =   True )
# Out:
# ------------------------------------------------------------------------------
#
#             MANUAL: To install this python package, please use the following code.
#
#             # In a python notebook:
#             # !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#             # In a command line:
#             # pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#
#             # Run
#             tmp = RNN_Regressor(
#                     start_date =   '2013-01-01',
#                     end_date   =   '2019-12-6',
#                     tickers    =   'AAPL',
#                     cutoff     =   0.8,
#                     numOfHiddenLayer = 3,
#                     l1_units   =   50,
#                     l2_units   =   50,
#                     l3_units   =   50,
#                     l4_units   =   30,
#                     l5_units   =   10,
#                     dropOutRate =  0.2,
#                     optimizer  =   'adam',
#                     loss       =   'mean_squared_error',
#                     epochs     =   50,
#                     batch_size =   64,
#                     plotGraph  =   True,
#                     verbose    =   True )
#
#             # Cite
#             # All Rights Reserved. © Yiqiao Yin
#
# ------------------------------------------------------------------------------
# [*********************100%***********************]  1 of 1 completed
# --------------------------------------------------------------------
# Shape for data frame in training set:
# Shape of X: (1832, 100, 1) ; Shape of Y: 1832
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Shape for data frame in testing set:
# Shape of X: (114, 100, 1) : Shape of Y: 114
# --------------------------------------------------------------------
# --------------------------------------------
# Let us investigate the sequential models.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 50)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------
# Time Consumption (in sec): 0.5260441303253174
# Time Consumption (in min): 0.01
# Time Consumption (in hr): 0.0 2
# --------------------------------------------
# Epoch 1/15
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0099
# Epoch 2/15
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0014
# Epoch 3/15
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0011
# Epoch 4/15
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 5/15
# 29/29 [==============================] - 1s 35ms/step - loss: 9.6600e-04
# Epoch 6/15
# 29/29 [==============================] - 1s 35ms/step - loss: 9.7743e-04
# Epoch 7/15
# 29/29 [==============================] - 1s 35ms/step - loss: 9.1127e-04
# Epoch 8/15
# 29/29 [==============================] - 1s 34ms/step - loss: 8.8864e-04
# Epoch 9/15
# 29/29 [==============================] - 1s 34ms/step - loss: 8.8393e-04
# Epoch 10/15
# 29/29 [==============================] - 1s 34ms/step - loss: 9.2707e-04
# Epoch 11/15
# 29/29 [==============================] - 1s 34ms/step - loss: 7.9953e-04
# Epoch 12/15
# 29/29 [==============================] - 1s 34ms/step - loss: 8.2596e-04
# Epoch 13/15
# 29/29 [==============================] - 1s 34ms/step - loss: 8.2915e-04
# Epoch 14/15
# 29/29 [==============================] - 1s 34ms/step - loss: 7.2171e-04
# Epoch 15/15
# 29/29 [==============================] - 1s 34ms/step - loss: 6.9666e-04: 0s - lo
# Time Consumption: 17.941377639770508
# ---------------------------------------------------------------------------------
# Root Mean Square Error is 8.68 for test set.
# ------------------
# Interpretation:
# ------------------
# On the test set, the performance of this LSTM architecture guesses
# AAPL stock price on average within the error of $8.68 dollars.
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## A Deeper RNN: RNN5
#
# A curious question is the the following: does test set performance get better when we increase the number of hidden layers in a RNN architecture?

# %%
tmp2 = RNN_Regressor(
    start_date =   '2013-01-01',
    end_date   =   '2021-07-14',
    tickers    =   'AAPL',
    cutoff     =   0.9,
    numOfHiddenLayer = 5,
    l1_units   =   50,
    l2_units   =   50,
    l3_units   =   50,
    dropOutRate = 0.3,
    optimizer  =   'adam',
    loss       =   'mean_squared_error',
    epochs     =   20,
    batch_size =   64,
    plotGraph  =   True,
    verbose    =   True )
# Out:
# ------------------------------------------------------------------------------
#
#             MANUAL: To install this python package, please use the following code.
#
#             # In a python notebook:
#             # !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#             # In a command line:
#             # pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#
#             # Run
#             tmp = RNN_Regressor(
#                     start_date =   '2013-01-01',
#                     end_date   =   '2019-12-6',
#                     tickers    =   'AAPL',
#                     cutoff     =   0.8,
#                     numOfHiddenLayer = 3,
#                     l1_units   =   50,
#                     l2_units   =   50,
#                     l3_units   =   50,
#                     l4_units   =   30,
#                     l5_units   =   10,
#                     dropOutRate =  0.2,
#                     optimizer  =   'adam',
#                     loss       =   'mean_squared_error',
#                     epochs     =   50,
#                     batch_size =   64,
#                     plotGraph  =   True,
#                     verbose    =   True )
#
#             # Cite
#             # All Rights Reserved. © Yiqiao Yin
#
# ------------------------------------------------------------------------------
# [*********************100%***********************]  1 of 1 completed
# --------------------------------------------------------------------
# Shape for data frame in training set:
# Shape of X: (1832, 100, 1) ; Shape of Y: 1832
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Shape for data frame in testing set:
# Shape of X: (114, 100, 1) : Shape of Y: 114
# --------------------------------------------------------------------
# --------------------------------------------
# Let us investigate the sequential models.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100, 50)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100, 50)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100, 50)           0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 100, 30)           9720
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100, 30)           0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 10)                1640
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 62,171
# Trainable params: 62,171
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------
# Time Consumption (in sec): 0.9644241333007812
# Time Consumption (in min): 0.02
# Time Consumption (in hr): 0.0 2
# --------------------------------------------
# Epoch 1/20
# 29/29 [==============================] - 2s 81ms/step - loss: 0.0130
# Epoch 2/20
# 29/29 [==============================] - 2s 80ms/step - loss: 0.0046
# Epoch 3/20
# 29/29 [==============================] - 2s 79ms/step - loss: 0.0036
# Epoch 4/20
# 29/29 [==============================] - 2s 79ms/step - loss: 0.0030
# Epoch 5/20
# 29/29 [==============================] - 2s 78ms/step - loss: 0.0034
# Epoch 6/20
# 29/29 [==============================] - 2s 78ms/step - loss: 0.0028
# Epoch 7/20
# 29/29 [==============================] - 2s 78ms/step - loss: 0.0027
# Epoch 8/20
# 29/29 [==============================] - 2s 79ms/step - loss: 0.0028
# Epoch 9/20
# 29/29 [==============================] - 2s 79ms/step - loss: 0.0024
# Epoch 10/20
# 29/29 [==============================] - 2s 79ms/step - loss: 0.0024
# Epoch 11/20
# 29/29 [==============================] - 2s 77ms/step - loss: 0.0025
# Epoch 12/20
# 29/29 [==============================] - 2s 76ms/step - loss: 0.0024
# Epoch 13/20
# 29/29 [==============================] - 2s 76ms/step - loss: 0.0022
# Epoch 14/20
# 29/29 [==============================] - 2s 76ms/step - loss: 0.0023
# Epoch 15/20
# 29/29 [==============================] - 2s 77ms/step - loss: 0.0023
# Epoch 16/20
# 29/29 [==============================] - 2s 76ms/step - loss: 0.0017
# Epoch 17/20
# 29/29 [==============================] - 2s 76ms/step - loss: 0.0017
# Epoch 18/20
# 29/29 [==============================] - 2s 77ms/step - loss: 0.0016
# Epoch 19/20
# 29/29 [==============================] - 2s 78ms/step - loss: 0.0016
# Epoch 20/20
# 29/29 [==============================] - 2s 76ms/step - loss: 0.0017
# Time Consumption: 52.60264706611633
# ---------------------------------------------------------------------------------
# Root Mean Square Error is 7.93 for test set.
# ------------------
# Interpretation:
# ------------------
# On the test set, the performance of this LSTM architecture guesses
# AAPL stock price on average within the error of $7.93 dollars.
# ---------------------------------------------------------------------------------

# %% [markdown]
# Ends here.
