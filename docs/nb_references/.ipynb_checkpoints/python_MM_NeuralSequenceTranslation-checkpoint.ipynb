# %% [markdown]
# # Money Management: Stock Price Forecasting Using Neural Sequence Translation
#
# Neural Sequence Translation (NST) is an tweak version of Recurrent Neural Network which not just forecasts a point in the future but an entire vector in the future. Just like [Neural Machine Translation](https://arxiv.org/abs/1409.0473), this notebook explores this upgrade philosophy and apply this idea in a singular stock data.
#
# Stock price today is probably dependent on:
# - The trend it has been folloing from the previous day.
# - The price it was traded at from previous day.
# - Some other factors that may affect stock price today.
#
# Generalize intuition from above to the following:
# - The previous cell state (i.e. the information that was present in the memory after the previous time step).
# - The previous hidden state (i.e. this is the same as the output of the previous cell).
# - The input at the current time step (i.e. the new information that is being fed in at that moment).
#
# In this notebook, we cover
# - Part 1 - Data Preprocessing
# - Part 2 - Construct NST Architecture
# - Part 3 - Predictions and Performance Visualization
#
# A Production of [Yin's Capital](www.YinsCapital.com)

# %% [markdown]
# ## Recurrent Neural Network (a sequential model)
#
# Given data $X$ and $Y$, we want to feed information forward into a time stamp. Then we form some belief and we make some initial predictions. We investigate our beliefs by looking at the loss function of the initial guesses and the real value. We update our model according to error we observed.
#
# ## Architecture: Feed-forward
#
# Consider data with time stamp
# $$X_{\langle 1 \rangle} \rightarrow X_{\langle 2 \rangle} \rightarrow \dots \rightarrow X_{\langle T \rangle}$$
# and feed-forward architecture pass information through exactly as the following:
# $$
# \text{Information in:} \rightarrow
# \begin{matrix}
# \{Y_{\langle 1 \rangle}, ..., Y_{\langle k \rangle}\} & \{Y_{\langle 1 \rangle}, ..., Y_{\langle k \rangle}\} &       & \{Y_{\langle 1 \rangle}, ..., Y_{\langle k \rangle}\} \\
# \updownarrow               & \updownarrow               &       & \updownarrow \\
# \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} & \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} &       & \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# X_{\langle 1 \rangle} \rightarrow    & X_{\langle 2 \rangle} \rightarrow    & \dots \rightarrow & X_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# w_{\langle 1 \rangle}, b_{0, \langle 1 \rangle}    & w_{\langle 2 \rangle}, b_{0, \langle 2 \rangle}    &       & w_{\langle T \rangle}, b_{0, \langle T \rangle} \\
# \end{matrix}
# \rightarrow
# \text{Form beliefs about } Y_{\langle T \rangle}
# $$
# while the educated guesses $\hat{Y}_{\langle T \rangle}$ are our beliefs about real $Y$ at time stamp $T$.
#
# ## Architecture: Feed-backward
#
# Let us clearly define our loss function to make sure we have a proper grip of our mistakes.
# $$\mathcal{L} = \sum_t \sum_k L(\hat{y}_{\langle t,k \rangle} - y_{\langle t,k \rangle})^2$$
# and we can compute the gradient
# $$\triangledown = \frac{\partial \mathcal{L}}{\partial a}$$
# and then with respect with parameters $w$ and $b$
# $$\frac{\partial \triangledown}{\partial w}, \frac{\partial \triangledown}{\partial a}$$
# and now with perspective of where we make our mistakes according to our parameters we can go backward
# $$
# \text{Information in:} \leftarrow
# \underbrace{
# \begin{matrix}
# \{Y_{\langle 1 \rangle}, ..., Y_{\langle k \rangle}\} & \{Y_{\langle 1 \rangle}, ..., Y_{\langle k \rangle}\} &       & \{Y_{\langle 1 \rangle}, ..., Y_{\langle k \rangle}\} \\
# \updownarrow               & \updownarrow               &       & \updownarrow \\
# \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} & \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} &       & \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# X_{\langle 1 \rangle} \leftarrow    & X_{\langle 2 \rangle} \leftarrow    & \dots \leftarrow & X_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# w'_{\langle 1 \rangle}, b'_{0, \langle 1 \rangle}    & w'_{\langle 2 \rangle}, b'_{0, \langle 2 \rangle}    &       & w'_{\langle T \rangle}, b'_{0, \langle T \rangle} \\
# \end{matrix}}_{\text{Update: } w, b \text{ with } w', b'}
# \leftarrow
# \text{Total Loss: } \mathcal{L} (\hat{y}, y)
# $$
# and the *update* action in the above architecture is dependent on your optimizer specified in the algorithm.

# %% [markdown]
# ## Part 1: Data Processing

# %%
# libraries
import pandas as pd
import numpy as np
import yfinance as yf

# %%
# set parameters
start_date       =   '2013-01-01'
end_date         =   '2021-09-04'
ticker           =   'AAPL'
w                =   3
h                =   5
max_len          =   1000 # use this if Embedding is used
output_dim       =   5 # use this if Embedding is used
cutoff           =   0.9
numOfHiddenLayer =   4
numOfDense       =   3
l1_units         =   128*4
l2_units         =   128*3
l2_units         =   128*2
l3_units         =   128
l4_units         =   30
l5_units         =   10
dropOutRate       =  0.3
optimizer        =   'adam'
loss             =   'mean_squared_error'
useDice          =   True
epochs           =   100
batch_size       =   64
plotGraph        =   True
verbose          =   True

# %%
# get data
stockData = yf.download(ticker, start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# We make the following simple assumptions:
# - the explanatory data matrix $X$ is the downloaded stock data except the first row
# - the response data matrix $Y$ is the downloaded stock data except the last row
# - this way we are using stock data at $t$ to predict stock data at $t+1$
# - the information in the response data matrix $Y$: open, high, low, close, adjusted close

# %%
stockData = stockData.iloc[:,:5]

# %%
stockData.head(2)
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2013-01-02  19.779285  19.821428  19.343929  19.608213  16.985447
# 2013-01-03  19.567142  19.631071  19.321428  19.360714  16.771053

# %%
stockData.iloc[w::,].head(2)
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2013-01-07  18.642857  18.903570  18.400000  18.710714  16.207998
# 2013-01-08  18.900356  18.996071  18.616072  18.761070  16.251616

# %%
stockData.iloc[w::,].shape
# Out:
# (2182, 5)

# %%
stockData.iloc[0:int(stockData.shape[0]-w),].head(2)
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2013-01-02  19.779285  19.821428  19.343929  19.608213  16.985447
# 2013-01-03  19.567142  19.631071  19.321428  19.360714  16.771053

# %%
stockData.iloc[0:int(stockData.shape[0]-w),].shape
# Out:
# (2182, 5)

# %%
Y = stockData.iloc[w::, ]
# X = stockData.iloc[0:int(stockData.shape[0]-w),]

X = np.arange(0, Y.shape[0]*w*h, 1).reshape(Y.shape[0], w*h)
for i in range(0,int(stockData.shape[0]-w)):
    X[i,] = np.array(stockData.iloc[i:(i+w),]).reshape(1, w*h)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (2182, 15)
# (2182, 5)

# %%
X_train = X[0:round(X.shape[0]*cutoff), ]
X_test = X[round(X.shape[0]*cutoff):X.shape[0], ]

# %%
y_train = Y.iloc[0:round(Y.shape[0]*cutoff), ]
y_test = Y.iloc[round(Y.shape[0]*cutoff):Y.shape[0], ]

# %%
X_train = np.array(X_train).reshape(X_train.shape[0], w*h) # dim would be 1, w*h if Embedding is used
X_test = np.array(X_test).reshape(X_test.shape[0], w*h)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1964, 15)
# (218, 15)
# (1964, 5)
# (218, 5)

# %% [markdown]
# ## Part 2: Design a Neural Sequence Translation Architecture

# %%
### Build RNN
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers import LayerNormalization
import time

# %%
# Initialize RNN
begintime = time.time()
regressor = Sequential()

# %%
# Embedding
regressor.add(Embedding(input_dim=max_len, output_dim=output_dim, input_length=w*h))

# %%
# Comment
# regressor.add(LSTM(units = l1_units, return_sequences = True, input_shape = (w*h, output_dim))) # this is if Embedding is used
# regressor.add(LSTM(units = l1_units, return_sequences = True, input_shape = (w, h))) # this is if no Embedding is used

# Design hidden layers
if numOfHiddenLayer == 2:
    # Adding the first LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l1_units, return_sequences = True, input_shape = (w*h, output_dim)))
    regressor.add(Dropout(dropOutRate))

    # Adding a second LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l2_units))
    regressor.add(Dropout(dropOutRate))

elif numOfHiddenLayer == 3:
    # Adding the first LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l1_units, return_sequences = True, input_shape = (w*h, output_dim)))
    regressor.add(LayerNormalization(axis=1))
    regressor.add(Dropout(dropOutRate))

    # Adding a second LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l2_units, return_sequences = True))
    regressor.add(LayerNormalization(axis=1))
    regressor.add(Dropout(dropOutRate))

    # Adding a third LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l3_units))
    regressor.add(Dropout(dropOutRate))

elif numOfHiddenLayer == 4:
    # Adding the first LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l1_units, return_sequences = True, input_shape = (w*h, output_dim)))
    regressor.add(LayerNormalization(axis=1))
    regressor.add(Dropout(dropOutRate))

    # Adding a second LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l2_units, return_sequences = True))
    regressor.add(LayerNormalization(axis=1))
    regressor.add(Dropout(dropOutRate))

    # Adding a third LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l3_units, return_sequences = True))
    regressor.add(LayerNormalization(axis=1))
    regressor.add(Dropout(dropOutRate))

    # Adding a fourth LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l4_units))
    regressor.add(LayerNormalization(axis=1))
    regressor.add(Dropout(dropOutRate))

elif numOfHiddenLayer == 5:
    # Adding the first LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l1_units, return_sequences = True, input_shape = (w*h, output_dim)))
    regressor.add(Dropout(dropOutRate))

    # Adding a second LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l2_units, return_sequences = True))
    regressor.add(Dropout(dropOutRate))

    # Adding a third LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l3_units, return_sequences = True))
    regressor.add(Dropout(dropOutRate))

    # Adding a fourth LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l4_units, return_sequences = True))
    regressor.add(Dropout(dropOutRate))

    # Adding a fifth LSTM layer and some Dropout regularisation
    regressor.add(LSTM(units = l5_units))
    regressor.add(Dropout(dropOutRate))

# %%
if numOfDense == 1:
    regressor.add(Dense(units = l1_units))
elif numOfDense == 2:
    regressor.add(Dense(units = l1_units))
    regressor.add(Dense(units = l2_units))
elif numOfDense == 3:
    regressor.add(Dense(units = l1_units))
    regressor.add(Dense(units = l2_units))
    regressor.add(Dense(units = l3_units))
else:
    if verbose:
        print("Options are 1, 2, or 3. Reset to one dense layer.")
    regressor.add(Dense(units = l1_units))

# %%
# Adding the output layer
regressor.add(Dense(units = y_train.shape[1]))
endtime = time.time()

# %%
# Summary
if verbose:
    print("--------------------------------------------")
    print('Let us investigate the sequential models.')
    regressor.summary()
    print("--------------------------------------------")
    print("Time Consumption (in sec):", endtime - begintime)
    print("Time Consumption (in min):", round((endtime - begintime)/60, 2))
    print("Time Consumption (in hr):", round((endtime - begintime)/60)/60, 2)
    print("--------------------------------------------")
# Out:
# --------------------------------------------
# Let us investigate the sequential models.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 15, 5)             5000
# _________________________________________________________________
# lstm (LSTM)                  (None, 15, 512)           1060864
# _________________________________________________________________
# layer_normalization (LayerNo (None, 15, 512)           30
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 512)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 15, 256)           787456
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 15, 256)           30
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 256)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 15, 128)           197120
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 15, 128)           30
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 128)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 30)                19080
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 30)                60
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense (Dense)                (None, 512)               15872
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 2,250,411
# Trainable params: 2,250,411
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------
# Time Consumption (in sec): 1.2157483100891113
# Time Consumption (in min): 0.02
# Time Consumption (in hr): 0.0 2
# --------------------------------------------

# %%
### Train RNN
# Compiling the RNN
start = time.time()
regressor.compile(optimizer = optimizer, loss = loss)

# %%
# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = epochs, batch_size = batch_size)
end = time.time()
# Out:
# Epoch 1/100
# 31/31 [==============================] - 9s
# Epoch 41/100
# 31/31 [==============================] - 3s 110ms/step - loss: 20.4661
# Epoch 42/100
# 31/31 [==============================] - 4s 114ms/step - loss: 19.6782
# Epoch 43/100
# 31/31 [==============================] - 3s 109ms/step - loss: 20.9306
# Epoch 44/100
# 31/31 [==============================] - 3s 105ms/step - loss: 18.4986
# Epoch 45/100
# 31/31 [==============================] - 3s 107ms/step - loss: 20.0932
# Epoch 46/100
# 31/31 [==============================] - 3s 106ms/step - loss: 20.2556
# Epoch 47/100
# 31/31 [==============================] - 3s 105ms/step - loss: 17.8203
# Epoch 48/100
# 31/31 [==============================] - 3s 105ms/step - loss: 18.5452
# Epoch 49/100
# 31/31 [==============================] - 3s 105ms/step - loss: 18.6263
# Epoch 50/100
# 31/31 [==============================] - 3s 106ms/step - loss: 23.1173
# Epoch 51/100
# 31/31 [==============================] - 3s 105ms/step - loss: 19.8668
# Epoch 52/100
# 31/31 [==============================] - 3s 105ms/step - loss: 18.0264
# Epoch 53/100
# 31/31 [==============================] - 3s 112ms/step - loss: 16.4805
# Epoch 54/100
# 31/31 [==============================] - 3s 111ms/step - loss: 20.7623
# Epoch 55/100
# 31/31 [==============================] - 4s 121ms/step - loss: 20.0764
# Epoch 56/100
# 31/31 [==============================] - 4s 118ms/step - loss: 20.5502
# Epoch 57/100
# 31/31 [==============================] - 4s 117ms/step - loss: 16.1422
# Epoch 58/100
# 31/31 [==============================] - 4s 127ms/step - loss: 17.6414
# Epoch 59/100
# 31/31 [==============================] - 4s 118ms/step - loss: 16.5063
# Epoch 60/100
# 31/31 [==============================] - 4s 119ms/step - loss: 17.0422
# Epoch 61/100
# 31/31 [==============================] - 3s 112ms/step - loss: 17.9307
# Epoch 62/100
# 31/31 [==============================] - 3s 109ms/step - loss: 18.0134
# Epoch 63/100
# 31/31 [==============================] - 3s 108ms/step - loss: 18.1153
# Epoch 64/100
# 31/31 [==============================] - 3s 110ms/step - loss: 17.1874
# Epoch 65/100
# 31/31 [==============================] - 3s 109ms/step - loss: 16.9162
# Epoch 66/100
# 31/31 [==============================] - 3s 108ms/step - loss: 17.7691
# Epoch 67/100
# 31/31 [==============================] - 3s 111ms/step - loss: 18.3099
# Epoch 68/100
# 31/31 [==============================] - 4s 120ms/step - loss: 15.9868
# Epoch 69/100
# 31/31 [==============================] - 3s 108ms/step - loss: 20.5713
# Epoch 70/100
# 31/31 [==============================] - 3s 108ms/step - loss: 17.8542
# Epoch 71/100
# 31/31 [==============================] - 3s 110ms/step - loss: 16.4238
# Epoch 72/100
# 31/31 [==============================] - 3s 108ms/step - loss: 16.2760
# Epoch 73/100
# 31/31 [==============================] - 3s 110ms/step - loss: 15.5068
# Epoch 74/100
# 31/31 [==============================] - 3s 108ms/step - loss: 19.3952
# Epoch 75/100
# 31/31 [==============================] - 3s 111ms/step - loss: 15.4595
# Epoch 76/100
# 31/31 [==============================] - 4s 120ms/step - loss: 16.7996
# Epoch 77/100
# 31/31 [==============================] - 3s 112ms/step - loss: 15.1328
# Epoch 78/100
# 31/31 [==============================] - 3s 108ms/step - loss: 15.8914
# Epoch 79/100
# 31/31 [==============================] - 3s 110ms/step - loss: 17.0206
# Epoch 80/100
# 31/31 [==============================] - 4s 113ms/step - loss: 18.6747
# Epoch 81/100
# 31/31 [==============================] - 3s 110ms/step - loss: 16.5956
# Epoch 82/100
# 31/31 [==============================] - 3s 111ms/step - loss: 13.8495
# Epoch 83/100
# 31/31 [==============================] - 4s 117ms/step - loss: 15.4360
# Epoch 84/100
# 31/31 [==============================] - 3s 112ms/step - loss: 20.9291
# Epoch 85/100
# 31/31 [==============================] - 3s 109ms/step - loss: 15.4652
# Epoch 86/100
# 31/31 [==============================] - 3s 111ms/step - loss: 15.8580
# Epoch 87/100
# 31/31 [==============================] - 4s 114ms/step - loss: 15.8561
# Epoch 88/100
# 31/31 [==============================] - 3s 111ms/step - loss: 16.9929
# Epoch 89/100
# 31/31 [==============================] - 3s 108ms/step - loss: 17.7128
# Epoch 90/100
# 31/31 [==============================] - 3s 110ms/step - loss: 15.2683
# Epoch 91/100
# 31/31 [==============================] - 3s 109ms/step - loss: 14.2637
# Epoch 92/100
# 31/31 [==============================] - 4s 113ms/step - loss: 15.4204
# Epoch 93/100
# 31/31 [==============================] - 3s 109ms/step - loss: 17.6253
# Epoch 94/100
# 31/31 [==============================] - 3s 111ms/step - loss: 16.0861
# Epoch 95/100
# 31/31 [==============================] - 3s 112ms/step - loss: 18.0628
# Epoch 96/100
# 31/31 [==============================] - 4s 121ms/step - loss: 20.9661
# Epoch 97/100
# 31/31 [==============================] - 3s 110ms/step - loss: 16.2495
# Epoch 98/100
# 31/31 [==============================] - 3s 111ms/step - loss: 15.8704
# Epoch 99/100
# 31/31 [==============================] - 4s 121ms/step - loss: 20.0205
# Epoch 100/100
# 31/31 [==============================] - 3s 112ms/step - loss: 18.7312

# %%
# Time Check
if verbose == True: 
    print('Time Consumption:', end - start)
# Out:
# Time Consumption: 359.2434084415436

# %% [markdown]
# ## Part 3: Predictions and Performance Visualization

# %%
### Predictions
predicted_stock_price = regressor.predict(X_test)

# %%
real_stock_price = y_test

# %%
# Visualising the results
import matplotlib.pyplot as plt
if plotGraph:
    fig, axs = plt.subplots(2, figsize = (10,7))
    fig.suptitle(f'Real (Up) vs. Estimate (Down) {ticker} Stock Price')
    axs[0].plot(real_stock_price, color = 'red', label = f'Real {ticker} Stock Price')
    axs[1].plot(predicted_stock_price, color = 'blue', label = f'Predicted {ticker} Stock Price')

# %%
import pandas as pd
import mplfinance as mpf
mpf.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']

# %%
predicted_stock_price = pd.DataFrame(predicted_stock_price)
predicted_stock_price.columns = real_stock_price.columns
predicted_stock_price.index = real_stock_price.index

s = mpf.make_mpf_style(base_mpf_style='charles', rc={'font.size': 6})
fig = mpf.figure(figsize=(10, 7), style=s) # pass in the self defined style to the whole canvas
ax = fig.add_subplot(2,1,1) # main candle stick chart subplot, you can also pass in the self defined style here only for this subplot
av = fig.add_subplot(2,1,2, sharex=ax)  # volume chart subplot

df1 = real_stock_price
mpf.plot(df1, type='candle', style='yahoo', ax=ax, volume=False)

df2 = predicted_stock_price
mpf.plot(df2, type='candle', style='yahoo', ax=av)
# Out:
# <Mpf_Figure size 1000x700 with 2 Axes>

# %% [markdown]
# ## Part 4: Software Development

# %%
from YinCapital_forecast.modules import Neural_Sequence_Translation

# %%
tmp = Neural_Sequence_Translation(
        start_date       =   '2014-01-01',
        end_date         =   '2021-08-20',
        ticker           =   'AAPL',
        w                =   10 ,
        h                =   5,
        cutoff           =   0.95,
        numOfHiddenLayer =   3,
        numOfDense       =   3,
        l1_units         =   128*4,
        l2_units         =   128*3,
        l3_units         =   128,
        l4_units         =   30,
        l5_units         =   10,
        dropOutRate       =  0.3,
        optimizer        =   'adam',
        loss             =   'mean_squared_error',
        epochs           =   120,
        batch_size       =   64,
        plotGraph        =   False,
        verbose          =   True )
# Out:
# ------------------------------------------------------------------------------
#
#             MANUAL: To install this python package, please use the following code.
#
#             # In a python notebook:
#             # !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#             # In a command line:
#             # pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#
#             # Run
#             tmp = Neural_Sequence_Translation(
#                 start_date       =   '2013-01-01',
#                 end_date         =   '2021-01-01',
#                 ticker           =   'AAPL',
#                 w                =   1,
#                 h                =   5,
#                 cutoff           =   0.8,
#                 numOfHiddenLayer =   3,
#                 numOfDense       =   2,
#                 l1_units         =   50,
#                 l2_units         =   50,
#                 l2_units         =   50,
#                 l3_units         =   50,
#                 l4_units         =   30,
#                 l5_units         =   10,
#                 dropOutRate       =  0.2,
#                 optimizer        =   'adam',
#                 loss             =   'mean_squared_error',
#                 useDice          =   True,
#                 epochs           =   50,
#                 batch_size       =   64,
#                 plotGraph        =   True,
#                 useMPLFinancePlot=   True,
#                 verbose          =   True )
#
#             # Cite
#             # All Rights Reserved. © Yiqiao Yin
#
# ------------------------------------------------------------------------------
# [*********************100%***********************]  1 of 1 completed
# (1816, 10, 5)
# (96, 10, 5)
# (1816, 5)
# (96, 5)
# --------------------------------------------
# Let us investigate the sequential models.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 10, 512)           1060864
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 512)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 384)           1377792
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10, 384)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 128)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dense_4 (Dense)              (None, 384)               196992
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               49280
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 3,014,277
# Trainable params: 3,014,277
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------
# Time Consumption (in sec): 0.8337709903717041
# Time Consumption (in min): 0.01
# Time Consumption (in hr): 0.0 2
# --------------------------------------------
# Epoch 1/120
# 29/29 [==============================] - 6s 82ms/step - loss: 1192.6182
# Epoch 2/120
# 29/29 [==============================] - 2s 82ms/step - loss: 168.6923
# Epoch 3/120
# 29/29 [==============================] - 2s 82ms/step - loss: 40.1894
# Epoch 4/120
# 29/29 [==============================] - 2s 84ms/step - loss: 32.8939
# Epoch 5/120
# 29/29 [==============================] - 2s 85ms/step - loss: 36.4763
# Epoch 6/120
# 29/29 [==============================] - 2s 85ms/step - loss: 24.6474
# Epoch 7/120
# 29/29 [==============================] - 2s 84ms/step - loss: 23.7251
# Epoch 8/120
# 29/29 [==============================] - 3s 91ms/step - loss: 24.2951
# Epoch 9/120
# 29/29 [==============================] - 2s 86ms/step - loss: 21.2927 0s - loss: 21.10
# Epoch 10/120
# 29/29 [==============================] - 3s 87ms/step - loss: 29.1886
# Epoch 11/120
# 29/29 [==============================] - 3s 90ms/step - loss: 19.7819
# Epoch 12/120
# 29/29 [==============================] - 3s 91ms/step - loss: 21.1385
# Epoch 13/120
# 29/29 [==============================] - 3s 96ms/step - loss: 21.8946
# Epoch 14/120
# 29/29 [==============================] - 3s 99ms/step - loss: 30.7723
# Epoch 15/120
# 29/29 [==============================] - 3s 106ms/step - loss: 26.1383
# Epoch 16/120
# 29/29 [==============================] - 3s 103ms/step - loss: 25.7911
# Epoch 17/120
# 29/29 [==============================] - 3s 102ms/step - loss: 25.9190
# Epoch 18/120
# 29/29 [==============================] - 3s 104ms/step - loss: 22.6866
# Epoch 19/120
# 29/29 [==============================] - 3s 111ms/step - loss: 23.5032
# Epoch 20/120
# 29/29 [==============================] - 3s 104ms/step - loss: 23.4655
# 29/29 [==============================] - 3s 86ms/step - loss: 11.1606
# Epoch 102/120
# 29/29 [==============================] - 2s 86ms/step - loss: 11.9387
# Epoch 103/120
# 29/29 [==============================] - 2s 85ms/step - loss: 8.6228
# Epoch 104/120
# 29/29 [==============================] - 3s 87ms/step - loss: 8.5192
# Epoch 105/120
# 29/29 [==============================] - 2s 86ms/step - loss: 8.7032
# Epoch 106/120
# 29/29 [==============================] - 3s 88ms/step - loss: 8.4960
# Epoch 107/120
# 29/29 [==============================] - 3s 88ms/step - loss: 15.6404
# Epoch 108/120
# 29/29 [==============================] - 3s 88ms/step - loss: 10.9049
# Epoch 109/120
# 29/29 [==============================] - 3s 87ms/step - loss: 8.2348
# Epoch 110/120
# 29/29 [==============================] - 2s 86ms/step - loss: 8.7559
# Epoch 111/120
# 29/29 [==============================] - 3s 88ms/step - loss: 8.8928
# Epoch 112/120
# 29/29 [==============================] - 3s 88ms/step - loss: 9.5387
# Epoch 113/120
# 29/29 [==============================] - 3s 91ms/step - loss: 10.2576
# Epoch 114/120
# 29/29 [==============================] - 3s 89ms/step - loss: 17.1672
# Epoch 115/120
# 29/29 [==============================] - 3s 89ms/step - loss: 10.3624
# Epoch 116/120
# 29/29 [==============================] - 3s 88ms/step - loss: 10.0345
# Epoch 117/120
# 29/29 [==============================] - 3s 90ms/step - loss: 10.7649
# Epoch 118/120
# 29/29 [==============================] - 3s 91ms/step - loss: 10.6825
# Epoch 119/120
# 29/29 [==============================] - 3s 91ms/step - loss: 9.4910
# Epoch 120/120
# 29/29 [==============================] - 3s 89ms/step - loss: 8.7895: 0s - loss: 8.85
# Time Consumption: 325.51224875450134
# <Mpf_Figure size 1000x700 with 2 Axes>

# %%
# libraries
import pandas as pd
import numpy as np
import yfinance as yf

# get data
ticker = "FB"
stockData = yf.download(ticker, start_date, end_date)
stockData = stockData.iloc[:,:5]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Y = stockData.iloc[w::, ]
# X = stockData.iloc[0:int(stockData.shape[0]-w),]

X = np.arange(0, Y.shape[0]*w*h, 1).reshape(Y.shape[0], w*h)
for i in range(0,int(stockData.shape[0]-w)):
    X[i,] = np.array(stockData.iloc[i:(i+w),]).reshape(1, w*h)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (2182, 15)
# (2182, 5)

# %%
tmp = Embedding_Neural_Sequence_Translation(
        X                 =   X,   # explanatory data matrix
        Y                 =   Y,   # response data matrix
        w                 =   3,
        h                 =   5,
        cutoff            =   0.95, # take a fraction between 0 and 1
        max_len           =   2000,
        output_dim        =   20,
        numOfHiddenLayer  =   4,   # take an integer from 1, 2, 3, 4, or 5
        numOfDense        =   3,   # take an integer from 1, 2, or 3
        l1_units          =   128*4,
        l2_units          =   128*3,
        l3_units          =   128*2,
        l4_units          =   16,
        l5_units          =   10,
        dropOutRate       =   0.2,
        optimizer         =   'rmsprop',
        loss              =   'mean_squared_error',
        epochs            =   100,
        batch_size        =   32,
        plotGraph         =   False,
        useMPLFinancePlot =   True,
        verbose           =   True )
# Out:
# ------------------------------------------------------------------------------
#
#             MANUAL: To install this python package, please use the following code.
#
#             # In a python notebook:
#             # !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#             # In a command line:
#             # pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#
#             # Run
#             tmp = Embedding_Neural_Sequence_Translation(
#                 X                 =   X,   # explanatory data matrix
#                 Y                 =   Y,   # response data matrix
#                 w                 =   1,
#                 h                 =   5,
#                 cutoff            =   0.8, # take a fraction between 0 and 1
#                 max_len           =   1000,
#                 output_dim        =   5,
#                 numOfHiddenLayer  =   3,   # take an integer from 1, 2, 3, 4, or 5
#                 numOfDense        =   2,   # take an integer from 1, 2, or 3
#                 l1_units          =   128,
#                 l2_units          =   64,
#                 l3_units          =   32,
#                 l4_units          =   16,
#                 l5_units          =   10,
#                 dropOutRate       =   0.2,
#                 optimizer         =   'adam',
#                 loss              =   'mean_squared_error',
#                 epochs            =   50,
#                 batch_size        =   64,
#                 plotGraph         =   False,
#                 useMPLFinancePlot =   True,
#                 verbose           =   True )
#
#             # Cite
#             # All Rights Reserved. © Yiqiao Yin
#
# ------------------------------------------------------------------------------
# (2073, 15)
# (109, 15)
# (2073, 5)
# (109, 5)
# --------------------------------------------
# Let us investigate the sequential models.
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 15, 20)            40000
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 15, 512)           1091584
# _________________________________________________________________
# layer_normalization_18 (Laye (None, 15, 512)           30
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 15, 512)           0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 15, 384)           1377792
# _________________________________________________________________
# layer_normalization_19 (Laye (None, 15, 384)           30
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 15, 384)           0
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 15, 256)           656384
# _________________________________________________________________
# layer_normalization_20 (Laye (None, 15, 256)           30
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 15, 256)           0
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 16)                17472
# _________________________________________________________________
# layer_normalization_21 (Laye (None, 16)                32
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               8704
# _________________________________________________________________
# dense_19 (Dense)             (None, 384)               196992
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               98560
# _________________________________________________________________
# dense_21 (Dense)             (None, 5)                 1285
# =================================================================
# Total params: 3,488,895
# Trainable params: 3,488,895
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------
# Time Consumption (in sec): 1.0621881484985352
# Time Consumption (in min): 0.02
# Time Consumption (in hr): 0.0 2
# --------------------------------------------
# Epoch 1/100
# 65/65 [==============================] - 15s 142ms/step - loss: 7023.8755
# Epoch 2/100
# 65/65 [==============================] - 9s 145ms/step - loss: 3250.4568
# Epoch 3/100
# 65/65 [==============================] - 9s 140ms/step - loss: 1835.5393
# Epoch 4/100
# 65/65 [==============================] - 9s 138ms/step - loss: 939.3220
# Epoch 5/100
# 65/65 [==============================] - 9s 139ms/step - loss: 875.2766
# Epoch 6/100
# 65/65 [==============================] - 9s 138ms/step - loss: 1060.9763
# Epoch 7/100
# 65/65 [==============================] - 9s 140ms/step - loss: 858.5289
# Epoch 8/100
# 65/65 [==============================] - 9s 141ms/step - loss: 668.1679
# Epoch 9/100
# 65/65 [==============================] - 9s 140ms/step - loss: 556.3788
# Epoch 10/100
# 65/65 [==============================] - 9s 144ms/step - loss: 495.4101
# Epoch 11/100
# 65/65 [==============================] - 9s 145ms/step - loss: 559.6019
# Epoch 12/100
# 65/65 [==============================] - 9s 137ms/step - loss: 453.5956
# Epoch 13/100
# 65/65 [==============================] - 9s 141ms/step - loss: 356.9515
# Epoch 14/100
# 65/65 [==============================] - 9s 138ms/step - loss: 369.6766
# Epoch 15/100
# 65/65 [==============================] - 9s 131ms/step - loss: 363.4797
# Epoch 16/100
# 65/65 [==============================] - 9s 135ms/step - loss: 333.9221
# Epoch 17/100
# 65/65 [==============================] - 9s 144ms/step - loss: 330.7837
# Epoch 18/100
# 65/65 [==============================] - 9s 140ms/step - loss: 283.8596
# Epoch 19/100
# 65/65 [==============================] - 9s 138ms/step - loss: 300.6115
# Epoch 20/100
# 65/65 [==============================] - 9s 139ms/step - loss: 263.3597
# Epoch 21/100
# 65/65 [==============================] - 9s 141ms/step - loss: 224.5732
# Epoch 22/100
# 65/65 [==============================] - 9s 139ms/step - loss: 319.8285
# Epoch 23/100
# 65/65 [==============================] - 9s 141ms/step - loss: 266.9774
# Epoch 24/100
# 65/65 [==============================] - 9s 139ms/step - loss: 206.0994
