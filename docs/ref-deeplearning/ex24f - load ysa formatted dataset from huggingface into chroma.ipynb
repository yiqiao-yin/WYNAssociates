# %% [markdown]
# # Basic embedding retrieval with Chroma
#
# This notebook demonstrates the most basic use of Chroma to store and retrieve information using embeddings. This core building block is at the heart of many powerful AI applications.
#
# ## What are embeddings?
#
# Embeddings are the A.I-native way to represent any kind of data, making them the perfect fit for working with all kinds of A.I-powered tools and algorithms. They can represent text, images, and soon audio and video.
#
# To create an embedding, data is fed into an embedding model, which outputs vectors of numbers. The model is trained in such a way that 'similar' data, e.g. text with similar meanings, or images with similar content, will produce vectors which are nearer to one another, than those which are dissimilar.
#
# ## Embeddings and retrieval
#
# We can use the similarity property of embeddings to search for and retrieve information. For example, we can find documents relevant to a particular topic, or images similar to a given image. Rather than searching for keywords or tags, we can search by finding data with similar semantic meaning.

# %%
! pip install chromadb datasets
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.22-py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.0/509.0 kB 9.5 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.17.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.0.3)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.6.1)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 30.3 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.109.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 14.7 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Downloading uvicorn-0.27.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.25.2)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.4.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.9.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 30.7 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.17.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 36.0 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.22.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 9.9 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.43b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.15.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 10.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.2)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.60.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 42.1 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.7 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Collecting pyarrow>=12.0.0 (from datasets)
#   Downloading pyarrow-15.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 30.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Collecting backoff<3.0.0,>=1.10.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.22.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 8.4 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.43b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.43b0-py3-none-any.whl (28 kB)
# Collecting opentelemetry-semantic-conventions==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl (36 kB)
# Collecting opentelemetry-util-http==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.43b0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.9 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 34.7 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 41.9 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.2 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (3.7.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=254a315fcab723151fe8ec688cdc15b48734d8147925f0e7e3224eb91b81194c
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, python-dotenv, pyarrow, pulsar-client, overrides, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, importlib-metadata, humanfriendly, httptools, h11, dill, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, multiprocess, coloredlogs, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, datasets, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 10.0.1
#     Uninstalling pyarrow-10.0.1:
#       Successfully uninstalled pyarrow-10.0.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 15.0.0 which is incompatible.
# Successfully installed asgiref-3.7.2 backoff-2.2.1 bcrypt-4.1.2 chroma-hnswlib-0.7.3 chromadb-0.4.22 coloredlogs-15.0.1 datasets-2.17.0 deprecated-1.2.14 dill-0.3.8 fastapi-0.109.2 h11-0.14.0 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-6.11.0 kubernetes-29.0.0 mmh3-4.1.0 monotonic-1.6 multiprocess-0.70.16 onnxruntime-1.17.0 opentelemetry-api-1.22.0 opentelemetry-exporter-otlp-proto-common-1.22.0 opentelemetry-exporter-otlp-proto-grpc-1.22.0 opentelemetry-instrumentation-0.43b0 opentelemetry-instrumentation-asgi-0.43b0 opentelemetry-instrumentation-fastapi-0.43b0 opentelemetry-proto-1.22.0 opentelemetry-sdk-1.22.0 opentelemetry-semantic-conventions-0.43b0 opentelemetry-util-http-0.43b0 overrides-7.7.0 posthog-3.4.1 pulsar-client-3.4.0 pyarrow-15.0.0 pypika-0.48.9 python-dotenv-1.0.1 starlette-0.36.3 uvicorn-0.27.1 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0

# %% [markdown]
# ## Example Dataset
#
# As a demonstration we use the [SciQ dataset](https://arxiv.org/abs/1707.06209), available from [HuggingFace](https://huggingface.co/datasets/sciq).
#
# Dataset description, from HuggingFace:
#
# > The SciQ dataset contains 13,679 crowdsourced science exam questions about Physics, Chemistry and Biology, among others. The questions are in multiple-choice format with 4 answer options each. For the majority of the questions, an additional paragraph with supporting evidence for the correct answer is provided.
#
# In this notebook, we will demonstrate how to retrieve supporting evidence for a given question.

# %%
# Get the SciQ dataset from HuggingFace
from datasets import load_dataset
import pandas as pd

# %%
# %%time

dataset = load_dataset("eagle0504/youthless-homeless-shelter-web-scrape-dataset-qa-formatted")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/308 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/26.5k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/131 [00:00<?, ? examples/s]
# CPU times: user 913 ms, sys: 1.2 s, total: 2.12 s
# Wall time: 4.52 s

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['questions', 'answers'],
#         num_rows: 131
#     })
# })

# %% [markdown]
# ## Loading the data into Chroma
#
# Chroma comes with a built-in embedding model, which makes it simple to load text.
# We can load the SciQ dataset into Chroma with just a few lines of code.

# %%
# Import Chroma and instantiate a client. The default Chroma client is ephemeral, meaning it will not save to disk.
import chromadb

client = chromadb.Client()

# %%
# Create a new Chroma collection to store the supporting evidence. We don't need to specify an embedding fuction, and the default will be used.
collection = client.create_collection("vectordb1")

# %% [markdown]
# ### Investigate the Data Type

# %%
len(dataset["train"])
# Out:
# 131

# %% [markdown]
# THE HEAVY LIFTING IS HERE! PLEASE CURATE YOUR QUESTIONS TO MAKE SURE YOU CAN OVERLAP WITH USER QUESTIONS AS MUCH AS YOU CAN.

# %%
dataset["train"]['questions']
# Out:
# ['What is the main focus of the Youth Spirit Artworks program in Berkeley, California?',
#  'What challenges do older homeless and low-income youth from BIPOC and LGBTQIA+ communities face, and how does YSA address these challenges?',
#  'What is the main mission of the Telegraph Avenue Homeless Youth Drop-In Center?',
#  'What is the main goal of providing young people with skills, experience, and confidence?',
#  'What were the main goals of Young Aspirations, Young Artists (YaYa) organization in New Orleans?',
#  'What role did Sally play in the co-founding of Street Spirit?',
#  'What is the name of the group that started it?',
#  'Who were some of the important leaders in the Board?',
#  'Who played a big role in getting funding for YSA and supporting its vision?',
#  "How has YSA's use of art as a tool contributed to meeting life outcomes for young people who have experienced trauma and face financial challenges?",
#  'What opportunities does this provide for individuals?',
#  'Who is the secretary of the YSA board?',
#  'Who is the co-secretary of the YSA board?',
#  "What is Saphonia Foster's role on the YSA board?",
#  'Who is the treasurer of the YSA board?',
#  'Does Jonathannis hold any other positions besides being a member of the YSA board?',
#  "What is Allen's educational background and professional qualifications?",
#  'Who is the certified public accountant of the board of YSA?',
#  'Are you between the ages of 18-23, identify either Oakland or Berkeley as your home city, and are currently "literally" homeless?',
#  'What are the three conditions that individuals or families must meet under the first definition of homelessness?',
#  'What are the three conditions that individuals or families must meet to be considered under the second definition?',
#  'What are the conditions that individuals and families under the third definition must meet to be considered homeless?',
#  'What role has Jimi held in the Oakland community for many years?',
#  'What arts organizations has Evins worked with to bring quality art programming to Oakland and East Oakland?',
#  'Who was the lead artist for the "100 Families Oakland: Art and Social Change" project in 2005?',
#  "Question: \n        Where have Jimi's art exhibits been held?",
#  'What awards has he received from the Ebony Museum of Arts, Inc?',
#  'What prestigious awards and honors have been received for dedication to preserving African heritage and championing youth?',
#  'When did he receive the Alameda County Arts Leadership Award?',
#  "What has Jimi's passion been since he was a child?",
#  'What is the purpose of being at YSA?',
#  'What methods can be used to inspire and empower youth to believe in their ability to create and imagine in both art and life?',
#  'What publication does Alastair Boone work for as the Editor in Chief?',
#  'What are the responsibilities of an editor in relation to homelessness issues in the Bay Area and beyond?',
#  'Where was Boone born?',
#  'Where did she previously work before CityLab?',
#  'Where else has her writing been published?',
#  'What programs does YSA offer to fulfill its mission?',
#  'What is the schedule for the Fine Art program in the YSA studio?',
#  'What is the purpose of the Fine Art program in Berkeley and how do the YSA youth benefit from it?',
#  'What topics are covered in the accredited curriculum for the youth in the Fine Art program?',
#  'How does the Art Entrepreneurship and Sales program help youth participate in the marketing and sales of art?',
#  'What topics are covered in the accredited curriculum for the Art Entrepreneurship and Sales program?',
#  'What is the purpose of the Tiny House Village community organizing campaign initiated by youth at YSA?',
#  'How many houses have been built as of 2023 with the help of over 2,000 volunteers in Habitat-for-Humanity-style builds?',
#  'When did the Tiny House Empowerment Village open?',
#  'What features are included in the completed Tiny House Village?',
#  'What opportunities are available to residents for personal and professional growth through youth and volunteer led clubs?',
#  'How can residents develop a responsibility to the community through connections to local faith organizations and involvement in social justice projects?',
#  "What types of workshops do residents at the Village participate in as part of YSA's core jobs training program?",
#  'What was the motivation behind the initiation of the Tiny House Empowerment Village project?',
#  'How many homeless young people are there sleeping on the streets in Alameda County compared to the number of available youth-designated beds in shelters and affordable housing?',
#  'Question: \n        What challenges do young people facing housing instability typically encounter?',
#  "How will Youth Spirit Artworks' Tiny House Empowerment Village contribute to increasing the number of youth-designated beds in the county by almost 40%?",
#  'Who designed and built the Tiny House prototype unveiled in 2017?',
#  'What is the purpose of the Tiny House Empowerment Village?',
#  'What work does the religious community commit to for vulnerable members of our communities?',
#  'Which congregations support our organization as leadsupporting?',
#  'Which churches and congregations are listed as supporting organizations in the given content?',
#  'What is the name of the church located in Albany?',
#  'What is the address of Columba Catholic Church in Oakland?',
#  '"Which religious institution is located in Berkeley?"',
#  'What should I do to get my congregation involved in creating housing for at-risk youth beyond the Tiny House Empowerment Village?',
#  "What is the goal of Youth Spirit Artworks' community organizing campaign in the East Bay Area?",
#  "What specific roles or tasks are available for volunteers to help with at the build days for the YSA youth's housing projects?",
#  '"Are you interested in joining the committee for planning and outreach in our Tiny House Empowerment Village advocacy project?"',
#  'What is the link to volunteer with the TinyHouse Empowerment Village?',
#  'What is the preferred method for making referrals to the Tiny House Empowerment Village community?',
#  'What is the process for individuals to be considered for a spot at the Tiny House Empowerment Village shelter?',
#  'What factors are used to determine the ranking of individuals on the waitlist for our program?',
#  'What criteria determines who ranks at the top of the Coordinated Entry referral list?',
#  'What are the options for qualifying to take a Crisis Assessment according to the content provided?',
#  'What is the email address to reach out to for any questions?',
#  'What is the first option to see if you qualify to take a Crisis Assessment?',
#  'What is the phone number for Towne House (BACS Wellness Center)?',
#  'When can you call 2-1-1 from Monday to Friday?',
#  'Where can people without a phone call 2-1-1 in Berkeley?',
#  'What are the hours of operation for the Towne House (BACS Wellness Center) located at 629 Oakland Ave, Oakland CA 94611?',
#  'What is the address of the North County Housing Resource Center in Berkeley?',
#  'What are the operating hours of the Berkeley Drop-in Center on Tuesdays?',
#  'How many youth-designated beds are currently available for homeless young people in Alameda County?',
#  'What factors contribute to the lack of access to public resources for young people facing housing instability?',
#  'Question:\n    What are some of the challenges and risks that individuals experiencing homelessness may face in pursuing academic and vocational goals?',
#  'What is the responsibility of our community towards supporting our youth?',
#  'What is the mission of Youth Spirit Artworks (YSA) regarding homeless and underserved low-income young people in the Bay Area?',
#  'What kind of innovative youth-led efforts does YSA provide for jobs training and placement?',
#  'What is the mission of Housing Consortium of the East Bay (HCEB)?',
#  "What obstacle did the youth in YSA's program identify as their number-one challenge eight years ago?",
#  'What are potential solutions that can break the cycle of homelessness?',
#  'Question: \n    What was the result of their vision for a Tiny House Village?',
#  'What approaches and thinking are being used to address the homeless crisis, particularly in the Bay Area?',
#  'What was the approach used for building the Tiny House Empowerment Village project?',
#  'What was the first phase of the project?',
#  'Who led the YSA youth team in partnering with skilled Build Leaders to construct the first two houses in March and April of 2019?',
#  'What purpose did these houses serve in relation to training and future builds?',
#  'What was the focus of the second phase?',
#  'How many houses were completed by the interfaith religious community during the summer and fall of 2019?',
#  'How many houses were built by community volunteers in 2020?',
#  'What was the focus of the third phase?',
#  'Who were the artists responsible for designing and creating the murals on the Tiny Houses?',
#  'When will all 26 houses have completed murals?',
#  'What was the purpose of the fourth phase?',
#  'How many residents will be moving into the Village in February 2021?',
#  'What facilities are available in The Village for communal use?',
#  'What is the final stage of growth?',
#  "What is YSA's commitment to addressing the long-term need for affordable, permanent housing?",
#  'What factors make tiny houses compatible with the Habitat for Humanity community build model?',
#  'What is the maximum duration allowed for young people to stay based on the Covenant?',
#  "What opportunities are available for youth in the Village through Youth Spirit Artworks' job training program?",
#  'How much money has Youth Spirit Artworks raised since 2019 for tiny house construction?',
#  'Question: How much money has the Village raised from the City of Oakland for ongoing operating funds?',
#  'What is the goal of raising $100,000 in Case Management funds from the City of Berkeley?',
#  'What are the guiding principles of the operational plan?',
#  'What is the anticipated average monthly rental income per unit?',
#  'What is the purpose of using the rents collected?',
#  "What is the main focus of YSA's program model?",
#  'What types of services and training opportunities are available to residents to support their transition towards long-term housing stability?',
#  'What programs are currently offered at the YSA studio in Berkeley that have demonstrated success?',
#  'What services does Youth Spirit Artworks provide to support the successful transition of youth to long-term stability?',
#  'What expectations are placed on residents while in the program?',
#  'What is the purpose of the covenant of behavior for the Village based on community accountability and restorative justice?',
#  'What are the reasons for YSA tracking progress toward key goals and objectives?',
#  'What methods does YSA use to measure outcomes of resident progress in both the housing and job training program?',
#  'What plans do residents develop upon move-in?',
#  'What strategies are used to support participants in tracking and meeting their goals during regular case management meetings and community accountability?',
#  'Based on the content above, are residents in the first Village cohort eligible to apply for paid community leadership roles as Resident Assistants?',
#  'How does YSA track the impact and outcomes of its program over a period of years?',
#  'What is unique about our model of the Tiny House Empowerment Village for young adults?',
#  'What are the key components of the content that will be documented and shared?',
#  'What is the potential impact of using this model to help youth around the country?',
#  'What is the email address to contact Sally Hindman for additional information?']

# %%
# %%time

# Embed and store the first 100 supports for this demo
L = len(dataset["train"]['questions'])
collection.add(
    ids=[str(i) for i in range(0, L)],  # IDs are just strings
    documents=dataset["train"]['questions'], # Enter questions here
    metadatas=[{"type": "support"} for _ in range(0, L)],
)
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:03<00:00, 22.0MiB/s]
# CPU times: user 16.2 s, sys: 684 ms, total: 16.9 s
# Wall time: 7.95 s

# %%
collection.count()
# Out:
# 131

# %% [markdown]
# ## Querying the data
#
# Once the data is loaded, we can use Chroma to find supporting evidence for the questions in the dataset.
# In this example, we retrieve the most relevant result according to the embedding similarity score.
#
# Chroma handles computing similarity and finding the most relevant results for you, so you can focus on building your application.

# %%
dataset["train"]['questions'][0]
# Out:
# 'What is the main focus of the Youth Spirit Artworks program in Berkeley, California?'

# %%
user_query = "What is the main focus of the Youth Spirit Artworks program in Berkeley, California?"
user_query
# Out:
# 'What is the main focus of the Youth Spirit Artworks program in Berkeley, California?'

# %%
results = collection.query(
    query_texts=user_query,
    n_results=2)

# %%
results
# Out:
# {'ids': [['0', '63']],
#  'distances': [[0.0, 0.42253151535987854]],
#  'metadatas': [[{'type': 'support'}, {'type': 'support'}]],
#  'embeddings': None,
#  'documents': [['What is the main focus of the Youth Spirit Artworks program in Berkeley, California?',
#    "What is the goal of Youth Spirit Artworks' community organizing campaign in the East Bay Area?"]],
#  'uris': None,
#  'data': None}

# %%
idx = results["ids"][0]
idx = [int(i) for i in idx]
idx
# Out:
# [0, 63]

# %%
results["distances"][0]
# Out:
# [0.0, 0.42253151535987854]

# %%
[dataset["train"]['questions'][i] for i in idx]
# Out:
# ['What is the main focus of the Youth Spirit Artworks program in Berkeley, California?',
#  "What is the goal of Youth Spirit Artworks' community organizing campaign in the East Bay Area?"]

# %%
[dataset["train"]['answers'][i] for i in idx]
# Out:
# ['About YSAYouth Spirit Artworks (YSA) is a program in Berkeley, California, that helps homeless andlow-income young people in the San Francisco Bay Area',
#  'In response to the dire need for youth housing, Youth Spirit Artworks is engaged in aten-year community organizing campaign to create “100 Homes for 100 Homeless Youth” in theEast Bay Area']

# %%
ref = pd.DataFrame(
    {
        "idx": idx,
        "question": [dataset["train"]['questions'][i] for i in idx],
        "answers": [dataset["train"]['answers'][i] for i in idx],
        "distances": results["distances"][0]
    }
)
ref
# Out:
#    idx                                           question  \
# 0    0  What is the main focus of the Youth Spirit Art...
# 1   63  What is the goal of Youth Spirit Artworks' com...
#
#                                              answers  distances
# 0  About YSAYouth Spirit Artworks (YSA) is a prog...   0.000000
# 1  In response to the dire need for youth housing...   0.422532

# %%
ref = pd.DataFrame(
    {
        "idx": idx,
        "question": [dataset["train"]['questions'][i] for i in idx],
        "answers": [dataset["train"]['answers'][i] for i in idx],
        "distances": results["distances"][0]
    }
)
ref
# Out:
#    idx                                           question  \
# 0    0  What is the main focus of the Youth Spirit Art...
# 1   63  What is the goal of Youth Spirit Artworks' com...
#
#                                              answers  distances
# 0  About YSAYouth Spirit Artworks (YSA) is a prog...   0.082199
# 1  In response to the dire need for youth housing...   0.441973

# %%
special_threshold = -0.3
filtered_ref = ref[ref["distances"] < special_threshold]
if filtered_ref.shape[0] > 0:
    ref_from_db_search = filtered_ref["answers"]
else:
    ref_from_db_search = ref["answers"]

ref_from_db_search
# Out:
# 0    About YSAYouth Spirit Artworks (YSA) is a prog...
# 1    In response to the dire need for youth housing...
# Name: answers, dtype: object

# %% [markdown]
# we display the query questions along with their retrieved supports

# %% [markdown]
# ## What's next?
#
# Check out the Chroma documentation to [get started](https://docs.trychroma.com/getting-started) with building your own applications.
#
# The core embeddings based retrieval functionality demonstrated here is at the heart of many powerful AI applications, like using large language models with Chroma to [chat with your documents](https://github.com/chroma-core/chroma/tree/main/examples/chat_with_your_documents), as well as memory for agents like [BabyAgi](https://github.com/yoheinakajima/babyagi) and [Voyager](https://github.com/MineDojo/Voyager).
#
# Chroma is already integrated with many popular AI applications frameworks, including [LangChain](https://python.langchain.com/docs/integrations/vectorstores/chroma) and [LlamaIndex](https://gpt-index.readthedocs.io/en/latest/examples/vector_stores/ChromaIndexDemo.html).
#
# Join our community to learn more and get help with your projects: [Discord](https://discord.gg/MMeYNTmh3x) | [Twitter](https://twitter.com/trychroma)
#
# We are [hiring](https://trychroma.notion.site/careers-chroma-9d017c3007c7478ebd85bad854101497?pvs=4)!
