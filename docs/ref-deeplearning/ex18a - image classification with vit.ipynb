# %% [markdown]
# # Image classification with Vision Transformer
#
# **Author:** [Khalid Salama](https://www.linkedin.com/in/khalid-salama-24403144/)<br>
# **Date created:** 2021/01/18<br>
# **Last modified:** 2021/01/18<br>
# **Description:** Implementing the Vision Transformer (ViT) model for image classification.

# %% [markdown]
# ## Introduction
#
# This example implements the [Vision Transformer (ViT)](https://arxiv.org/abs/2010.11929)
# model by Alexey Dosovitskiy et al. for image classification,
# and demonstrates it on the CIFAR-100 dataset.
# The ViT model applies the Transformer architecture with self-attention to sequences of
# image patches, without using convolution layers.
#
# This example requires TensorFlow 2.4 or higher, as well as
# [TensorFlow Addons](https://www.tensorflow.org/addons/overview),
# which can be installed using the following command:
#
# ```python
# pip install -U tensorflow-addons
# ```

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
try:
    import tensorflow_addons as tfa
except:
    # !pip install tensorflow-addons
    import tensorflow_addons as tfa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 7.8 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %% [markdown]
# ## Prepare the data

# %%
num_classes = 100
input_shape = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 4s 0us/step
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %% [markdown]
# ## Configure the hyperparameters

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 800
image_size = 72  # We'll resize input images to this size
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 10
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %% [markdown]
# ## Use data augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %% [markdown]
# ## Implement multilayer perceptron (MLP)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ## Implement patch creation as a layer

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %% [markdown]
# Let's display patches for a sample image

# %%
patches = Patches(patch_size)(resized_image)
print(f'Before function Pathch size: {resized_image.shape}')
print(f'After function Pathch size: {patches.shape}')
# Out:
# Before function Pathch size: (1, 72, 72, 3)
# After function Pathch size: (1, 144, 108)

# %%
import matplotlib.pyplot as plt

def plot_patches(sample_index: int):
    plt.figure(figsize=(4, 4))
    image = x_train[np.random.choice(range(x_train.shape[sample_index]))]
    plt.imshow(image.astype("uint8"))
    plt.axis("off")

    resized_image = tf.image.resize(
        tf.convert_to_tensor([image]), size=(image_size, image_size)
    )
    patches = Patches(patch_size)(resized_image)
    print(f"Image size: {image_size} X {image_size}")
    print(f"Patch size: {patch_size} X {patch_size}")
    print(f"Patches per image: {patches.shape[1]}")
    print(f"Elements per patch: {patches.shape[-1]}")

    n = int(np.sqrt(patches.shape[1]))
    plt.figure(figsize=(4, 4))
    for i, patch in enumerate(patches[sample_index]):
        ax = plt.subplot(n, n, i + 1)
        patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
        plt.imshow(patch_img.numpy().astype("uint8"))
        plt.axis("off")

plot_patches(0)
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %% [markdown]
# ## Implement the patch encoding layer
#
# The `PatchEncoder` layer will linearly transform a patch by projecting it into a
# vector of size `projection_dim`. In addition, it adds a learnable position
# embedding to the projected vector.

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %% [markdown]
# ## Build the ViT model
#
# The ViT model consists of multiple Transformer blocks,
# which use the `layers.MultiHeadAttention` layer as a self-attention mechanism
# applied to the sequence of patches. The Transformer blocks produce a
# `[batch_size, num_patches, projection_dim]` tensor, which is processed via an
# classifier head with softmax to produce the final class probabilities output.
#
# Unlike the technique described in the [paper](https://arxiv.org/abs/2010.11929),
# which prepends a learnable embedding to the sequence of encoded patches to serve
# as the image representation, all the outputs of the final Transformer block are
# reshaped with `layers.Flatten()` and used as the image
# representation input to the classifier head.
# Note that the `layers.GlobalAveragePooling1D` layer
# could also be used instead to aggregate the outputs of the Transformer block,
# especially when the number of patches and the projection dimensions are large.

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %% [markdown]
# ## Compile, train, and evaluate the mode

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
with tf.device('/device:GPU:0'):
    vit_classifier = create_vit_classifier()
    history = run_experiment(vit_classifier)
# Out:
# Epoch 1/800
# 176/176 [==============================] - 50s 194ms/step - loss: 4.4156 - accuracy: 0.0494 - top-5-accuracy: 0.1767 - val_loss: 3.8652 - val_accuracy: 0.1078 - val_top-5-accuracy: 0.3236
# Epoch 2/800
# 176/176 [==============================] - 32s 183ms/step - loss: 3.9120 - accuracy: 0.0972 - top-5-accuracy: 0.2989 - val_loss: 3.5622 - val_accuracy: 0.1658 - val_top-5-accuracy: 0.4070
# Epoch 3/800
# 176/176 [==============================] - 32s 184ms/step - loss: 3.6738 - accuracy: 0.1318 - top-5-accuracy: 0.3685 - val_loss: 3.3844 - val_accuracy: 0.1894 - val_top-5-accuracy: 0.4652
# Epoch 4/800
# 176/176 [==============================] - 33s 187ms/step - loss: 3.5034 - accuracy: 0.1599 - top-5-accuracy: 0.4212 - val_loss: 3.2372 - val_accuracy: 0.2224 - val_top-5-accuracy: 0.5042
# Epoch 5/800
# 176/176 [==============================] - 33s 186ms/step - loss: 3.3468 - accuracy: 0.1888 - top-5-accuracy: 0.4662 - val_loss: 3.0930 - val_accuracy: 0.2512 - val_top-5-accuracy: 0.5418
# Epoch 6/800
# 176/176 [==============================] - 33s 187ms/step - loss: 3.2004 - accuracy: 0.2132 - top-5-accuracy: 0.5020 - val_loss: 2.9791 - val_accuracy: 0.2646 - val_top-5-accuracy: 0.5650
# Epoch 7/800
# 176/176 [==============================] - 33s 187ms/step - loss: 3.0708 - accuracy: 0.2412 - top-5-accuracy: 0.5373 - val_loss: 2.8621 - val_accuracy: 0.2900 - val_top-5-accuracy: 0.5878
# Epoch 8/800
# 176/176 [==============================] - 33s 187ms/step - loss: 2.9350 - accuracy: 0.2650 - top-5-accuracy: 0.5748 - val_loss: 2.6902 - val_accuracy: 0.3222 - val_top-5-accuracy: 0.6270
# Epoch 9/800
# 176/176 [==============================] - 33s 185ms/step - loss: 2.8165 - accuracy: 0.2899 - top-5-accuracy: 0.6023 - val_loss: 2.5624 - val_accuracy: 0.3488 - val_top-5-accuracy: 0.6544
# Epoch 10/800
# 176/176 [==============================] - 32s 183ms/step - loss: 2.7035 - accuracy: 0.3132 - top-5-accuracy: 0.6271 - val_loss: 2.4717 - val_accuracy: 0.3658 - val_top-5-accuracy: 0.6784
# Epoch 11/800
# 176/176 [==============================] - 33s 185ms/step - loss: 2.5961 - accuracy: 0.3344 - top-5-accuracy: 0.6521 - val_loss: 2.4145 - val_accuracy: 0.3796 - val_top-5-accuracy: 0.6832
# Epoch 12/800
# 176/176 [==============================] - 33s 186ms/step - loss: 2.5128 - accuracy: 0.3510 - top-5-accuracy: 0.6704 - val_loss: 2.3506 - val_accuracy: 0.3922 - val_top-5-accuracy: 0.7004
# Epoch 13/800
# 176/176 [==============================] - 33s 185ms/step - loss: 2.4173 - accuracy: 0.3694 - top-5-accuracy: 0.6898 - val_loss: 2.3229 - val_accuracy: 0.3970 - val_top-5-accuracy: 0.7050
# Epoch 14/800
# 176/176 [==============================] - 33s 187ms/step - loss: 2.3574 - accuracy: 0.3823 - top-5-accuracy: 0.7033 - val_loss: 2.2501 - val_accuracy: 0.4154 - val_top-5-accuracy: 0.7206
# Epoch 15/800
# 176/176 [==============================] - 32s 182ms/step - loss: 2.2833 - accuracy: 0.3986 - top-5-accuracy: 0.7192 - val_loss: 2.2187 - val_accuracy: 0.4138 - val_top-5-accuracy: 0.7238
# Epoch 16/800
# 176/176 [==============================] - 32s 183ms/step - loss: 2.2217 - accuracy: 0.4118 - top-5-accuracy: 0.7309 - val_loss: 2.1888 - val_accuracy: 0.4290 - val_top-5-accuracy: 0.7324
# Epoch 17/800
# 176/176 [==============================] - 32s 184ms/step - loss: 2.1583 - accuracy: 0.4240 - top-5-accuracy: 0.7429 - val_loss: 2.1685 - val_accuracy: 0.4316 - val_top-5-accuracy: 0.7412
# Epoch 18/800
# 176/176 [==============================] - 33s 187ms/step - loss: 2.0951 - accuracy: 0.4390 - top-5-accuracy: 0.7546 - val_loss: 2.1505 - val_accuracy: 0.4362 - val_top-5-accuracy: 0.7446
# Epoch 19/800
# 176/176 [==============================] - 33s 187ms/step - loss: 2.0377 - accuracy: 0.4534 - top-5-accuracy: 0.7676 - val_loss: 2.0999 - val_accuracy: 0.4458 - val_top-5-accuracy: 0.7466
# Epoch 20/800
# 176/176 [==============================] - 33s 186ms/step - loss: 1.9819 - accuracy: 0.4648 - top-5-accuracy: 0.7784 - val_loss: 2.0782 - val_accuracy: 0.4566 - val_top-5-accuracy: 0.7558
# Epoch 21/800
# 176/176 [==============================] - 33s 186ms/step - loss: 1.9328 - accuracy: 0.4786 - top-5-accuracy: 0.7862 - val_loss: 2.0316 - val_accuracy: 0.4656 - val_top-5-accuracy: 0.7646
# Epoch 22/800
# 176/176 [==============================] - 32s 183ms/step - loss: 1.8842 - accuracy: 0.4880 - top-5-accuracy: 0.7951 - val_loss: 1.9878 - val_accuracy: 0.4718 - val_top-5-accuracy: 0.7734
# Epoch 23/800
# 176/176 [==============================] - 32s 184ms/step - loss: 1.8441 - accuracy: 0.4951 - top-5-accuracy: 0.8052 - val_loss: 1.9922 - val_accuracy: 0.4724 - val_top-5-accuracy: 0.7704
# Epoch 24/800
# 176/176 [==============================] - 33s 187ms/step - loss: 1.7964 - accuracy: 0.5068 - top-5-accuracy: 0.8134 - val_loss: 1.9485 - val_accuracy: 0.4820 - val_top-5-accuracy: 0.7748
# Epoch 25/800
# 176/176 [==============================] - 33s 185ms/step - loss: 1.7410 - accuracy: 0.5188 - top-5-accuracy: 0.8254 - val_loss: 1.9808 - val_accuracy: 0.4840 - val_top-5-accuracy: 0.7746
# Epoch 26/800
# 176/176 [==============================] - 33s 185ms/step - loss: 1.7166 - accuracy: 0.5215 - top-5-accuracy: 0.8281 - val_loss: 1.9386 - val_accuracy: 0.4892 - val_top-5-accuracy: 0.7762
# Epoch 27/800
# 176/176 [==============================] - 31s 179ms/step - loss: 1.6657 - accuracy: 0.5359 - top-5-accuracy: 0.8352 - val_loss: 1.9455 - val_accuracy: 0.4862 - val_top-5-accuracy: 0.7782
# Epoch 28/800
# 176/176 [==============================] - 33s 185ms/step - loss: 1.6331 - accuracy: 0.5441 - top-5-accuracy: 0.8415 - val_loss: 1.9156 - val_accuracy: 0.4976 - val_top-5-accuracy: 0.7810
# Epoch 29/800
# 176/176 [==============================] - 32s 181ms/step - loss: 1.6050 - accuracy: 0.5506 - top-5-accuracy: 0.8450 - val_loss: 1.9000 - val_accuracy: 0.4940 - val_top-5-accuracy: 0.7884
# Epoch 30/800
# 176/176 [==============================] - 33s 186ms/step - loss: 1.5707 - accuracy: 0.5582 - top-5-accuracy: 0.8530 - val_loss: 1.9156 - val_accuracy: 0.4994 - val_top-5-accuracy: 0.7878
# Epoch 31/800
# 176/176 [==============================] - 32s 179ms/step - loss: 1.5315 - accuracy: 0.5639 - top-5-accuracy: 0.8594 - val_loss: 1.9200 - val_accuracy: 0.4968 - val_top-5-accuracy: 0.7832
# Epoch 32/800
# 176/176 [==============================] - 32s 182ms/step - loss: 1.4980 - accuracy: 0.5752 - top-5-accuracy: 0.8654 - val_loss: 1.8793 - val_accuracy: 0.5002 - val_top-5-accuracy: 0.7932
# Epoch 33/800
# 176/176 [==============================] - 32s 183ms/step - loss: 1.4832 - accuracy: 0.5802 - top-5-accuracy: 0.8668 - val_loss: 1.9070 - val_accuracy: 0.5022 - val_top-5-accuracy: 0.7832
# Epoch 34/800
# 176/176 [==============================] - 31s 178ms/step - loss: 1.4534 - accuracy: 0.5886 - top-5-accuracy: 0.8712 - val_loss: 1.8959 - val_accuracy: 0.5002 - val_top-5-accuracy: 0.7878
# Epoch 35/800
# 176/176 [==============================] - 32s 184ms/step - loss: 1.4169 - accuracy: 0.5938 - top-5-accuracy: 0.8769 - val_loss: 1.8890 - val_accuracy: 0.5088 - val_top-5-accuracy: 0.7892
# Epoch 36/800
# 176/176 [==============================] - 31s 178ms/step - loss: 1.3883 - accuracy: 0.6032 - top-5-accuracy: 0.8826 - val_loss: 1.9084 - val_accuracy: 0.5054 - val_top-5-accuracy: 0.7922
# Epoch 37/800
# 176/176 [==============================] - 32s 182ms/step - loss: 1.3705 - accuracy: 0.6088 - top-5-accuracy: 0.8851 - val_loss: 1.8804 - val_accuracy: 0.5062 - val_top-5-accuracy: 0.7944
# Epoch 38/800
# 176/176 [==============================] - 33s 186ms/step - loss: 1.3460 - accuracy: 0.6116 - top-5-accuracy: 0.8883 - val_loss: 1.8830 - val_accuracy: 0.5106 - val_top-5-accuracy: 0.7988
# Epoch 39/800
# 176/176 [==============================] - 32s 183ms/step - loss: 1.3078 - accuracy: 0.6239 - top-5-accuracy: 0.8944 - val_loss: 1.8782 - val_accuracy: 0.5132 - val_top-5-accuracy: 0.8034
# Epoch 40/800
# 176/176 [==============================] - 32s 183ms/step - loss: 1.2830 - accuracy: 0.6285 - top-5-accuracy: 0.8983 - val_loss: 1.8753 - val_accuracy: 0.5144 - val_top-5-accuracy: 0.8018
# Epoch 41/800
# 176/176 [==============================] - 32s 181ms/step - loss: 1.2722 - accuracy: 0.6317 - top-5-accuracy: 0.8994 - val_loss: 1.8996 - val_accuracy: 0.5076 - val_top-5-accuracy: 0.8004
# Epoch 42/800
# 176/176 [==============================] - 32s 181ms/step - loss: 1.2642 - accuracy: 0.6329 - top-5-accuracy: 0.9009 - val_loss: 1.8853 - val_accuracy: 0.5102 - val_top-5-accuracy: 0.7992
# Epoch 43/800
# 176/176 [==============================] - 33s 186ms/step - loss: 1.2258 - accuracy: 0.6401 - top-5-accuracy: 0.9060 - val_loss: 1.8671 - val_accuracy: 0.5170 - val_top-5-accuracy: 0.8044
# Epoch 44/800
# 176/176 [==============================] - 31s 179ms/step - loss: 1.2068 - accuracy: 0.6488 - top-5-accuracy: 0.9083 - val_loss: 1.8997 - val_accuracy: 0.5130 - val_top-5-accuracy: 0.8012
# Epoch 45/800
# 176/176 [==============================] - 32s 184ms/step - loss: 1.1844 - accuracy: 0.6517 - top-5-accuracy: 0.9121 - val_loss: 1.8622 - val_accuracy: 0.5198 - val_top-5-accuracy: 0.8070
# Epoch 46/800
# 176/176 [==============================] - 33s 185ms/step - loss: 1.1766 - accuracy: 0.6556 - top-5-accuracy: 0.9130 - val_loss: 1.8365 - val_accuracy: 0.5232 - val_top-5-accuracy: 0.8106
# Epoch 47/800
# 176/176 [==============================] - 32s 181ms/step - loss: 1.1566 - accuracy: 0.6635 - top-5-accuracy: 0.9161 - val_loss: 1.8633 - val_accuracy: 0.5204 - val_top-5-accuracy: 0.8104
# Epoch 48/800
# 176/176 [==============================] - 32s 180ms/step - loss: 1.1344 - accuracy: 0.6675 - top-5-accuracy: 0.9185 - val_loss: 1.8793 - val_accuracy: 0.5158 - val_top-5-accuracy: 0.8004
# Epoch 49/800
# 176/176 [==============================] - 31s 178ms/step - loss: 1.1233 - accuracy: 0.6707 - top-5-accuracy: 0.9202 - val_loss: 1.8730 - val_accuracy: 0.5128 - val_top-5-accuracy: 0.8026
# Epoch 50/800
# 176/176 [==============================] - 32s 180ms/step - loss: 1.1053 - accuracy: 0.6768 - top-5-accuracy: 0.9212 - val_loss: 1.8755 - val_accuracy: 0.5172 - val_top-5-accuracy: 0.8062
# Epoch 51/800
# 176/176 [==============================] - 32s 181ms/step - loss: 1.0924 - accuracy: 0.6801 - top-5-accuracy: 0.9242 - val_loss: 1.8690 - val_accuracy: 0.5196 - val_top-5-accuracy: 0.8048
# Epoch 52/800
# 176/176 [==============================] - 32s 182ms/step - loss: 1.0840 - accuracy: 0.6803 - top-5-accuracy: 0.9252 - val_loss: 1.8502 - val_accuracy: 0.5200 - val_top-5-accuracy: 0.8108
# Epoch 53/800
# 176/176 [==============================] - 32s 180ms/step - loss: 1.0732 - accuracy: 0.6836 - top-5-accuracy: 0.9278 - val_loss: 1.9038 - val_accuracy: 0.5172 - val_top-5-accuracy: 0.8040
# Epoch 54/800
# 176/176 [==============================] - 31s 178ms/step - loss: 1.0524 - accuracy: 0.6884 - top-5-accuracy: 0.9290 - val_loss: 1.9154 - val_accuracy: 0.5216 - val_top-5-accuracy: 0.8030
# Epoch 55/800
# 176/176 [==============================] - 32s 180ms/step - loss: 1.0432 - accuracy: 0.6916 - top-5-accuracy: 0.9321 - val_loss: 1.9098 - val_accuracy: 0.5180 - val_top-5-accuracy: 0.8036
# Epoch 56/800
# 176/176 [==============================] - 33s 185ms/step - loss: 1.0338 - accuracy: 0.6953 - top-5-accuracy: 0.9318 - val_loss: 1.9032 - val_accuracy: 0.5262 - val_top-5-accuracy: 0.8046
# Epoch 57/800
# 176/176 [==============================] - 32s 181ms/step - loss: 1.0030 - accuracy: 0.7008 - top-5-accuracy: 0.9371 - val_loss: 1.8991 - val_accuracy: 0.5240 - val_top-5-accuracy: 0.8072
# Epoch 58/800
# 176/176 [==============================] - 33s 185ms/step - loss: 1.0092 - accuracy: 0.6996 - top-5-accuracy: 0.9346 - val_loss: 1.8809 - val_accuracy: 0.5302 - val_top-5-accuracy: 0.8102
# Epoch 59/800
# 176/176 [==============================] - 31s 178ms/step - loss: 1.0012 - accuracy: 0.7025 - top-5-accuracy: 0.9367 - val_loss: 1.8983 - val_accuracy: 0.5278 - val_top-5-accuracy: 0.8036
# Epoch 60/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.9942 - accuracy: 0.7021 - top-5-accuracy: 0.9369 - val_loss: 1.9111 - val_accuracy: 0.5208 - val_top-5-accuracy: 0.8100
# Epoch 61/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.9715 - accuracy: 0.7119 - top-5-accuracy: 0.9381 - val_loss: 1.8659 - val_accuracy: 0.5244 - val_top-5-accuracy: 0.8076
# Epoch 62/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.9624 - accuracy: 0.7139 - top-5-accuracy: 0.9399 - val_loss: 1.8954 - val_accuracy: 0.5336 - val_top-5-accuracy: 0.8102
# Epoch 63/800
# 176/176 [==============================] - 31s 177ms/step - loss: 0.9528 - accuracy: 0.7138 - top-5-accuracy: 0.9424 - val_loss: 1.8631 - val_accuracy: 0.5300 - val_top-5-accuracy: 0.8070
# Epoch 64/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.9387 - accuracy: 0.7182 - top-5-accuracy: 0.9448 - val_loss: 1.9403 - val_accuracy: 0.5266 - val_top-5-accuracy: 0.8042
# Epoch 65/800
# 176/176 [==============================] - 31s 177ms/step - loss: 0.9440 - accuracy: 0.7195 - top-5-accuracy: 0.9428 - val_loss: 1.9136 - val_accuracy: 0.5260 - val_top-5-accuracy: 0.8060
# Epoch 66/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.9214 - accuracy: 0.7255 - top-5-accuracy: 0.9453 - val_loss: 1.8904 - val_accuracy: 0.5284 - val_top-5-accuracy: 0.8102
# Epoch 67/800
# 176/176 [==============================] - 31s 177ms/step - loss: 0.9231 - accuracy: 0.7250 - top-5-accuracy: 0.9443 - val_loss: 1.8664 - val_accuracy: 0.5306 - val_top-5-accuracy: 0.8080
# Epoch 68/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.9113 - accuracy: 0.7270 - top-5-accuracy: 0.9460 - val_loss: 1.8891 - val_accuracy: 0.5274 - val_top-5-accuracy: 0.8094
# Epoch 69/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.9110 - accuracy: 0.7286 - top-5-accuracy: 0.9470 - val_loss: 1.9400 - val_accuracy: 0.5250 - val_top-5-accuracy: 0.8014
# Epoch 70/800
# 176/176 [==============================] - 31s 177ms/step - loss: 0.9025 - accuracy: 0.7283 - top-5-accuracy: 0.9463 - val_loss: 1.9346 - val_accuracy: 0.5228 - val_top-5-accuracy: 0.8130
# Epoch 71/800
# 176/176 [==============================] - 31s 177ms/step - loss: 0.8910 - accuracy: 0.7340 - top-5-accuracy: 0.9489 - val_loss: 1.8913 - val_accuracy: 0.5302 - val_top-5-accuracy: 0.8086
# Epoch 72/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.8858 - accuracy: 0.7369 - top-5-accuracy: 0.9491 - val_loss: 1.9540 - val_accuracy: 0.5178 - val_top-5-accuracy: 0.8048
# Epoch 73/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.8658 - accuracy: 0.7409 - top-5-accuracy: 0.9512 - val_loss: 1.9170 - val_accuracy: 0.5238 - val_top-5-accuracy: 0.8098
# Epoch 74/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.8690 - accuracy: 0.7405 - top-5-accuracy: 0.9517 - val_loss: 1.9175 - val_accuracy: 0.5278 - val_top-5-accuracy: 0.8128
# Epoch 75/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.8695 - accuracy: 0.7386 - top-5-accuracy: 0.9510 - val_loss: 1.9180 - val_accuracy: 0.5284 - val_top-5-accuracy: 0.8118
# Epoch 76/800
# 176/176 [==============================] - 33s 186ms/step - loss: 0.8619 - accuracy: 0.7413 - top-5-accuracy: 0.9516 - val_loss: 1.8895 - val_accuracy: 0.5344 - val_top-5-accuracy: 0.8094
# Epoch 77/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.8567 - accuracy: 0.7452 - top-5-accuracy: 0.9519 - val_loss: 1.9341 - val_accuracy: 0.5254 - val_top-5-accuracy: 0.8124
# Epoch 78/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.8401 - accuracy: 0.7478 - top-5-accuracy: 0.9528 - val_loss: 1.8876 - val_accuracy: 0.5366 - val_top-5-accuracy: 0.8146
# Epoch 79/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.8321 - accuracy: 0.7506 - top-5-accuracy: 0.9544 - val_loss: 1.9206 - val_accuracy: 0.5298 - val_top-5-accuracy: 0.8104
# Epoch 80/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.8274 - accuracy: 0.7505 - top-5-accuracy: 0.9545 - val_loss: 1.9331 - val_accuracy: 0.5348 - val_top-5-accuracy: 0.8096
# Epoch 81/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.8374 - accuracy: 0.7468 - top-5-accuracy: 0.9558 - val_loss: 1.9378 - val_accuracy: 0.5282 - val_top-5-accuracy: 0.8092
# Epoch 82/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.8242 - accuracy: 0.7510 - top-5-accuracy: 0.9562 - val_loss: 1.9264 - val_accuracy: 0.5308 - val_top-5-accuracy: 0.8088
# Epoch 83/800
# 176/176 [==============================] - 33s 186ms/step - loss: 0.8086 - accuracy: 0.7573 - top-5-accuracy: 0.9570 - val_loss: 1.9361 - val_accuracy: 0.5388 - val_top-5-accuracy: 0.8060
# Epoch 84/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.8176 - accuracy: 0.7522 - top-5-accuracy: 0.9564 - val_loss: 1.9489 - val_accuracy: 0.5274 - val_top-5-accuracy: 0.8070
# Epoch 85/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.8037 - accuracy: 0.7580 - top-5-accuracy: 0.9574 - val_loss: 1.9605 - val_accuracy: 0.5270 - val_top-5-accuracy: 0.8068
# Epoch 86/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.8102 - accuracy: 0.7562 - top-5-accuracy: 0.9576 - val_loss: 1.9356 - val_accuracy: 0.5286 - val_top-5-accuracy: 0.8088
# Epoch 87/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7971 - accuracy: 0.7621 - top-5-accuracy: 0.9569 - val_loss: 1.9338 - val_accuracy: 0.5340 - val_top-5-accuracy: 0.8138
# Epoch 88/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.8027 - accuracy: 0.7604 - top-5-accuracy: 0.9564 - val_loss: 1.9664 - val_accuracy: 0.5350 - val_top-5-accuracy: 0.8070
# Epoch 89/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.7894 - accuracy: 0.7609 - top-5-accuracy: 0.9593 - val_loss: 1.9467 - val_accuracy: 0.5304 - val_top-5-accuracy: 0.8060
# Epoch 90/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.7847 - accuracy: 0.7629 - top-5-accuracy: 0.9594 - val_loss: 1.9089 - val_accuracy: 0.5304 - val_top-5-accuracy: 0.8106
# Epoch 91/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7758 - accuracy: 0.7671 - top-5-accuracy: 0.9612 - val_loss: 1.9234 - val_accuracy: 0.5298 - val_top-5-accuracy: 0.8094
# Epoch 92/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7914 - accuracy: 0.7621 - top-5-accuracy: 0.9578 - val_loss: 1.9601 - val_accuracy: 0.5296 - val_top-5-accuracy: 0.8060
# Epoch 93/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7879 - accuracy: 0.7632 - top-5-accuracy: 0.9594 - val_loss: 1.9279 - val_accuracy: 0.5374 - val_top-5-accuracy: 0.8116
# Epoch 94/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.7757 - accuracy: 0.7665 - top-5-accuracy: 0.9593 - val_loss: 1.9578 - val_accuracy: 0.5366 - val_top-5-accuracy: 0.8104
# Epoch 95/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.7683 - accuracy: 0.7660 - top-5-accuracy: 0.9613 - val_loss: 1.9745 - val_accuracy: 0.5354 - val_top-5-accuracy: 0.8064
# Epoch 96/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7662 - accuracy: 0.7718 - top-5-accuracy: 0.9595 - val_loss: 1.9756 - val_accuracy: 0.5328 - val_top-5-accuracy: 0.8056
# Epoch 97/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7519 - accuracy: 0.7727 - top-5-accuracy: 0.9629 - val_loss: 1.9220 - val_accuracy: 0.5372 - val_top-5-accuracy: 0.8110
# Epoch 98/800
# 176/176 [==============================] - 32s 185ms/step - loss: 0.7543 - accuracy: 0.7720 - top-5-accuracy: 0.9621 - val_loss: 1.9830 - val_accuracy: 0.5404 - val_top-5-accuracy: 0.8074
# Epoch 99/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.7532 - accuracy: 0.7748 - top-5-accuracy: 0.9626 - val_loss: 1.9255 - val_accuracy: 0.5372 - val_top-5-accuracy: 0.8088
# Epoch 100/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.7476 - accuracy: 0.7744 - top-5-accuracy: 0.9632 - val_loss: 1.9369 - val_accuracy: 0.5348 - val_top-5-accuracy: 0.8144
# Epoch 101/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.7528 - accuracy: 0.7712 - top-5-accuracy: 0.9625 - val_loss: 1.9215 - val_accuracy: 0.5392 - val_top-5-accuracy: 0.8132
# Epoch 102/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.7437 - accuracy: 0.7745 - top-5-accuracy: 0.9634 - val_loss: 1.9681 - val_accuracy: 0.5398 - val_top-5-accuracy: 0.8152
# Epoch 103/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7267 - accuracy: 0.7805 - top-5-accuracy: 0.9648 - val_loss: 1.9674 - val_accuracy: 0.5342 - val_top-5-accuracy: 0.8118
# Epoch 104/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7371 - accuracy: 0.7767 - top-5-accuracy: 0.9648 - val_loss: 1.9404 - val_accuracy: 0.5390 - val_top-5-accuracy: 0.8090
# Epoch 105/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.7300 - accuracy: 0.7786 - top-5-accuracy: 0.9654 - val_loss: 1.9617 - val_accuracy: 0.5348 - val_top-5-accuracy: 0.8090
# Epoch 106/800
# 176/176 [==============================] - 33s 187ms/step - loss: 0.7384 - accuracy: 0.7775 - top-5-accuracy: 0.9644 - val_loss: 1.9426 - val_accuracy: 0.5480 - val_top-5-accuracy: 0.8130
# Epoch 107/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.7157 - accuracy: 0.7816 - top-5-accuracy: 0.9648 - val_loss: 1.9629 - val_accuracy: 0.5374 - val_top-5-accuracy: 0.8094
# Epoch 108/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.7291 - accuracy: 0.7791 - top-5-accuracy: 0.9650 - val_loss: 1.9745 - val_accuracy: 0.5286 - val_top-5-accuracy: 0.8070
# Epoch 109/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7376 - accuracy: 0.7770 - top-5-accuracy: 0.9643 - val_loss: 1.9280 - val_accuracy: 0.5384 - val_top-5-accuracy: 0.8156
# Epoch 110/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.7265 - accuracy: 0.7812 - top-5-accuracy: 0.9642 - val_loss: 1.9470 - val_accuracy: 0.5390 - val_top-5-accuracy: 0.8108
# Epoch 111/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7217 - accuracy: 0.7827 - top-5-accuracy: 0.9647 - val_loss: 1.9763 - val_accuracy: 0.5318 - val_top-5-accuracy: 0.8136
# Epoch 112/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.7033 - accuracy: 0.7856 - top-5-accuracy: 0.9659 - val_loss: 1.9508 - val_accuracy: 0.5378 - val_top-5-accuracy: 0.8140
# Epoch 113/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.7172 - accuracy: 0.7840 - top-5-accuracy: 0.9645 - val_loss: 1.9778 - val_accuracy: 0.5300 - val_top-5-accuracy: 0.8092
# Epoch 114/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7129 - accuracy: 0.7842 - top-5-accuracy: 0.9662 - val_loss: 1.9845 - val_accuracy: 0.5426 - val_top-5-accuracy: 0.8154
# Epoch 115/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.7135 - accuracy: 0.7839 - top-5-accuracy: 0.9651 - val_loss: 1.9565 - val_accuracy: 0.5386 - val_top-5-accuracy: 0.8108
# Epoch 116/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.7102 - accuracy: 0.7857 - top-5-accuracy: 0.9664 - val_loss: 1.9833 - val_accuracy: 0.5396 - val_top-5-accuracy: 0.8070
# Epoch 117/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.7084 - accuracy: 0.7855 - top-5-accuracy: 0.9661 - val_loss: 1.9751 - val_accuracy: 0.5368 - val_top-5-accuracy: 0.8160
# Epoch 118/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.7007 - accuracy: 0.7882 - top-5-accuracy: 0.9661 - val_loss: 1.9623 - val_accuracy: 0.5396 - val_top-5-accuracy: 0.8150
# Epoch 119/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6925 - accuracy: 0.7905 - top-5-accuracy: 0.9671 - val_loss: 1.9883 - val_accuracy: 0.5384 - val_top-5-accuracy: 0.8138
# Epoch 120/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.7000 - accuracy: 0.7908 - top-5-accuracy: 0.9660 - val_loss: 1.9684 - val_accuracy: 0.5330 - val_top-5-accuracy: 0.8100
# Epoch 121/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6946 - accuracy: 0.7904 - top-5-accuracy: 0.9670 - val_loss: 1.9620 - val_accuracy: 0.5422 - val_top-5-accuracy: 0.8080
# Epoch 122/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.6967 - accuracy: 0.7902 - top-5-accuracy: 0.9667 - val_loss: 1.9678 - val_accuracy: 0.5362 - val_top-5-accuracy: 0.8090
# Epoch 123/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.6993 - accuracy: 0.7893 - top-5-accuracy: 0.9676 - val_loss: 1.9480 - val_accuracy: 0.5364 - val_top-5-accuracy: 0.8096
# Epoch 124/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6947 - accuracy: 0.7885 - top-5-accuracy: 0.9684 - val_loss: 1.9708 - val_accuracy: 0.5386 - val_top-5-accuracy: 0.8126
# Epoch 125/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6964 - accuracy: 0.7894 - top-5-accuracy: 0.9671 - val_loss: 1.9767 - val_accuracy: 0.5344 - val_top-5-accuracy: 0.8072
# Epoch 126/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6852 - accuracy: 0.7942 - top-5-accuracy: 0.9671 - val_loss: 1.9697 - val_accuracy: 0.5450 - val_top-5-accuracy: 0.8140
# Epoch 127/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.6855 - accuracy: 0.7939 - top-5-accuracy: 0.9684 - val_loss: 1.9681 - val_accuracy: 0.5444 - val_top-5-accuracy: 0.8120
# Epoch 128/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6774 - accuracy: 0.7934 - top-5-accuracy: 0.9692 - val_loss: 1.9536 - val_accuracy: 0.5414 - val_top-5-accuracy: 0.8114
# Epoch 129/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6815 - accuracy: 0.7927 - top-5-accuracy: 0.9684 - val_loss: 1.9778 - val_accuracy: 0.5392 - val_top-5-accuracy: 0.8054
# Epoch 130/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6688 - accuracy: 0.8002 - top-5-accuracy: 0.9690 - val_loss: 2.0061 - val_accuracy: 0.5352 - val_top-5-accuracy: 0.8072
# Epoch 131/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6898 - accuracy: 0.7921 - top-5-accuracy: 0.9679 - val_loss: 1.9886 - val_accuracy: 0.5444 - val_top-5-accuracy: 0.8076
# Epoch 132/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6753 - accuracy: 0.7932 - top-5-accuracy: 0.9695 - val_loss: 2.0065 - val_accuracy: 0.5450 - val_top-5-accuracy: 0.8048
# Epoch 133/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6744 - accuracy: 0.7949 - top-5-accuracy: 0.9686 - val_loss: 1.9965 - val_accuracy: 0.5368 - val_top-5-accuracy: 0.8048
# Epoch 134/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.6680 - accuracy: 0.7988 - top-5-accuracy: 0.9699 - val_loss: 2.0628 - val_accuracy: 0.5282 - val_top-5-accuracy: 0.8030
# Epoch 135/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6858 - accuracy: 0.7930 - top-5-accuracy: 0.9673 - val_loss: 1.9485 - val_accuracy: 0.5392 - val_top-5-accuracy: 0.8078
# Epoch 136/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.6820 - accuracy: 0.7925 - top-5-accuracy: 0.9678 - val_loss: 1.9736 - val_accuracy: 0.5402 - val_top-5-accuracy: 0.8086
# Epoch 137/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6687 - accuracy: 0.7982 - top-5-accuracy: 0.9695 - val_loss: 1.9895 - val_accuracy: 0.5386 - val_top-5-accuracy: 0.8070
# Epoch 138/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6608 - accuracy: 0.8008 - top-5-accuracy: 0.9691 - val_loss: 1.9688 - val_accuracy: 0.5422 - val_top-5-accuracy: 0.8128
# Epoch 139/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6652 - accuracy: 0.7972 - top-5-accuracy: 0.9706 - val_loss: 1.9927 - val_accuracy: 0.5408 - val_top-5-accuracy: 0.8126
# Epoch 140/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6631 - accuracy: 0.8023 - top-5-accuracy: 0.9704 - val_loss: 1.9860 - val_accuracy: 0.5458 - val_top-5-accuracy: 0.8076
# Epoch 141/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.6556 - accuracy: 0.8002 - top-5-accuracy: 0.9706 - val_loss: 1.9886 - val_accuracy: 0.5372 - val_top-5-accuracy: 0.8150
# Epoch 142/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.6697 - accuracy: 0.7990 - top-5-accuracy: 0.9700 - val_loss: 1.9314 - val_accuracy: 0.5442 - val_top-5-accuracy: 0.8118
# Epoch 143/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.6502 - accuracy: 0.8038 - top-5-accuracy: 0.9715 - val_loss: 1.9759 - val_accuracy: 0.5354 - val_top-5-accuracy: 0.8068
# Epoch 144/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6663 - accuracy: 0.7991 - top-5-accuracy: 0.9700 - val_loss: 1.9853 - val_accuracy: 0.5408 - val_top-5-accuracy: 0.8090
# Epoch 145/800
# 176/176 [==============================] - 33s 186ms/step - loss: 0.6570 - accuracy: 0.8014 - top-5-accuracy: 0.9704 - val_loss: 1.9618 - val_accuracy: 0.5484 - val_top-5-accuracy: 0.8140
# Epoch 146/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.6495 - accuracy: 0.8023 - top-5-accuracy: 0.9706 - val_loss: 1.9518 - val_accuracy: 0.5420 - val_top-5-accuracy: 0.8068
# Epoch 147/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6497 - accuracy: 0.8040 - top-5-accuracy: 0.9698 - val_loss: 1.9844 - val_accuracy: 0.5432 - val_top-5-accuracy: 0.8076
# Epoch 148/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6462 - accuracy: 0.8061 - top-5-accuracy: 0.9710 - val_loss: 1.9583 - val_accuracy: 0.5420 - val_top-5-accuracy: 0.8156
# Epoch 149/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6398 - accuracy: 0.8070 - top-5-accuracy: 0.9720 - val_loss: 1.9544 - val_accuracy: 0.5472 - val_top-5-accuracy: 0.8148
# Epoch 150/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6581 - accuracy: 0.8014 - top-5-accuracy: 0.9701 - val_loss: 2.0054 - val_accuracy: 0.5370 - val_top-5-accuracy: 0.8140
# Epoch 151/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6572 - accuracy: 0.8013 - top-5-accuracy: 0.9699 - val_loss: 1.9640 - val_accuracy: 0.5420 - val_top-5-accuracy: 0.8098
# Epoch 152/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6477 - accuracy: 0.8062 - top-5-accuracy: 0.9714 - val_loss: 1.9563 - val_accuracy: 0.5382 - val_top-5-accuracy: 0.8104
# Epoch 153/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6421 - accuracy: 0.8055 - top-5-accuracy: 0.9717 - val_loss: 1.9964 - val_accuracy: 0.5392 - val_top-5-accuracy: 0.8084
# Epoch 154/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.6470 - accuracy: 0.8053 - top-5-accuracy: 0.9712 - val_loss: 1.9491 - val_accuracy: 0.5452 - val_top-5-accuracy: 0.8122
# Epoch 155/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.6387 - accuracy: 0.8075 - top-5-accuracy: 0.9718 - val_loss: 1.9691 - val_accuracy: 0.5428 - val_top-5-accuracy: 0.8106
# Epoch 156/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.6390 - accuracy: 0.8080 - top-5-accuracy: 0.9718 - val_loss: 1.9597 - val_accuracy: 0.5402 - val_top-5-accuracy: 0.8118
# Epoch 157/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6569 - accuracy: 0.8024 - top-5-accuracy: 0.9709 - val_loss: 1.9454 - val_accuracy: 0.5422 - val_top-5-accuracy: 0.8102
# Epoch 158/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6355 - accuracy: 0.8086 - top-5-accuracy: 0.9706 - val_loss: 1.9703 - val_accuracy: 0.5402 - val_top-5-accuracy: 0.8130
# Epoch 159/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6422 - accuracy: 0.8059 - top-5-accuracy: 0.9716 - val_loss: 1.9764 - val_accuracy: 0.5322 - val_top-5-accuracy: 0.8104
# Epoch 160/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6323 - accuracy: 0.8073 - top-5-accuracy: 0.9720 - val_loss: 1.9715 - val_accuracy: 0.5396 - val_top-5-accuracy: 0.8156
# Epoch 161/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6370 - accuracy: 0.8078 - top-5-accuracy: 0.9716 - val_loss: 1.9399 - val_accuracy: 0.5456 - val_top-5-accuracy: 0.8172
# Epoch 162/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.6324 - accuracy: 0.8083 - top-5-accuracy: 0.9702 - val_loss: 1.9728 - val_accuracy: 0.5406 - val_top-5-accuracy: 0.8154
# Epoch 163/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6436 - accuracy: 0.8051 - top-5-accuracy: 0.9718 - val_loss: 1.9431 - val_accuracy: 0.5450 - val_top-5-accuracy: 0.8136
# Epoch 164/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.6275 - accuracy: 0.8105 - top-5-accuracy: 0.9721 - val_loss: 1.9692 - val_accuracy: 0.5412 - val_top-5-accuracy: 0.8116
# Epoch 165/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6343 - accuracy: 0.8068 - top-5-accuracy: 0.9710 - val_loss: 1.9508 - val_accuracy: 0.5480 - val_top-5-accuracy: 0.8102
# Epoch 166/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6404 - accuracy: 0.8067 - top-5-accuracy: 0.9708 - val_loss: 1.9480 - val_accuracy: 0.5442 - val_top-5-accuracy: 0.8122
# Epoch 167/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6225 - accuracy: 0.8097 - top-5-accuracy: 0.9728 - val_loss: 1.9520 - val_accuracy: 0.5470 - val_top-5-accuracy: 0.8070
# Epoch 168/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.6233 - accuracy: 0.8104 - top-5-accuracy: 0.9728 - val_loss: 1.9707 - val_accuracy: 0.5426 - val_top-5-accuracy: 0.8132
# Epoch 169/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6280 - accuracy: 0.8098 - top-5-accuracy: 0.9727 - val_loss: 1.9612 - val_accuracy: 0.5482 - val_top-5-accuracy: 0.8128
# Epoch 170/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6336 - accuracy: 0.8077 - top-5-accuracy: 0.9718 - val_loss: 1.9701 - val_accuracy: 0.5372 - val_top-5-accuracy: 0.8126
# Epoch 171/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6267 - accuracy: 0.8105 - top-5-accuracy: 0.9726 - val_loss: 1.9708 - val_accuracy: 0.5440 - val_top-5-accuracy: 0.8152
# Epoch 172/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6016 - accuracy: 0.8159 - top-5-accuracy: 0.9755 - val_loss: 1.9713 - val_accuracy: 0.5402 - val_top-5-accuracy: 0.8148
# Epoch 173/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6206 - accuracy: 0.8119 - top-5-accuracy: 0.9729 - val_loss: 1.9607 - val_accuracy: 0.5484 - val_top-5-accuracy: 0.8152
# Epoch 174/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.6236 - accuracy: 0.8102 - top-5-accuracy: 0.9728 - val_loss: 1.9781 - val_accuracy: 0.5440 - val_top-5-accuracy: 0.8174
# Epoch 175/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6229 - accuracy: 0.8118 - top-5-accuracy: 0.9710 - val_loss: 1.9562 - val_accuracy: 0.5426 - val_top-5-accuracy: 0.8114
# Epoch 176/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6202 - accuracy: 0.8136 - top-5-accuracy: 0.9725 - val_loss: 1.9653 - val_accuracy: 0.5390 - val_top-5-accuracy: 0.8168
# Epoch 177/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.6221 - accuracy: 0.8118 - top-5-accuracy: 0.9719 - val_loss: 1.9983 - val_accuracy: 0.5400 - val_top-5-accuracy: 0.8082
# Epoch 178/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6200 - accuracy: 0.8128 - top-5-accuracy: 0.9715 - val_loss: 1.9925 - val_accuracy: 0.5354 - val_top-5-accuracy: 0.8150
# Epoch 179/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.6052 - accuracy: 0.8171 - top-5-accuracy: 0.9750 - val_loss: 1.9997 - val_accuracy: 0.5450 - val_top-5-accuracy: 0.8170
# Epoch 180/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6227 - accuracy: 0.8133 - top-5-accuracy: 0.9722 - val_loss: 1.9869 - val_accuracy: 0.5408 - val_top-5-accuracy: 0.8172
# Epoch 181/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.6106 - accuracy: 0.8144 - top-5-accuracy: 0.9741 - val_loss: 2.0111 - val_accuracy: 0.5440 - val_top-5-accuracy: 0.8138
# Epoch 182/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6137 - accuracy: 0.8131 - top-5-accuracy: 0.9729 - val_loss: 1.9873 - val_accuracy: 0.5472 - val_top-5-accuracy: 0.8168
# Epoch 183/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6124 - accuracy: 0.8148 - top-5-accuracy: 0.9724 - val_loss: 2.0031 - val_accuracy: 0.5426 - val_top-5-accuracy: 0.8104
# Epoch 184/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6184 - accuracy: 0.8126 - top-5-accuracy: 0.9732 - val_loss: 1.9559 - val_accuracy: 0.5504 - val_top-5-accuracy: 0.8144
# Epoch 185/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6102 - accuracy: 0.8138 - top-5-accuracy: 0.9743 - val_loss: 2.0770 - val_accuracy: 0.5290 - val_top-5-accuracy: 0.8038
# Epoch 186/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.6027 - accuracy: 0.8182 - top-5-accuracy: 0.9740 - val_loss: 1.9866 - val_accuracy: 0.5464 - val_top-5-accuracy: 0.8156
# Epoch 187/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6101 - accuracy: 0.8145 - top-5-accuracy: 0.9737 - val_loss: 1.9909 - val_accuracy: 0.5468 - val_top-5-accuracy: 0.8130
# Epoch 188/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6134 - accuracy: 0.8164 - top-5-accuracy: 0.9741 - val_loss: 1.9735 - val_accuracy: 0.5414 - val_top-5-accuracy: 0.8152
# Epoch 189/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.6075 - accuracy: 0.8150 - top-5-accuracy: 0.9738 - val_loss: 1.9475 - val_accuracy: 0.5518 - val_top-5-accuracy: 0.8100
# Epoch 190/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6076 - accuracy: 0.8161 - top-5-accuracy: 0.9744 - val_loss: 1.9595 - val_accuracy: 0.5424 - val_top-5-accuracy: 0.8154
# Epoch 191/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6050 - accuracy: 0.8188 - top-5-accuracy: 0.9749 - val_loss: 1.9904 - val_accuracy: 0.5430 - val_top-5-accuracy: 0.8192
# Epoch 192/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.5961 - accuracy: 0.8179 - top-5-accuracy: 0.9752 - val_loss: 1.9785 - val_accuracy: 0.5514 - val_top-5-accuracy: 0.8174
# Epoch 193/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.5999 - accuracy: 0.8169 - top-5-accuracy: 0.9752 - val_loss: 2.0324 - val_accuracy: 0.5366 - val_top-5-accuracy: 0.8124
# Epoch 194/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.6019 - accuracy: 0.8164 - top-5-accuracy: 0.9746 - val_loss: 1.9509 - val_accuracy: 0.5472 - val_top-5-accuracy: 0.8218
# Epoch 195/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.6112 - accuracy: 0.8168 - top-5-accuracy: 0.9729 - val_loss: 1.9704 - val_accuracy: 0.5434 - val_top-5-accuracy: 0.8178
# Epoch 196/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.6085 - accuracy: 0.8155 - top-5-accuracy: 0.9732 - val_loss: 2.0183 - val_accuracy: 0.5402 - val_top-5-accuracy: 0.8132
# Epoch 197/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6034 - accuracy: 0.8178 - top-5-accuracy: 0.9739 - val_loss: 1.9955 - val_accuracy: 0.5444 - val_top-5-accuracy: 0.8120
# Epoch 198/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.5968 - accuracy: 0.8201 - top-5-accuracy: 0.9746 - val_loss: 2.0012 - val_accuracy: 0.5426 - val_top-5-accuracy: 0.8136
# Epoch 199/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.6066 - accuracy: 0.8180 - top-5-accuracy: 0.9730 - val_loss: 1.9811 - val_accuracy: 0.5440 - val_top-5-accuracy: 0.8178
# Epoch 200/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.5962 - accuracy: 0.8204 - top-5-accuracy: 0.9741 - val_loss: 2.0505 - val_accuracy: 0.5432 - val_top-5-accuracy: 0.8148
# Epoch 201/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.5966 - accuracy: 0.8195 - top-5-accuracy: 0.9743 - val_loss: 1.9649 - val_accuracy: 0.5488 - val_top-5-accuracy: 0.8188
# Epoch 202/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.5936 - accuracy: 0.8194 - top-5-accuracy: 0.9752 - val_loss: 2.0027 - val_accuracy: 0.5418 - val_top-5-accuracy: 0.8164
# Epoch 203/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.5948 - accuracy: 0.8179 - top-5-accuracy: 0.9742 - val_loss: 2.0668 - val_accuracy: 0.5352 - val_top-5-accuracy: 0.8084
# Epoch 204/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6043 - accuracy: 0.8184 - top-5-accuracy: 0.9737 - val_loss: 2.0394 - val_accuracy: 0.5404 - val_top-5-accuracy: 0.8074
# Epoch 205/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.6000 - accuracy: 0.8169 - top-5-accuracy: 0.9742 - val_loss: 2.0129 - val_accuracy: 0.5376 - val_top-5-accuracy: 0.8102
# Epoch 206/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.6019 - accuracy: 0.8185 - top-5-accuracy: 0.9733 - val_loss: 2.0051 - val_accuracy: 0.5404 - val_top-5-accuracy: 0.8080
# Epoch 207/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.5976 - accuracy: 0.8197 - top-5-accuracy: 0.9738 - val_loss: 1.9902 - val_accuracy: 0.5386 - val_top-5-accuracy: 0.8132
# Epoch 208/800
# 176/176 [==============================] - 33s 185ms/step - loss: 0.5914 - accuracy: 0.8229 - top-5-accuracy: 0.9755 - val_loss: 1.9768 - val_accuracy: 0.5532 - val_top-5-accuracy: 0.8162
# Epoch 209/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.5886 - accuracy: 0.8214 - top-5-accuracy: 0.9751 - val_loss: 2.0052 - val_accuracy: 0.5432 - val_top-5-accuracy: 0.8098
# Epoch 210/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.5998 - accuracy: 0.8182 - top-5-accuracy: 0.9744 - val_loss: 1.9684 - val_accuracy: 0.5500 - val_top-5-accuracy: 0.8156
# Epoch 211/800
# 176/176 [==============================] - 33s 187ms/step - loss: 0.5931 - accuracy: 0.8204 - top-5-accuracy: 0.9754 - val_loss: 1.9690 - val_accuracy: 0.5564 - val_top-5-accuracy: 0.8160
# Epoch 212/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.5981 - accuracy: 0.8188 - top-5-accuracy: 0.9747 - val_loss: 2.0105 - val_accuracy: 0.5438 - val_top-5-accuracy: 0.8094
# Epoch 213/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.5796 - accuracy: 0.8244 - top-5-accuracy: 0.9760 - val_loss: 2.0106 - val_accuracy: 0.5434 - val_top-5-accuracy: 0.8102
# Epoch 214/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.5845 - accuracy: 0.8236 - top-5-accuracy: 0.9760 - val_loss: 2.0202 - val_accuracy: 0.5458 - val_top-5-accuracy: 0.8106
# Epoch 215/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.5857 - accuracy: 0.8222 - top-5-accuracy: 0.9758 - val_loss: 2.0625 - val_accuracy: 0.5366 - val_top-5-accuracy: 0.8044
# Epoch 216/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.5880 - accuracy: 0.8234 - top-5-accuracy: 0.9756 - val_loss: 2.0104 - val_accuracy: 0.5378 - val_top-5-accuracy: 0.8140
# Epoch 217/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.5956 - accuracy: 0.8199 - top-5-accuracy: 0.9739 - val_loss: 2.0096 - val_accuracy: 0.5470 - val_top-5-accuracy: 0.8048
# Epoch 218/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.5834 - accuracy: 0.8233 - top-5-accuracy: 0.9746 - val_loss: 1.9557 - val_accuracy: 0.5482 - val_top-5-accuracy: 0.8148
# Epoch 219/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.6034 - accuracy: 0.8171 - top-5-accuracy: 0.9736 - val_loss: 1.9955 - val_accuracy: 0.5410 - val_top-5-accuracy: 0.8072
# Epoch 220/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.5844 - accuracy: 0.8239 - top-5-accuracy: 0.9747 - val_loss: 2.0024 - val_accuracy: 0.5484 - val_top-5-accuracy: 0.8116
# Epoch 221/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.5762 - accuracy: 0.8258 - top-5-accuracy: 0.9758 - val_loss: 2.0338 - val_accuracy: 0.5444 - val_top-5-accuracy: 0.8100
# Epoch 222/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.5793 - accuracy: 0.8245 - top-5-accuracy: 0.9760 - val_loss: 1.9994 - val_accuracy: 0.5386 - val_top-5-accuracy: 0.8162
# Epoch 223/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.5890 - accuracy: 0.8198 - top-5-accuracy: 0.9757 - val_loss: 1.9714 - val_accuracy: 0.5478 - val_top-5-accuracy: 0.8156
# Epoch 224/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.5846 - accuracy: 0.8227 - top-5-accuracy: 0.9756 - val_loss: 1.9922 - val_accuracy: 0.5418 - val_top-5-accuracy: 0.8098
# Epoch 225/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.5862 - accuracy: 0.8235 - top-5-accuracy: 0.9754 - val_loss: 2.0065 - val_accuracy: 0.5412 - val_top-5-accuracy: 0.8044
# Epoch 226/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.5864 - accuracy: 0.8215 - top-5-accuracy: 0.9746 - val_loss: 2.0155 - val_accuracy: 0.5490 - val_top-5-accuracy: 0.8134
# Epoch 227/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.5896 - accuracy: 0.8220 - top-5-accuracy: 0.9743 - val_loss: 1.9887 - val_accuracy: 0.5384 - val_top-5-accuracy: 0.8108
# Epoch 228/800
# 176/176 [==============================] - 31s 177ms/step - loss: 0.5758 - accuracy: 0.8266 - top-5-accuracy: 0.9760 - val_loss: 2.0004 - val_accuracy: 0.5418 - val_top-5-accuracy: 0.8126
# Epoch 229/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.5903 - accuracy: 0.8215 - top-5-accuracy: 0.9754 - val_loss: 1.9469 - val_accuracy: 0.5372 - val_top-5-accuracy: 0.8168
# Epoch 230/800
# 176/176 [==============================] - 31s 177ms/step - loss: 0.5838 - accuracy: 0.8226 - top-5-accuracy: 0.9759 - val_loss: 2.0021 - val_accuracy: 0.5432 - val_top-5-accuracy: 0.8150
# Epoch 231/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.5722 - accuracy: 0.8265 - top-5-accuracy: 0.9759 - val_loss: 1.9670 - val_accuracy: 0.5500 - val_top-5-accuracy: 0.8180
# Epoch 232/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.5868 - accuracy: 0.8239 - top-5-accuracy: 0.9747 - val_loss: 1.9978 - val_accuracy: 0.5386 - val_top-5-accuracy: 0.8118
# Epoch 233/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.5723 - accuracy: 0.8284 - top-5-accuracy: 0.9772 - val_loss: 1.9980 - val_accuracy: 0.5520 - val_top-5-accuracy: 0.8160
# Epoch 234/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.5775 - accuracy: 0.8262 - top-5-accuracy: 0.9758 - val_loss: 1.9742 - val_accuracy: 0.5490 - val_top-5-accuracy: 0.8146
# Epoch 235/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.5800 - accuracy: 0.8250 - top-5-accuracy: 0.9765 - val_loss: 1.9934 - val_accuracy: 0.5436 - val_top-5-accuracy: 0.8094
# Epoch 236/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.5756 - accuracy: 0.8252 - top-5-accuracy: 0.9763 - val_loss: 1.9845 - val_accuracy: 0.5436 - val_top-5-accuracy: 0.8146
# Epoch 237/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.5783 - accuracy: 0.8249 - top-5-accuracy: 0.9750 - val_loss: 2.0184 - val_accuracy: 0.5444 - val_top-5-accuracy: 0.8112
# Epoch 238/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.5746 - accuracy: 0.8249 - top-5-accuracy: 0.9758 - val_loss: 2.0027 - val_accuracy: 0.5436 - val_top-5-accuracy: 0.8072
# Epoch 239/800
# ...
# Epoch 723/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4786 - accuracy: 0.8545 - top-5-accuracy: 0.9825 - val_loss: 1.9559 - val_accuracy: 0.5636 - val_top-5-accuracy: 0.8258
# Epoch 724/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4708 - accuracy: 0.8557 - top-5-accuracy: 0.9829 - val_loss: 1.9791 - val_accuracy: 0.5584 - val_top-5-accuracy: 0.8244
# Epoch 725/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4750 - accuracy: 0.8552 - top-5-accuracy: 0.9828 - val_loss: 1.9178 - val_accuracy: 0.5644 - val_top-5-accuracy: 0.8222
# Epoch 726/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4760 - accuracy: 0.8574 - top-5-accuracy: 0.9810 - val_loss: 1.9366 - val_accuracy: 0.5642 - val_top-5-accuracy: 0.8272
# Epoch 727/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4656 - accuracy: 0.8584 - top-5-accuracy: 0.9831 - val_loss: 1.9686 - val_accuracy: 0.5670 - val_top-5-accuracy: 0.8300
# Epoch 728/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4684 - accuracy: 0.8580 - top-5-accuracy: 0.9836 - val_loss: 1.9069 - val_accuracy: 0.5704 - val_top-5-accuracy: 0.8296
# Epoch 729/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4751 - accuracy: 0.8564 - top-5-accuracy: 0.9821 - val_loss: 2.0312 - val_accuracy: 0.5542 - val_top-5-accuracy: 0.8186
# Epoch 730/800
# 176/176 [==============================] - 33s 185ms/step - loss: 0.4789 - accuracy: 0.8569 - top-5-accuracy: 0.9817 - val_loss: 1.9550 - val_accuracy: 0.5666 - val_top-5-accuracy: 0.8274
# Epoch 731/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4737 - accuracy: 0.8577 - top-5-accuracy: 0.9826 - val_loss: 2.0759 - val_accuracy: 0.5616 - val_top-5-accuracy: 0.8236
# Epoch 732/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.4624 - accuracy: 0.8597 - top-5-accuracy: 0.9834 - val_loss: 1.9544 - val_accuracy: 0.5596 - val_top-5-accuracy: 0.8288
# Epoch 733/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.4679 - accuracy: 0.8584 - top-5-accuracy: 0.9823 - val_loss: 1.9929 - val_accuracy: 0.5708 - val_top-5-accuracy: 0.8264
# Epoch 734/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.4699 - accuracy: 0.8598 - top-5-accuracy: 0.9823 - val_loss: 1.9703 - val_accuracy: 0.5664 - val_top-5-accuracy: 0.8312
# Epoch 735/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.4736 - accuracy: 0.8577 - top-5-accuracy: 0.9828 - val_loss: 1.9845 - val_accuracy: 0.5666 - val_top-5-accuracy: 0.8280
# Epoch 736/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4727 - accuracy: 0.8566 - top-5-accuracy: 0.9822 - val_loss: 2.0063 - val_accuracy: 0.5696 - val_top-5-accuracy: 0.8310
# Epoch 737/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4649 - accuracy: 0.8619 - top-5-accuracy: 0.9825 - val_loss: 1.9969 - val_accuracy: 0.5660 - val_top-5-accuracy: 0.8278
# Epoch 738/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4738 - accuracy: 0.8576 - top-5-accuracy: 0.9820 - val_loss: 1.9889 - val_accuracy: 0.5618 - val_top-5-accuracy: 0.8262
# Epoch 739/800
# 176/176 [==============================] - 33s 185ms/step - loss: 0.4672 - accuracy: 0.8594 - top-5-accuracy: 0.9829 - val_loss: 1.9650 - val_accuracy: 0.5624 - val_top-5-accuracy: 0.8244
# Epoch 740/800
# 176/176 [==============================] - 33s 185ms/step - loss: 0.4745 - accuracy: 0.8557 - top-5-accuracy: 0.9829 - val_loss: 2.0073 - val_accuracy: 0.5616 - val_top-5-accuracy: 0.8214
# Epoch 741/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4773 - accuracy: 0.8554 - top-5-accuracy: 0.9827 - val_loss: 1.9223 - val_accuracy: 0.5618 - val_top-5-accuracy: 0.8164
# Epoch 742/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4832 - accuracy: 0.8528 - top-5-accuracy: 0.9822 - val_loss: 1.9592 - val_accuracy: 0.5680 - val_top-5-accuracy: 0.8274
# Epoch 743/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4710 - accuracy: 0.8579 - top-5-accuracy: 0.9820 - val_loss: 1.9385 - val_accuracy: 0.5728 - val_top-5-accuracy: 0.8274
# Epoch 744/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4701 - accuracy: 0.8580 - top-5-accuracy: 0.9832 - val_loss: 2.0029 - val_accuracy: 0.5712 - val_top-5-accuracy: 0.8226
# Epoch 745/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4713 - accuracy: 0.8576 - top-5-accuracy: 0.9827 - val_loss: 1.9798 - val_accuracy: 0.5720 - val_top-5-accuracy: 0.8274
# Epoch 746/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4711 - accuracy: 0.8586 - top-5-accuracy: 0.9819 - val_loss: 1.9475 - val_accuracy: 0.5690 - val_top-5-accuracy: 0.8196
# Epoch 747/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4747 - accuracy: 0.8584 - top-5-accuracy: 0.9816 - val_loss: 1.9633 - val_accuracy: 0.5720 - val_top-5-accuracy: 0.8268
# Epoch 748/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4725 - accuracy: 0.8579 - top-5-accuracy: 0.9825 - val_loss: 1.9198 - val_accuracy: 0.5748 - val_top-5-accuracy: 0.8270
# Epoch 749/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4561 - accuracy: 0.8630 - top-5-accuracy: 0.9832 - val_loss: 1.9918 - val_accuracy: 0.5682 - val_top-5-accuracy: 0.8260
# Epoch 750/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4683 - accuracy: 0.8598 - top-5-accuracy: 0.9818 - val_loss: 1.9575 - val_accuracy: 0.5712 - val_top-5-accuracy: 0.8228
# Epoch 751/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4614 - accuracy: 0.8594 - top-5-accuracy: 0.9839 - val_loss: 2.0163 - val_accuracy: 0.5704 - val_top-5-accuracy: 0.8180
# Epoch 752/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.4739 - accuracy: 0.8565 - top-5-accuracy: 0.9832 - val_loss: 1.9775 - val_accuracy: 0.5692 - val_top-5-accuracy: 0.8216
# Epoch 753/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.4775 - accuracy: 0.8565 - top-5-accuracy: 0.9819 - val_loss: 2.0233 - val_accuracy: 0.5674 - val_top-5-accuracy: 0.8220
# Epoch 754/800
# 176/176 [==============================] - 31s 179ms/step - loss: 0.4715 - accuracy: 0.8563 - top-5-accuracy: 0.9837 - val_loss: 1.9788 - val_accuracy: 0.5592 - val_top-5-accuracy: 0.8228
# Epoch 755/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.4774 - accuracy: 0.8570 - top-5-accuracy: 0.9820 - val_loss: 1.9694 - val_accuracy: 0.5646 - val_top-5-accuracy: 0.8280
# Epoch 756/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.4708 - accuracy: 0.8573 - top-5-accuracy: 0.9821 - val_loss: 1.9729 - val_accuracy: 0.5638 - val_top-5-accuracy: 0.8226
# Epoch 757/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.4749 - accuracy: 0.8559 - top-5-accuracy: 0.9820 - val_loss: 1.9794 - val_accuracy: 0.5660 - val_top-5-accuracy: 0.8180
# Epoch 758/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.4678 - accuracy: 0.8594 - top-5-accuracy: 0.9824 - val_loss: 1.9737 - val_accuracy: 0.5744 - val_top-5-accuracy: 0.8236
# Epoch 759/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.4697 - accuracy: 0.8589 - top-5-accuracy: 0.9820 - val_loss: 1.9890 - val_accuracy: 0.5704 - val_top-5-accuracy: 0.8254
# Epoch 760/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.4646 - accuracy: 0.8586 - top-5-accuracy: 0.9837 - val_loss: 1.9572 - val_accuracy: 0.5692 - val_top-5-accuracy: 0.8238
# Epoch 761/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4706 - accuracy: 0.8588 - top-5-accuracy: 0.9822 - val_loss: 1.9765 - val_accuracy: 0.5702 - val_top-5-accuracy: 0.8280
# Epoch 762/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4616 - accuracy: 0.8612 - top-5-accuracy: 0.9833 - val_loss: 1.9124 - val_accuracy: 0.5756 - val_top-5-accuracy: 0.8292
# Epoch 763/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4668 - accuracy: 0.8588 - top-5-accuracy: 0.9830 - val_loss: 1.9946 - val_accuracy: 0.5650 - val_top-5-accuracy: 0.8212
# Epoch 764/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4851 - accuracy: 0.8567 - top-5-accuracy: 0.9810 - val_loss: 1.9932 - val_accuracy: 0.5616 - val_top-5-accuracy: 0.8240
# Epoch 765/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4560 - accuracy: 0.8618 - top-5-accuracy: 0.9837 - val_loss: 1.9358 - val_accuracy: 0.5664 - val_top-5-accuracy: 0.8256
# Epoch 766/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4837 - accuracy: 0.8528 - top-5-accuracy: 0.9821 - val_loss: 1.9240 - val_accuracy: 0.5642 - val_top-5-accuracy: 0.8214
# Epoch 767/800
# 176/176 [==============================] - 33s 185ms/step - loss: 0.4656 - accuracy: 0.8597 - top-5-accuracy: 0.9836 - val_loss: 1.9402 - val_accuracy: 0.5626 - val_top-5-accuracy: 0.8268
# Epoch 768/800
# 176/176 [==============================] - 32s 185ms/step - loss: 0.4794 - accuracy: 0.8568 - top-5-accuracy: 0.9813 - val_loss: 1.9112 - val_accuracy: 0.5638 - val_top-5-accuracy: 0.8274
# Epoch 769/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4652 - accuracy: 0.8608 - top-5-accuracy: 0.9828 - val_loss: 1.9472 - val_accuracy: 0.5722 - val_top-5-accuracy: 0.8302
# Epoch 770/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4704 - accuracy: 0.8580 - top-5-accuracy: 0.9831 - val_loss: 1.9726 - val_accuracy: 0.5688 - val_top-5-accuracy: 0.8264
# Epoch 771/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4704 - accuracy: 0.8585 - top-5-accuracy: 0.9828 - val_loss: 2.0291 - val_accuracy: 0.5732 - val_top-5-accuracy: 0.8240
# Epoch 772/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4628 - accuracy: 0.8612 - top-5-accuracy: 0.9824 - val_loss: 1.9098 - val_accuracy: 0.5726 - val_top-5-accuracy: 0.8278
# Epoch 773/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4732 - accuracy: 0.8578 - top-5-accuracy: 0.9820 - val_loss: 1.9290 - val_accuracy: 0.5656 - val_top-5-accuracy: 0.8204
# Epoch 774/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4758 - accuracy: 0.8577 - top-5-accuracy: 0.9828 - val_loss: 1.9880 - val_accuracy: 0.5682 - val_top-5-accuracy: 0.8300
# Epoch 775/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4668 - accuracy: 0.8610 - top-5-accuracy: 0.9827 - val_loss: 1.9934 - val_accuracy: 0.5694 - val_top-5-accuracy: 0.8246
# Epoch 776/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4659 - accuracy: 0.8606 - top-5-accuracy: 0.9826 - val_loss: 2.0329 - val_accuracy: 0.5650 - val_top-5-accuracy: 0.8254
# Epoch 777/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.4636 - accuracy: 0.8610 - top-5-accuracy: 0.9832 - val_loss: 1.9710 - val_accuracy: 0.5642 - val_top-5-accuracy: 0.8190
# Epoch 778/800
# 176/176 [==============================] - 32s 180ms/step - loss: 0.4707 - accuracy: 0.8570 - top-5-accuracy: 0.9829 - val_loss: 1.9632 - val_accuracy: 0.5714 - val_top-5-accuracy: 0.8236
# Epoch 779/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.4616 - accuracy: 0.8602 - top-5-accuracy: 0.9834 - val_loss: 1.9710 - val_accuracy: 0.5712 - val_top-5-accuracy: 0.8228
# Epoch 780/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.4700 - accuracy: 0.8594 - top-5-accuracy: 0.9830 - val_loss: 2.0309 - val_accuracy: 0.5704 - val_top-5-accuracy: 0.8240
# Epoch 781/800
# 176/176 [==============================] - 32s 181ms/step - loss: 0.4597 - accuracy: 0.8609 - top-5-accuracy: 0.9836 - val_loss: 1.9269 - val_accuracy: 0.5772 - val_top-5-accuracy: 0.8292
# Epoch 782/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4731 - accuracy: 0.8585 - top-5-accuracy: 0.9823 - val_loss: 1.9592 - val_accuracy: 0.5728 - val_top-5-accuracy: 0.8290
# Epoch 783/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4680 - accuracy: 0.8589 - top-5-accuracy: 0.9818 - val_loss: 1.9755 - val_accuracy: 0.5678 - val_top-5-accuracy: 0.8294
# Epoch 784/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4626 - accuracy: 0.8612 - top-5-accuracy: 0.9827 - val_loss: 1.9631 - val_accuracy: 0.5682 - val_top-5-accuracy: 0.8270
# Epoch 785/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4628 - accuracy: 0.8605 - top-5-accuracy: 0.9833 - val_loss: 1.9708 - val_accuracy: 0.5680 - val_top-5-accuracy: 0.8242
# Epoch 786/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4581 - accuracy: 0.8622 - top-5-accuracy: 0.9835 - val_loss: 1.9493 - val_accuracy: 0.5610 - val_top-5-accuracy: 0.8254
# Epoch 787/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4784 - accuracy: 0.8561 - top-5-accuracy: 0.9824 - val_loss: 1.9466 - val_accuracy: 0.5688 - val_top-5-accuracy: 0.8356
# Epoch 788/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4635 - accuracy: 0.8610 - top-5-accuracy: 0.9828 - val_loss: 1.9750 - val_accuracy: 0.5642 - val_top-5-accuracy: 0.8206
# Epoch 789/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4644 - accuracy: 0.8585 - top-5-accuracy: 0.9831 - val_loss: 1.9448 - val_accuracy: 0.5636 - val_top-5-accuracy: 0.8320
# Epoch 790/800
# 176/176 [==============================] - 32s 184ms/step - loss: 0.4829 - accuracy: 0.8547 - top-5-accuracy: 0.9824 - val_loss: 1.9254 - val_accuracy: 0.5702 - val_top-5-accuracy: 0.8308
# Epoch 791/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4652 - accuracy: 0.8611 - top-5-accuracy: 0.9820 - val_loss: 1.9146 - val_accuracy: 0.5676 - val_top-5-accuracy: 0.8272
# Epoch 792/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4744 - accuracy: 0.8584 - top-5-accuracy: 0.9822 - val_loss: 1.9301 - val_accuracy: 0.5680 - val_top-5-accuracy: 0.8314
# Epoch 793/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4864 - accuracy: 0.8526 - top-5-accuracy: 0.9812 - val_loss: 1.9770 - val_accuracy: 0.5630 - val_top-5-accuracy: 0.8212
# Epoch 794/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4778 - accuracy: 0.8546 - top-5-accuracy: 0.9822 - val_loss: 1.9685 - val_accuracy: 0.5714 - val_top-5-accuracy: 0.8314
# Epoch 795/800
# 176/176 [==============================] - 32s 183ms/step - loss: 0.4655 - accuracy: 0.8595 - top-5-accuracy: 0.9824 - val_loss: 1.9807 - val_accuracy: 0.5698 - val_top-5-accuracy: 0.8296
# Epoch 796/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4596 - accuracy: 0.8607 - top-5-accuracy: 0.9835 - val_loss: 1.9465 - val_accuracy: 0.5648 - val_top-5-accuracy: 0.8272
# Epoch 797/800
# 176/176 [==============================] - 32s 182ms/step - loss: 0.4696 - accuracy: 0.8593 - top-5-accuracy: 0.9824 - val_loss: 1.9878 - val_accuracy: 0.5670 - val_top-5-accuracy: 0.8278
# Epoch 798/800
# 176/176 [==============================] - 32s 179ms/step - loss: 0.4661 - accuracy: 0.8600 - top-5-accuracy: 0.9827 - val_loss: 1.9151 - val_accuracy: 0.5636 - val_top-5-accuracy: 0.8282
# Epoch 799/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.4741 - accuracy: 0.8581 - top-5-accuracy: 0.9824 - val_loss: 1.9582 - val_accuracy: 0.5688 - val_top-5-accuracy: 0.8300
# Epoch 800/800
# 176/176 [==============================] - 31s 178ms/step - loss: 0.4574 - accuracy: 0.8640 - top-5-accuracy: 0.9833 - val_loss: 1.9842 - val_accuracy: 0.5666 - val_top-5-accuracy: 0.8286
# 313/313 [==============================] - 5s 16ms/step - loss: 1.9154 - accuracy: 0.5716 - top-5-accuracy: 0.8285
# Test accuracy: 57.16%
# Test top 5 accuracy: 82.85%

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'top-5-accuracy', 'val_loss', 'val_accuracy', 'val_top-5-accuracy'])

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val loss'])
plt.subplot(1, 2, 2)
plt.plot(history.history['top-5-accuracy'])
plt.plot(history.history['val_top-5-accuracy'])
plt.legend(['accuracy', 'val top-5-accuracy'])
plt.show()

# %% [markdown]
# After 100 epochs, the ViT model achieves around 55% accuracy and
# 82% top-5 accuracy on the test data. These are not competitive results on the CIFAR-100 dataset,
# as a ResNet50V2 trained from scratch on the same data can achieve 67% accuracy.
#
# Note that the state of the art results reported in the
# [paper](https://arxiv.org/abs/2010.11929) are achieved by pre-training the ViT model using
# the JFT-300M dataset, then fine-tuning it on the target dataset. To improve the model quality
# without pre-training, you can try to train the model for more epochs, use a larger number of
# Transformer layers, resize the input images, change the patch size, or increase the projection dimensions.
# Besides, as mentioned in the paper, the quality of the model is affected not only by architecture choices,
# but also by parameters such as the learning rate schedule, optimizer, weight decay, etc.
# In practice, it's recommended to fine-tune a ViT model
# that was pre-trained using a large, high-resolution dataset.
