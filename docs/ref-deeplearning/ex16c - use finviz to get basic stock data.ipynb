# %% [markdown]
# ## What is Finviz?
#
# [FinViz](https://finviz.com/?a=128493348) aims to make market information accessible and provides a lot of data in visual snapshots, allowing traders and investors to quickly find the stock, future or forex pair they are looking for. The site provides advanced screeners, market maps, analysis, comparative tools, and charts.

# %% [markdown]
# ## Important Information
#
# Any quotes data displayed on finviz.com is delayed by 15 minutes for NASDAQ, and 20 minutes for NYSE and AMEX. This API should NOT be used for live trading, it's main purpose is financial analysis, research, and data scraping.

# %% [markdown]
# ## Install

# %%
# !pip install -U git+https://github.com/mariostoev/finviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/mariostoev/finviz
#   Cloning https://github.com/mariostoev/finviz to /tmp/pip-req-build-ux5w1o3r
#   Running command git clone --filter=blob:none --quiet https://github.com/mariostoev/finviz /tmp/pip-req-build-ux5w1o3r
#   Resolved https://github.com/mariostoev/finviz to commit 83de213e996a6672a0b395a6cf55e18d3728a675
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm<5.0.0,>=4.61.1 in /usr/local/lib/python3.8/dist-packages (from finviz==1.4.4) (4.64.1)
# Collecting urllib3<2.0.0,>=1.26.5
#   Using cached urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: lxml<5.0.0,>=4.6.3 in /usr/local/lib/python3.8/dist-packages (from finviz==1.4.4) (4.9.2)
# Collecting cssselect<2.0.0,>=1.1.0
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting beautifulsoup4<5.0.0,>=4.9.3
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 4.8 MB/s eta 0:00:00
# Collecting user_agent<0.2.0,>=0.1.9
#   Downloading user_agent-0.1.10.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tenacity<8.0.0,>=7.0.0
#   Downloading tenacity-7.0.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.7.4 in /usr/local/lib/python3.8/dist-packages (from finviz==1.4.4) (3.8.3)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in /usr/local/lib/python3.8/dist-packages (from finviz==1.4.4) (2.25.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0.0,>=3.7.4->finviz==1.4.4) (22.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0.0,>=3.7.4->finviz==1.4.4) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0.0,>=3.7.4->finviz==1.4.4) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0.0,>=3.7.4->finviz==1.4.4) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0.0,>=3.7.4->finviz==1.4.4) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0.0,>=3.7.4->finviz==1.4.4) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4.0.0,>=3.7.4->finviz==1.4.4) (2.1.1)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.25.1->finviz==1.4.4) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.25.1->finviz==1.4.4) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.25.1->finviz==1.4.4) (2022.12.7)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from tenacity<8.0.0,>=7.0.0->finviz==1.4.4) (1.15.0)
# Building wheels for collected packages: finviz, user_agent
#   Building wheel for finviz (pyproject.toml) ... done
#   Created wheel for finviz: filename=finviz-1.4.4-py3-none-any.whl size=18335 sha256=4127b8549717674a3265e3cf7df459a6ea274fb1c7fb0e13dfe93cf6851f0f37
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9yo0o7wv/wheels/16/39/9f/58c05155af5acf36c63505c9c7ef9baa535b12916567e5e56d
#   Building wheel for user_agent (setup.py) ... done
#   Created wheel for user_agent: filename=user_agent-0.1.10-py3-none-any.whl size=18982 sha256=946278a115205b537982e932290b7446263fdf550bd38ac495224da0c81462b4
#   Stored in directory: /root/.cache/pip/wheels/31/2b/5b/d3d4cef9b2818758251d0d556cf7a01550fa05df2e4bcd012e
# Successfully built finviz user_agent
# Installing collected packages: user_agent, urllib3, tenacity, soupsieve, cssselect, beautifulsoup4, finviz
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.1.0
#     Uninstalling tenacity-8.1.0:
#       Successfully uninstalled tenacity-8.1.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.2 cssselect-1.2.0 finviz-1.4.4 soupsieve-2.3.2.post1 tenacity-7.0.0 urllib3-1.26.14 user_agent-0.1.10

# %%
from finviz.screener import Screener

# %%
filters = ['exch_nasd', 'idx_sp500']  # Shows companies in NASDAQ which are in the S&P500
stock_list = Screener(filters=filters, table='Performance', order='price')  # Get the performance table and sort it by price ascending
# Out:
# 100%|██████████| 8/8 [00:02<00:00,  3.24it/s]

# %%
# Export the screener results to .csv
stock_list.to_csv("stock.csv")

# %%
# Create a SQLite database
stock_list.to_sqlite("stock.sqlite3")

# %%
for stock in stock_list[9:19]:  # Loop through 10th - 20th stocks
    print(stock['Ticker'], stock['Price']) # Print symbol and price
# Out:
# NWS 21.40
# PARA 24.60
# INTC 30.32
# BKR 31.37
# CSX 32.27
# FOX 32.30
# FOXA 34.60
# KDP 35.15
# WBA 37.09
# FITB 37.64

# %%
# Add more filters
stock_list.add(filters=['fa_div_high'])  # Show stocks with high dividend yield
# or just stock_list(filters=['fa_div_high'])
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  4.76it/s]

# %%
# Print the table into the console
print(stock_list)
# Out:
# No. | Ticker | Perf Week | Perf Month | Perf Quart | Perf Half | Perf Year | Perf YTD | Volatility W | Volatility M | Recom | Avg Volume | Rel Volume | Price | Change | Volume
# --- | ------ | --------- | ---------- | ---------- | --------- | --------- | -------- | ------------ | ------------ | ----- | ---------- | ---------- | ----- | ------ | ---------
# 1   | NWL    | 1.77%     | 13.36%     | 25.35%     | -17.63%   | -31.40%   | 23.24%   | 2.87%        | 2.93%        | 2.40  | 4.22M      | 0.76       | 16.12 | -2.13% | 3,214,058
# 2   | WBA    | -0.22%    | -1.07%     | 3.57%      | -4.85%    | -26.42%   | -0.72%   | 2.44%        | 2.39%        | 3.00  | 6.49M      | 0.91       | 37.09 | -1.64% | 5,933,454
