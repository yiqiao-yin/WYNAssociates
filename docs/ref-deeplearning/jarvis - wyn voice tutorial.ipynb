# %% [markdown]
# ## Install

# %%
! pip install wyn-voice==0.2.3

# %% [markdown]
# ## Run Chat Env

# %%
from wyn_voice.chat import ChatBot, AudioProcessor, ChatEnvironment

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
# Create instances of ChatBot and AudioProcessor
chatbot = ChatBot(
    api_key=OPENAI_API_KEY,
    protocol="You are a live translator."
    "When you hear Chinese, speak English."
    "When you hear English, speak Chinese.")
audio_processor = AudioProcessor(chatbot)

# Create an instance of ChatEnvironment
chat_env = ChatEnvironment(chatbot, audio_processor)

# Start the chat loop
chat_env.start_chat(exit_command="Exit the program")
# Out:
# ------------------- START -------------------
# If you want to quit the program, just say 'Exit the program'.
# Recording audio...
# Audio saved!
# Transcribing audio from: audio.wav
# 🤔 User: 我刚刚下飞机。
# 🤖 ChatBot: I just got off the plane.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ⏳ Audio lag: 2.392
# ------------------- round 0 finished -------------------
# ------------------- next round: -------------------
# ------------------- START -------------------
# If you want to quit the program, just say 'Exit the program'.
# Recording audio...
# Audio saved!
# Transcribing audio from: audio.wav
# 🤔 User: Okay, are you hungry? How's the food?
# 🤖 ChatBot: 好的，你饿了吗？食物怎么样？
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ⏳ Audio lag: 3.664
# ------------------- round 1 finished -------------------
# ------------------- next round: -------------------
# ------------------- START -------------------
# If you want to quit the program, just say 'Exit the program'.
# Recording audio...
# Audio saved!
# Transcribing audio from: audio.wav
# 🤔 User: We had a bit meal on the flight.
# 🤖 ChatBot: 我们在飞机上吃了一顿大餐。
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ⏳ Audio lag: 3.448
# ------------------- round 2 finished -------------------
# ------------------- next round: -------------------
# ------------------- START -------------------
# If you want to quit the program, just say 'Exit the program'.
# Recording audio...
# Audio saved!
# Transcribing audio from: audio.wav
# 🤔 User: That's very nice. Exit the program.
# 🤖 ChatBot: 这很好。退出程序。
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ⏳ Audio lag: 2.6559999999999997
# ------------------- round 3 finished -------------------
# ------------------- next round: -------------------
