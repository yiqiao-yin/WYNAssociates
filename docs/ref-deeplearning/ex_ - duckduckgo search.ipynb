# %%
import requests
from typing import Union, Dict, Any

def search_duckduckgo(query: str) -> Union[Dict[str, Any], str]:
    """
    Search DuckDuckGo for the given query and return the results.

    :param query: The search query string.
    :return: The response data in JSON format if possible, otherwise raw text.
    :raises requests.exceptions.RequestException: For network-related errors.
    """
    try:
        url = "https://api.duckduckgo.com/"
        params = {
            "q": query,
            "format": "json",
            "t": "python_function"
        }
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors

        try:
            return response.json()  # Attempt to return JSON data
        except ValueError:
            return response.text  # Return raw text if JSON decoding fails

    except requests.exceptions.RequestException as e:
        raise requests.exceptions.RequestException(f"An error occurred: {e}")

# %%
query = "barack obama"
try:
    result = search_duckduckgo(query)
    print(result)
except Exception as e:
    print(f"Failed to fetch data: {e}")
# Out:
# {'Abstract': '', 'AbstractSource': 'Wikipedia', 'AbstractText': '', 'AbstractURL': 'https://en.wikipedia.org/wiki/Barack_Obama_(disambiguation)', 'Answer': '', 'AnswerType': '', 'Definition': '', 'DefinitionSource': '', 'DefinitionURL': '', 'Entity': '', 'Heading': 'Barack Obama', 'Image': '', 'ImageHeight': 0, 'ImageIsLogo': 0, 'ImageWidth': 0, 'Infobox': '', 'Redirect': '', 'RelatedTopics': [{'FirstURL': 'https://duckduckgo.com/Barack_Obama', 'Icon': {'Height': '', 'URL': '/i/1174bdd9.jpg', 'Width': ''}, 'Result': '<a href="https://duckduckgo.com/Barack_Obama">Barack Obama</a> An American politician who served as the 44th president of the United States from 2009 to 2017.', 'Text': 'Barack Obama An American politician who served as the 44th president of the United States from 2009 to 2017.'}, {'FirstURL': 'https://duckduckgo.com/Presidency_of_Barack_Obama', 'Icon': {'Height': '', 'URL': '/i/1174bdd9.jpg', 'Width': ''}, 'Result': '<a href="https://duckduckgo.com/Presidency_of_Barack_Obama">Presidency of Barack Obama</a>Barack Obama\'s tenure as the 44th president of the United States began with his first...', 'Text': "Presidency of Barack Obama Barack Obama's tenure as the 44th president of the United States began with his first..."}, {'FirstURL': 'https://duckduckgo.com/Barack_Obama_Sr.', 'Icon': {'Height': '', 'URL': '', 'Width': ''}, 'Result': '<a href="https://duckduckgo.com/Barack_Obama_Sr.">Barack Obama Sr.</a>Barack Hussein Obama Sr. was a Kenyan senior governmental economist and the father of Barack...', 'Text': 'Barack Obama Sr. Barack Hussein Obama Sr. was a Kenyan senior governmental economist and the father of Barack...'}, {'FirstURL': 'https://duckduckgo.com/Barack_Obama_in_comics', 'Icon': {'Height': '', 'URL': '/i/c79bd90c.jpg', 'Width': ''}, 'Result': '<a href="https://duckduckgo.com/Barack_Obama_in_comics">Barack Obama in comics</a>Barack Obama has appeared as a character in comic books published by a number of publishing...', 'Text': 'Barack Obama in comics Barack Obama has appeared as a character in comic books published by a number of publishing...'}, {'FirstURL': 'https://duckduckgo.com/President_Barack_Obama_(painting)', 'Icon': {'Height': '', 'URL': '', 'Width': ''}, 'Result': '<a href="https://duckduckgo.com/President_Barack_Obama_(painting)">President Barack Obama (painting)</a>An oil-on-canvas portrait of Barack Obama, the 44th president of the United States, completed by...', 'Text': 'President Barack Obama (painting) An oil-on-canvas portrait of Barack Obama, the 44th president of the United States, completed by...'}, {'FirstURL': 'https://duckduckgo.com/Barack_Obama%3A_Der_schwarze_Kennedy', 'Icon': {'Height': '', 'URL': '', 'Width': ''}, 'Result': '<a href="https://duckduckgo.com/Barack_Obama%3A_Der_schwarze_Kennedy">Barack Obama: Der schwarze Kennedy</a> A best-selling German-language biography of President of the United States Barack Obama by...', 'Text': 'Barack Obama: Der schwarze Kennedy A best-selling German-language biography of President of the United States Barack Obama by...'}, {'FirstURL': 'https://duckduckgo.com/Barack_Obama_%22Joker%22_poster', 'Icon': {'Height': '', 'URL': '/i/180dbbc8.jpg', 'Width': ''}, 'Result': '<a href="https://duckduckgo.com/Barack_Obama_%22Joker%22_poster">Barack Obama "Joker" poster</a>A manipulated image of Barack Obama, then president of the United States, used by some critics of...', 'Text': 'Barack Obama "Joker" poster A manipulated image of Barack Obama, then president of the United States, used by some critics of...'}, {'FirstURL': 'https://duckduckgo.com/Barack_Obama_%22Hope%22_poster', 'Icon': {'Height': '', 'URL': '/i/e142d77b.jpg', 'Width': ''}, 'Result': '<a href="https://duckduckgo.com/Barack_Obama_%22Hope%22_poster">Barack Obama "Hope" poster</a>An image of US president Barack Obama designed by American artist Shepard Fairey.', 'Text': 'Barack Obama "Hope" poster An image of US president Barack Obama designed by American artist Shepard Fairey.'}, ...

# %%
import pprint

# %%
pprint.pprint(result)
# Out:
# {'Abstract': '',
#  'AbstractSource': 'Wikipedia',
#  'AbstractText': '',
#  'AbstractURL': 'https://en.wikipedia.org/wiki/Barack_Obama_(disambiguation)',
#  'Answer': '',
#  'AnswerType': '',
#  'Definition': '',
#  'DefinitionSource': '',
#  'DefinitionURL': '',
#  'Entity': '',
#  'Heading': 'Barack Obama',
#  'Image': '',
#  'ImageHeight': 0,
#  'ImageIsLogo': 0,
#  'ImageWidth': 0,
#  'Infobox': '',
#  'Redirect': '',
#  'RelatedTopics': [{'FirstURL': 'https://duckduckgo.com/Barack_Obama',
#                     'Icon': {'Height': '',
#                              'URL': '/i/1174bdd9.jpg',
#                              'Width': ''},
#                     'Result': '<a '
#                               'href="https://duckduckgo.com/Barack_Obama">Barack '
#                               'Obama</a> An American politician who served as '
#                               'the 44th president of the United States from '
#                               '2009 to 2017.',
#                     'Text': 'Barack Obama An American politician who served as '
#                             'the 44th president of the United States from 2009 '
#                             'to 2017.'},
#                    {'FirstURL': 'https://duckduckgo.com/Presidency_of_Barack_Obama',
#                     'Icon': {'Height': '',
#                              'URL': '/i/1174bdd9.jpg',
#                              'Width': ''},
#                     'Result': '<a '
#                               'href="https://duckduckgo.com/Presidency_of_Barack_Obama">Presidency '
#                               "of Barack Obama</a>Barack Obama's tenure as the "
#                               '44th president of the United States began with '
#                               'his first...',
#                     'Text': "Presidency of Barack Obama Barack Obama's tenure "
#                             'as the 44th president of the United States began '
#                             'with his first...'},
#                    {'FirstURL': 'https://duckduckgo.com/Barack_Obama_Sr.',
#                     'Icon': {'Height': '', 'URL': '', 'Width': ''},
#                     'Result': '<a '
#                               'href="https://duckduckgo.com/Barack_Obama_Sr.">Barack '
#                               'Obama Sr.</a>Barack Hussein Obama Sr. was a '
#                               'Kenyan senior governmental economist and the '
#                               'father of Barack...',
#                     'Text': 'Barack Obama Sr. Barack Hussein Obama Sr. was a '
#                             'Kenyan senior governmental economist and the '
#                             'father of Barack...'},
#                    {'FirstURL': 'https://duckduckgo.com/Barack_Obama_in_comics',
#                     'Icon': {'Height': '',
#                              'URL': '/i/c79bd90c.jpg',
#                              'Width': ''},
#                     'Result': '<a '
#                               'href="https://duckduckgo.com/Barack_Obama_in_comics">Barack '
#                               'Obama in comics</a>Barack Obama has appeared as '
#                               'a character in comic books published by a '
#                               'number of publishing...',
#                     'Text': 'Barack Obama in comics Barack Obama has appeared '
#                             'as a character in comic books published by a '
#                             'number of publishing...'},
#                    {'FirstURL': 'https://duckduckgo.com/President_Barack_Obama_(painting)',
#                     'Icon': {'Height': '', 'URL': '', 'Width': ''},
#                     'Result': '<a '
#                               'href="https://duckduckgo.com/President_Barack_Obama_(painting)">President '
#                               'Barack Obama (painting)</a>An oil-on-canvas '
#                               'portrait of Barack Obama, the 44th president of '
#                               'the United States, completed by...',
#                     'Text': 'President Barack Obama (painting) An '
#                             'oil-on-canvas portrait of Barack Obama, the 44th '
#                             'president of the United States, completed by...'},
#                    {'FirstURL': 'https://duckduckgo.com/Barack_Obama%3A_Der_schwarze_Kennedy',
#                     'Icon': {'Height': '', 'URL': '', 'Width': ''},
#                     'Result': '<a '
#                               'href="https://duckduckgo.com/Barack_Obama%3A_Der_schwarze_Kennedy">Barack '
#                               'Obama: Der schwarze Kennedy</a> A best-selling '
#                               'German-language biography of President of the '
#                               'United States Barack Obama by...',
#                     'Text': 'Barack Obama: Der schwarze Kennedy A best-selling '
#                             'German-language biography of President of the '
#                             'United States Barack Obama by...'},
#                    {'FirstURL': 'https://duckduckgo.com/Barack_Obama_%22Joker%22_poster',
#                     'Icon': {'Height': '',
#                              'URL': '/i/180dbbc8.jpg',
#                              'Width': ''},
#                     'Result': '<a '
#                               'href="https://duckduckgo.com/Barack_Obama_%22Joker%22_poster">Barack '
#                               'Obama "Joker" poster</a>A manipulated image of '
#                               'Barack Obama, then president of the United '
#                               'States, used by some critics of...',
#                     'Text': 'Barack Obama "Joker" poster A manipulated image '
#                             'of Barack Obama, then president of the United '
#                             'States, used by some critics of...'},
#                    {'FirstURL': 'https://duckduckgo.com/Barack_Obama_%22Hope%22_poster',
#                     'Icon': {'Height': '',
#                              'URL': '/i/e142d77b.jpg',
#                              'Width': ''},
#                     'Result': '<a '
#                               'href="https://duckduckgo.com/Barack_Obama_%22Hope%22_poster">Barack '
#                               'Obama "Hope" poster</a>An image of US president '
#                               'Barack Obama designed by American artist '
#                               'Shepard Fairey.',
#                     'Text': 'Barack Obama "Hope" poster An image of US '
#                             'president Barack Obama designed by American '
#                             'artist Shepard Fairey.'},
#                    {'Name': 'See also',
#                     'Topics': [{'FirstURL': 'https://duckduckgo.com/d/Barack',
#                                 'Icon': {'Height': '', 'URL': '', 'Width': ''},
#                                 'Result': '<a '
#                                           'href="https://duckduckgo.com/d/Barack">Barack</a> '
#                                           'See related meanings for the word '
#                                           "'Barack'.",
#                                 'Text': 'Barack See related meanings for the '
#                                         "word 'Barack'."},
#                                {'FirstURL': 'https://duckduckgo.com/d/Obama',
#                                 'Icon': {'Height': '', 'URL': '', 'Width': ''},
#                                 'Result': '<a '
#                                           'href="https://duckduckgo.com/d/Obama">Obama</a> '
#                                           'See related meanings for the word '
#                                           "'Obama'.",
#                                 'Text': 'Obama See related meanings for the '
#                                         "word 'Obama'."}]}],
#  'Results': [],
#  'Type': 'D',
#  'meta': {'attribution': None,
#           'blockgroup': None,
#           'created_date': None,
#           'description': 'Wikipedia',
#           'designer': None,
#           'dev_date': None,
#           'dev_milestone': 'live',
#           'developer': [{'name': 'DDG Team',
#                          'type': 'ddg',
#                          'url': 'http://www.duckduckhack.com'}],
#           'example_query': 'nikola tesla',
#           'id': 'wikipedia_fathead',
#           'is_stackexchange': None,
#           'js_callback_name': 'wikipedia',
#           'live_date': None,
#           'maintainer': {'github': 'duckduckgo'},
#           'name': 'Wikipedia',
#           'perl_module': 'DDG::Fathead::Wikipedia',
#           'producer': None,
#           'production_state': 'online',
#           'repo': 'fathead',
#           'signal_from': 'wikipedia_fathead',
#           'src_domain': 'en.wikipedia.org',
#           'src_id': 1,
#           'src_name': 'Wikipedia',
#           'src_options': {'directory': '',
#                           'is_fanon': 0,
#                           'is_mediawiki': 1,
#                           'is_wikipedia': 1,
#                           'language': 'en',
#                           'min_abstract_length': '20',
#                           'skip_abstract': 0,
#                           'skip_abstract_paren': 0,
#                           'skip_end': '0',
#                           'skip_icon': 0,
#                           'skip_image_name': 0,
#                           'skip_qr': '',
#                           'source_skip': '',
#                           'src_info': ''},
#           'src_url': None,
#           'status': 'live',
#           'tab': 'About',
#           'topic': ['productivity'],
#           'unsafe': 0}}
