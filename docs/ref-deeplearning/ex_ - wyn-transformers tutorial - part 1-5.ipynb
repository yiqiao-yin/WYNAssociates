# %%
! pip install wyn-transformers

# %%
import wyn_transformers
from wyn_transformers.transformers import *

# Hyperparameters
num_layers = 2
d_model = 64
dff = 128
num_heads = 4
input_vocab_size = 8500
maximum_position_encoding = 10000

# Instantiate the Transformer model
transformer = TransformerModel(num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding)

# Compile the model
transformer.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Generate random sample data
sample_data = np.random.randint(0, input_vocab_size, size=(64, 38))

# Fit the model on the random sample data
transformer.fit(sample_data, sample_data, epochs=5)
# Out:
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 499ms/step - accuracy: 0.0000e+00 - loss: 16.0640
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 490ms/step - accuracy: 0.0000e+00 - loss: 15.4381
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 479ms/step - accuracy: 5.4825e-04 - loss: 14.7394
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 497ms/step - accuracy: 0.0027 - loss: 14.1677
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step - accuracy: 0.0019 - loss: 13.9759

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Create a sample pandas DataFrame
data = {
    # input: X
    'question': [
        'What is the capital of France?',
        'How many continents are there?',
        'What is the largest mammal?',
        'Who wrote the play Hamlet?'
    ],
    # output: Y
    'answer': [
        'The capital of France is Paris.',
        'There are seven continents.',
        'The blue whale is the largest mammal.',
        'William Shakespeare wrote Hamlet.'
    ]
}

# Or read it from a directory
# data = pd.DataFrame("test.csv")

df = pd.DataFrame(data)
df
# Out:
#                          question                                 answer
# 0  What is the capital of France?        The capital of France is Paris.
# 1  How many continents are there?            There are seven continents.
# 2     What is the largest mammal?  The blue whale is the largest mammal.
# 3      Who wrote the play Hamlet?      William Shakespeare wrote Hamlet.

# %%
# Initialize the Tokenizer
tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")

# Fit the tokenizer on the questions and answers
tokenizer.fit_on_texts(df['question'].tolist() + df['answer'].tolist())

# Convert texts to sequences
question_sequences = tokenizer.texts_to_sequences(df['question'].tolist())
answer_sequences = tokenizer.texts_to_sequences(df['answer'].tolist())

# Pad sequences to ensure consistent input size for the model
max_length = 7  # Example fixed length; this can be adjusted as needed
question_padded = pad_sequences(question_sequences, maxlen=max_length, padding='post')
answer_padded = pad_sequences(answer_sequences, maxlen=max_length, padding='post')

# Combine questions and answers for training
sample_data = np.concatenate((question_padded, answer_padded), axis=0)

# Display the prepared sample data
print("Sample data (tokenized and padded):\n", sample_data)
# Out:
# Sample data (tokenized and padded):
#  [[ 4  3  2  5  6  7  0]
#  [15 16  8  9 10  0  0]
#  [ 4  3  2 11 12  0  0]
#  [17 13  2 18 14  0  0]
#  [ 2  5  6  7  3 19  0]
#  [10  9 20  8  0  0  0]
#  [ 2 21 22  3  2 11 12]
#  [23 24 13 14  0  0  0]]

# %%
import tensorflow as tf
from wyn_transformers.inference import *

# Testing the function to convert back to text
print("Original token:")
print(question_padded)
print("\nConverted back to text (questions):")
print(sequences_to_text(question_padded, tokenizer))

print("Original token:")
print(answer_padded)
print("\nConverted back to text (answers):")
print(sequences_to_text(answer_padded, tokenizer))
# Out:
# Original token:
# [[ 4  3  2  5  6  7  0]
#  [15 16  8  9 10  0  0]
#  [ 4  3  2 11 12  0  0]
#  [17 13  2 18 14  0  0]]
#
# Converted back to text (questions):
# ['what is the capital of france', 'how many continents are there', 'what is the largest mammal', 'who wrote the play hamlet']
# Original token:
# [[ 2  5  6  7  3 19  0]
#  [10  9 20  8  0  0  0]
#  [ 2 21 22  3  2 11 12]
#  [23 24 13 14  0  0  0]]
#
# Converted back to text (answers):
# ['the capital of france is paris', 'there are seven continents', 'the blue whale is the largest mammal', 'william shakespeare wrote hamlet']

# %%
# Hyperparameters
num_layers = 2
d_model = 64
dff = 128
num_heads = 2
input_vocab_size = 400
maximum_position_encoding = 10000

# Instantiate the Transformer model
transformer = TransformerModel(num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding)

# Compile the model
transformer.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Fit the model on the custom sample data
transformer.fit(sample_data, sample_data, epochs=400)
# Out:
# Epoch 1/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.0000e+00 - loss: 12.0465
# Epoch 2/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0000e+00 - loss: 9.5926
# Epoch 3/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1250 - loss: 9.0890
# Epoch 4/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1786 - loss: 8.1515
# Epoch 5/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2321 - loss: 7.7422
# Epoch 6/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2679 - loss: 7.4757
# Epoch 7/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2679 - loss: 6.7560
# Epoch 8/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3036 - loss: 6.6273
# Epoch 9/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2143 - loss: 6.5950
# Epoch 10/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.2143 - loss: 5.9479
# Epoch 11/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2500 - loss: 5.8522
# Epoch 12/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2321 - loss: 5.7459
# Epoch 13/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2321 - loss: 5.5190
# Epoch 14/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.1786 - loss: 5.6509
# Epoch 15/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2321 - loss: 5.5805
# Epoch 16/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1429 - loss: 5.1697
# Epoch 17/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1607 - loss: 5.0789
# Epoch 18/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1071 - loss: 4.9991
# Epoch 19/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.1071 - loss: 4.9220
# Epoch 20/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0536 - loss: 4.8185
# Epoch 21/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0536 - loss: 4.7240
# Epoch 22/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 4.4572
# Epoch 23/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0179 - loss: 4.6524
# Epoch 24/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0179 - loss: 4.3352
# Epoch 25/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0179 - loss: 4.3393
# Epoch 26/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0179 - loss: 4.3233
# Epoch 27/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0179 - loss: 4.5078
# Epoch 28/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.0357 - loss: 4.2369
# Epoch 29/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.0179 - loss: 4.2374
# Epoch 30/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0357 - loss: 4.1923
# Epoch 31/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0179 - loss: 4.2142
# Epoch 32/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.0357 - loss: 4.2117
# Epoch 33/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.0357 - loss: 4.2153
# Epoch 34/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0179 - loss: 4.1840
# Epoch 35/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0179 - loss: 4.2129
# Epoch 36/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0357 - loss: 4.1699
# Epoch 37/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0179 - loss: 4.1449
# Epoch 38/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0357 - loss: 4.1476
# Epoch 39/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.0536 - loss: 4.2778
# Epoch 40/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0357 - loss: 4.0647
# Epoch 41/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0357 - loss: 4.1087
# Epoch 42/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0357 - loss: 4.1804
# Epoch 43/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.0536 - loss: 4.3677
# Epoch 44/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.0536 - loss: 4.3402
# Epoch 45/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0714 - loss: 4.3517
# Epoch 46/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0536 - loss: 4.6733
# Epoch 47/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0357 - loss: 4.9001
# Epoch 48/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0536 - loss: 4.5932
# Epoch 49/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0357 - loss: 5.1424
# Epoch 50/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.0357 - loss: 4.6583
# Epoch 51/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0357 - loss: 4.6593
# Epoch 52/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0357 - loss: 4.3573
# Epoch 53/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0357 - loss: 4.4313
# Epoch 54/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 4.5856
# Epoch 55/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0357 - loss: 4.4030
# Epoch 56/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0357 - loss: 4.8370
# Epoch 57/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0357 - loss: 4.3399
# Epoch 58/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0357 - loss: 4.2836
# Epoch 59/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.0357 - loss: 4.3152
# Epoch 60/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0357 - loss: 4.2697
# Epoch 61/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0357 - loss: 4.3186
# Epoch 62/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.0357 - loss: 4.2612
# Epoch 63/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 4.4761
# Epoch 64/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0357 - loss: 4.2624
# Epoch 65/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0357 - loss: 4.2277
# Epoch 66/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0357 - loss: 4.2694
# Epoch 67/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0357 - loss: 4.2242
# Epoch 68/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0357 - loss: 4.4089
# Epoch 69/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.0357 - loss: 4.2940
# Epoch 70/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.0357 - loss: 4.1953
# Epoch 71/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0357 - loss: 4.1956
# Epoch 72/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0357 - loss: 4.1534
# Epoch 73/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.0357 - loss: 4.2140
# Epoch 74/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0357 - loss: 4.4657
# Epoch 75/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.0357 - loss: 4.2892
# Epoch 76/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.0357 - loss: 4.1696
# Epoch 77/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.0357 - loss: 4.5012
# Epoch 78/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 4.1913
# Epoch 79/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0357 - loss: 4.7973
# Epoch 80/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 5.2941
# Epoch 81/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.0357 - loss: 5.1034
# Epoch 82/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0536 - loss: 4.5515
# Epoch 83/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.0179 - loss: 4.6919
# Epoch 84/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0714 - loss: 4.2098
# Epoch 85/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0536 - loss: 4.9141
# Epoch 86/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0714 - loss: 4.4867
# Epoch 87/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.0714 - loss: 4.1603
# Epoch 88/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.0357 - loss: 4.3522
# Epoch 89/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.0536 - loss: 4.0664
# Epoch 90/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.0357 - loss: 4.1216
# Epoch 91/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.0536 - loss: 4.0144
# Epoch 92/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.0357 - loss: 4.3319
# Epoch 93/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.0357 - loss: 4.1420
# Epoch 94/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.0357 - loss: 4.2790
# Epoch 95/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0536 - loss: 4.2098
# Epoch 96/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.0357 - loss: 4.2577
# Epoch 97/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.0357 - loss: 4.2659
# Epoch 98/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.0357 - loss: 3.9221
# Epoch 99/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.0357 - loss: 3.9714
# Epoch 100/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.0357 - loss: 3.9263
# Epoch 101/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.0357 - loss: 3.8791
# Epoch 102/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.0357 - loss: 3.9055
# Epoch 103/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0357 - loss: 3.8690
# Epoch 104/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0357 - loss: 3.8133
# Epoch 105/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0357 - loss: 4.0959
# Epoch 106/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0357 - loss: 3.7795
# Epoch 107/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 3.5107
# Epoch 108/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0357 - loss: 3.8099
# Epoch 109/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0357 - loss: 3.7463
# Epoch 110/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 4.2248
# Epoch 111/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.0357 - loss: 3.4698
# Epoch 112/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0357 - loss: 3.6925
# Epoch 113/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0357 - loss: 3.6970
# Epoch 114/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0357 - loss: 3.7767
# Epoch 115/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.0357 - loss: 3.3593
# Epoch 116/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0357 - loss: 3.4085
# Epoch 117/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 3.3509
# Epoch 118/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0357 - loss: 3.3730
# Epoch 119/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0357 - loss: 3.3349
# Epoch 120/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.0357 - loss: 3.3093
# Epoch 121/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0357 - loss: 3.3414
# Epoch 122/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0357 - loss: 3.3112
# Epoch 123/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0357 - loss: 3.2763
# Epoch 124/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0357 - loss: 3.1884
# Epoch 125/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0357 - loss: 3.2890
# Epoch 126/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0357 - loss: 3.2402
# Epoch 127/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0357 - loss: 3.1926
# Epoch 128/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 3.2292
# Epoch 129/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 3.1357
# Epoch 130/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.0357 - loss: 3.1222
# Epoch 131/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0357 - loss: 3.1231
# Epoch 132/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.0357 - loss: 3.0915
# Epoch 133/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.0357 - loss: 3.0522
# Epoch 134/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0357 - loss: 3.1215
# Epoch 135/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0357 - loss: 3.1092
# Epoch 136/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.0357 - loss: 3.1060
# Epoch 137/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0357 - loss: 3.1706
# Epoch 138/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0357 - loss: 3.2242
# Epoch 139/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0357 - loss: 3.1796
# Epoch 140/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.0357 - loss: 3.1952
# Epoch 141/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0536 - loss: 3.2510
# Epoch 142/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0357 - loss: 3.2359
# Epoch 143/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0357 - loss: 3.2569
# Epoch 144/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.0536 - loss: 3.2625
# Epoch 145/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0536 - loss: 3.2724
# Epoch 146/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0536 - loss: 3.2122
# Epoch 147/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.0893 - loss: 3.2356
# Epoch 148/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0357 - loss: 3.4542
# Epoch 149/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0714 - loss: 3.2062
# Epoch 150/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.0893 - loss: 3.1853
# Epoch 151/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0357 - loss: 3.1732
# Epoch 152/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0357 - loss: 3.2268
# Epoch 153/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0536 - loss: 3.1244
# Epoch 154/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0714 - loss: 3.1111
# Epoch 155/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0893 - loss: 3.1272
# Epoch 156/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0714 - loss: 3.1540
# Epoch 157/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0357 - loss: 3.1854
# Epoch 158/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0536 - loss: 3.1036
# Epoch 159/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0714 - loss: 3.1082
# Epoch 160/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0536 - loss: 3.0717
# Epoch 161/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.0714 - loss: 3.0970
# Epoch 162/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0536 - loss: 3.0569
# Epoch 163/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0714 - loss: 3.0684
# Epoch 164/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.0714 - loss: 3.0480
# Epoch 165/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0714 - loss: 3.0379
# Epoch 166/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.0714 - loss: 3.0268
# Epoch 167/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.0893 - loss: 3.0238
# Epoch 168/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.0536 - loss: 2.9992
# Epoch 169/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.0893 - loss: 3.0403
# Epoch 170/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0714 - loss: 2.9964
# Epoch 171/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1071 - loss: 2.9915
# Epoch 172/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0893 - loss: 2.9208
# Epoch 173/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0714 - loss: 2.9720
# Epoch 174/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0714 - loss: 2.9166
# Epoch 175/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.0893 - loss: 2.9397
# Epoch 176/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0893 - loss: 2.9290
# Epoch 177/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.0714 - loss: 2.8391
# Epoch 178/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0893 - loss: 2.8881
# Epoch 179/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0536 - loss: 2.8053
# Epoch 180/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0893 - loss: 3.1128
# Epoch 181/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.0714 - loss: 2.7830
# Epoch 182/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1071 - loss: 2.8000
# Epoch 183/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.1071 - loss: 2.7298
# Epoch 184/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.0714 - loss: 2.7297
# Epoch 185/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0714 - loss: 2.7270
# Epoch 186/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0714 - loss: 2.7677
# Epoch 187/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0714 - loss: 2.6593
# Epoch 188/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0714 - loss: 2.6438
# Epoch 189/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0893 - loss: 2.5500
# Epoch 190/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0714 - loss: 2.5637
# Epoch 191/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0536 - loss: 2.5359
# Epoch 192/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0714 - loss: 2.5644
# Epoch 193/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0893 - loss: 2.5184
# Epoch 194/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0357 - loss: 2.4686
# Epoch 195/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0357 - loss: 2.5294
# Epoch 196/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0357 - loss: 2.4335
# Epoch 197/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0714 - loss: 2.4291
# Epoch 198/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.0714 - loss: 2.3851
# Epoch 199/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0357 - loss: 2.4077
# Epoch 200/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.0536 - loss: 2.3810
# Epoch 201/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0357 - loss: 2.4084
# Epoch 202/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0893 - loss: 2.3652
# Epoch 203/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0893 - loss: 2.3932
# Epoch 204/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0536 - loss: 2.3423
# Epoch 205/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0536 - loss: 2.3687
# Epoch 206/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0714 - loss: 2.6070
# Epoch 207/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0357 - loss: 2.3226
# Epoch 208/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0714 - loss: 2.3613
# Epoch 209/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0357 - loss: 2.3813
# Epoch 210/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0536 - loss: 2.2907
# Epoch 211/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0536 - loss: 2.3349
# Epoch 212/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.1071 - loss: 2.3140
# Epoch 213/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1071 - loss: 2.2760
# Epoch 214/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0893 - loss: 2.3659
# Epoch 215/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1607 - loss: 2.3119
# Epoch 216/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.1071 - loss: 2.2900
# Epoch 217/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0893 - loss: 2.2859
# Epoch 218/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.1071 - loss: 2.2657
# Epoch 219/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1071 - loss: 2.2499
# Epoch 220/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.1071 - loss: 2.2921
# Epoch 221/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1786 - loss: 2.2725
# Epoch 222/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.0893 - loss: 2.2014
# Epoch 223/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1429 - loss: 2.2640
# Epoch 224/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1071 - loss: 2.2062
# Epoch 225/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0893 - loss: 2.2360
# Epoch 226/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1071 - loss: 2.2389
# Epoch 227/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.0714 - loss: 2.2838
# Epoch 228/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1429 - loss: 2.2215
# Epoch 229/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.0714 - loss: 2.2107
# Epoch 230/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1429 - loss: 2.2524
# Epoch 231/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.0714 - loss: 2.2279
# Epoch 232/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0536 - loss: 2.1944
# Epoch 233/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.0714 - loss: 2.2645
# Epoch 234/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.1250 - loss: 2.2128
# Epoch 235/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1250 - loss: 2.1925
# Epoch 236/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1429 - loss: 2.2178
# Epoch 237/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1429 - loss: 2.1970
# Epoch 238/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1964 - loss: 2.1904
# Epoch 239/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1607 - loss: 2.2376
# Epoch 240/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1964 - loss: 2.2473
# Epoch 241/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1786 - loss: 2.1619
# Epoch 242/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0714 - loss: 2.1813
# Epoch 243/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.1429 - loss: 2.2162
# Epoch 244/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1964 - loss: 2.1588
# Epoch 245/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2143 - loss: 2.1625
# Epoch 246/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1786 - loss: 2.2032
# Epoch 247/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1964 - loss: 2.1955
# Epoch 248/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1964 - loss: 2.1424
# Epoch 249/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1964 - loss: 2.1730
# Epoch 250/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2143 - loss: 2.1421
# Epoch 251/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1607 - loss: 2.1702
# Epoch 252/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1429 - loss: 2.1747
# Epoch 253/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.1607 - loss: 2.1489
# Epoch 254/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.1607 - loss: 2.1747
# Epoch 255/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.2143 - loss: 2.1565
# Epoch 256/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2143 - loss: 2.1713
# Epoch 257/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.2143 - loss: 2.1233
# Epoch 258/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1964 - loss: 2.1306
# Epoch 259/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2679 - loss: 2.1447
# Epoch 260/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0893 - loss: 2.1433
# Epoch 261/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2321 - loss: 2.1451
# Epoch 262/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1786 - loss: 2.1337
# Epoch 263/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1964 - loss: 2.1653
# Epoch 264/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1786 - loss: 2.1319
# Epoch 265/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1429 - loss: 2.1378
# Epoch 266/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2857 - loss: 2.1506
# Epoch 267/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2143 - loss: 2.1326
# Epoch 268/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1429 - loss: 2.1593
# Epoch 269/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2679 - loss: 2.1353
# Epoch 270/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1964 - loss: 2.1789
# Epoch 271/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2500 - loss: 2.1464
# Epoch 272/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3214 - loss: 2.1262
# Epoch 273/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3393 - loss: 2.1353
# Epoch 274/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.2143 - loss: 2.1137
# Epoch 275/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.2500 - loss: 2.1209
# Epoch 276/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2143 - loss: 2.1257
# Epoch 277/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.2500 - loss: 2.1268
# Epoch 278/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3571 - loss: 2.1167
# Epoch 279/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.4107 - loss: 2.1205
# Epoch 280/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.2857 - loss: 2.1183
# Epoch 281/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3214 - loss: 2.1379
# Epoch 282/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4643 - loss: 2.1321
# Epoch 283/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4464 - loss: 2.4095
# Epoch 284/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4821 - loss: 2.1051
# Epoch 285/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3929 - loss: 2.1341
# Epoch 286/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3750 - loss: 2.0855
# Epoch 287/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.3929 - loss: 2.1094
# Epoch 288/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5357 - loss: 2.1036
# Epoch 289/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4107 - loss: 2.0886
# Epoch 290/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4286 - loss: 2.1031
# Epoch 291/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5357 - loss: 2.0983
# Epoch 292/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5893 - loss: 2.0583
# Epoch 293/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5714 - loss: 2.0548
# Epoch 294/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5893 - loss: 2.0171
# Epoch 295/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6429 - loss: 1.9390
# Epoch 296/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 1.9415
# Epoch 297/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7143 - loss: 1.8330
# Epoch 298/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8214 - loss: 1.7379
# Epoch 299/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7679 - loss: 1.8508
# Epoch 300/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8036 - loss: 1.7331
# Epoch 301/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8214 - loss: 1.4565
# Epoch 302/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8036 - loss: 1.3837
# Epoch 303/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8393 - loss: 1.6572
# Epoch 304/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7321 - loss: 1.9049
# Epoch 305/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7321 - loss: 1.8368
# Epoch 306/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7321 - loss: 1.9531
# Epoch 307/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7857 - loss: 2.0461
# Epoch 308/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7857 - loss: 1.8970
# Epoch 309/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8036 - loss: 1.4023
# Epoch 310/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7321 - loss: 2.0105
# Epoch 311/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7679 - loss: 1.5947
# Epoch 312/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8036 - loss: 1.7694
# Epoch 313/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7500 - loss: 1.9496
# Epoch 314/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8214 - loss: 1.9787
# Epoch 315/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5536 - loss: 3.1607
# Epoch 316/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3571 - loss: 3.5345
# Epoch 317/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2500 - loss: 3.9061
# Epoch 318/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.1964 - loss: 4.0242
# Epoch 319/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1429 - loss: 4.0663
# Epoch 320/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1250 - loss: 4.1037
# Epoch 321/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1429 - loss: 4.0613
# Epoch 322/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.0893 - loss: 4.2658
# Epoch 323/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1250 - loss: 3.8910
# Epoch 324/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.0893 - loss: 3.8391
# Epoch 325/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1964 - loss: 4.0338
# Epoch 326/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1429 - loss: 3.7520
# Epoch 327/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.1607 - loss: 3.8522
# Epoch 328/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1607 - loss: 3.6917
# Epoch 329/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1964 - loss: 3.7021
# Epoch 330/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2143 - loss: 3.6887
# Epoch 331/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1786 - loss: 3.6364
# Epoch 332/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.2143 - loss: 3.6536
# Epoch 333/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2143 - loss: 3.6133
# Epoch 334/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.2321 - loss: 3.6208
# Epoch 335/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.2143 - loss: 3.6091
# Epoch 336/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.2143 - loss: 3.5585
# Epoch 337/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.2679 - loss: 3.5326
# Epoch 338/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2321 - loss: 3.4897
# Epoch 339/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2857 - loss: 3.5543
# Epoch 340/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2679 - loss: 3.7440
# Epoch 341/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.2500 - loss: 3.4127
# Epoch 342/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2500 - loss: 3.3850
# Epoch 343/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2321 - loss: 3.4554
# Epoch 344/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2679 - loss: 3.7171
# Epoch 345/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2500 - loss: 3.4762
# Epoch 346/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1607 - loss: 3.4517
# Epoch 347/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.2321 - loss: 3.4364
# Epoch 348/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2143 - loss: 3.4227
# Epoch 349/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.1964 - loss: 3.3986
# Epoch 350/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2143 - loss: 3.3871
# Epoch 351/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 3.3766
# Epoch 352/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2500 - loss: 3.4227
# Epoch 353/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1964 - loss: 3.3528
# Epoch 354/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2143 - loss: 3.4146
# Epoch 355/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2321 - loss: 3.4114
# Epoch 356/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2321 - loss: 3.4126
# Epoch 357/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2500 - loss: 3.3296
# Epoch 358/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2500 - loss: 3.3860
# Epoch 359/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2679 - loss: 3.3397
# Epoch 360/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3393 - loss: 3.3704
# Epoch 361/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2500 - loss: 3.3275
# Epoch 362/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3036 - loss: 3.3875
# Epoch 363/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3036 - loss: 3.3084
# Epoch 364/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2321 - loss: 3.3115
# Epoch 365/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2857 - loss: 3.3144
# Epoch 366/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2857 - loss: 3.6138
# Epoch 367/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2679 - loss: 3.3496
# Epoch 368/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2679 - loss: 3.3058
# Epoch 369/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3036 - loss: 3.3084
# Epoch 370/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2500 - loss: 3.4231
# Epoch 371/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3036 - loss: 3.3099
# Epoch 372/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2857 - loss: 3.3069
# Epoch 373/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3036 - loss: 3.3096
# Epoch 374/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3750 - loss: 3.2959
# Epoch 375/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3036 - loss: 3.2999
# Epoch 376/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3393 - loss: 3.2885
# Epoch 377/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3393 - loss: 3.3240
# Epoch 378/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3750 - loss: 3.2843
# Epoch 379/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.3393 - loss: 3.2974
# Epoch 380/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2679 - loss: 3.2843
# Epoch 381/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.4107 - loss: 3.2333
# Epoch 382/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4107 - loss: 3.3112
# Epoch 383/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4821 - loss: 3.2539
# Epoch 384/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4821 - loss: 3.2069
# Epoch 385/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 3.2197
# Epoch 386/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5179 - loss: 3.1766
# Epoch 387/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6250 - loss: 2.8962
# Epoch 388/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5714 - loss: 3.1698
# Epoch 389/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5179 - loss: 3.0897
# Epoch 390/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6250 - loss: 3.0935
# Epoch 391/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6071 - loss: 3.0630
# Epoch 392/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6429 - loss: 3.0364
# Epoch 393/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.6250 - loss: 3.0154
# Epoch 394/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 2.9342
# Epoch 395/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7321 - loss: 2.6548
# Epoch 396/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6429 - loss: 2.8777
# Epoch 397/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7321 - loss: 2.6731
# Epoch 398/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7857 - loss: 1.6903
# Epoch 399/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7679 - loss: 1.6762
# Epoch 400/400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7679 - loss: 1.9684

# %%
# Test the function with the example input
input_text = "Who wrote Hamlet?"
predicted_response = predict_text(input_text, transformer, tokenizer, max_length=20)
print("Predicted Response:", predicted_response)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted Response: shakespeare wrote hamlet

# %%
from wyn_transformers.push_to_hub import *

# %%
from google.colab import userdata

# %%
# Example usage:
huggingface_token = userdata.get('HF_TOKEN')
account_name = "eagle0504"
model_name = "pretrained_transformer_model_v1"

# Call the function to push the model
# result = push_model_to_huggingface(huggingface_token, account_name, transformer, model_name)
result = push_model_to_huggingface(huggingface_token, account_name, transformer, model_name, tokenizer)
print(result)
# Out:
# tmp_model.keras:   0%|          | 0.00/1.53M [00:00<?, ?B/s]
# vocab.pkl:   0%|          | 0.00/258 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py:3664: UserWarning: Warnings while validating metadata in README.md:
# - empty or missing yaml metadata in repo card
#   warnings.warn(f"Warnings while validating metadata in README.md:\n{message}")
# Model, config, tokenizer, and model card pushed successfully to Hugging Face Hub with YAML metadata.
# Please go to this URL: https://huggingface.co/eagle0504/pretrained_transformer_model_v1

# %%
from huggingface_hub import hf_hub_download
import tensorflow as tf
import os
import json
import pickle

# Define the Hugging Face model repository path
model_repo_url = f"{account_name}/{model_name}"

# Step 1: Download the model file from Hugging Face
model_filename = f"{model_name}.keras"
model_file_path = hf_hub_download(repo_id=model_repo_url, filename=model_filename, use_auth_token=huggingface_token)

# Step 2: Load the pre-trained model from the downloaded file
pre_trained_transformer = tf.keras.models.load_model(model_file_path, custom_objects={"TransformerModel": TransformerModel})

# Step 3: Compile the model to prepare for further training
pre_trained_transformer.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Step 4: Reload the tokenizer (if used) by downloading tokenizer files from Hugging Face
tokenizer_config_path = hf_hub_download(repo_id=model_repo_url, filename="tokenizer_config.json", use_auth_token=huggingface_token)
vocab_path = hf_hub_download(repo_id=model_repo_url, filename="vocab.pkl", use_auth_token=huggingface_token)

# Load the tokenizer configuration from the downloaded file
with open(tokenizer_config_path, "r") as f:
    tokenizer_config = json.load(f)

# Recreate the tokenizer using TensorFlow's Tokenizer class
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(
    num_words=tokenizer_config.get("num_words"),
    filters=tokenizer_config.get("filters"),
    lower=tokenizer_config.get("lower"),
    split=tokenizer_config.get("split"),
    char_level=tokenizer_config.get("char_level")
)
tokenizer.word_index = tokenizer_config.get("word_index")
tokenizer.index_word = tokenizer_config.get("index_word")

# Load the vocabulary from the pickle file
with open(vocab_path, "rb") as f:
    tokenizer.word_index = pickle.load(f)

# Clean up downloaded files
os.remove(tokenizer_config_path)
os.remove(vocab_path)
# Out:
# pretrained_transformer_model_v1.keras:   0%|          | 0.00/1.53M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/812 [00:00<?, ?B/s]
# vocab.pkl:   0%|          | 0.00/258 [00:00<?, ?B/s]

# %%
# Prepare your sample_data and call fit again
pre_trained_transformer.fit(sample_data, sample_data, epochs=5)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.8214 - loss: 1.8700
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7857 - loss: 1.8781
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8571 - loss: 1.4830
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8750 - loss: 1.2145
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8571 - loss: 1.1532

# %%
# Test the function with the example input
input_text = "what's capital of france?"
predicted_response = predict_text(input_text, pre_trained_transformer, tokenizer, max_length=20)
print("Predicted Response:", predicted_response)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Predicted Response: capital hamlet france
