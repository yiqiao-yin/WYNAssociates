# %% [markdown]
# ## Install

# %%
pip install wyn-agent-s==0.1.2
# Out:
# Collecting wyn-agent-s==0.1.2
#   Downloading wyn_agent_s-0.1.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting PyAutoGUI==0.9.54 (from wyn-agent-s==0.1.2)
#   Downloading PyAutoGUI-0.9.54.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting anthropic==0.45.0 (from wyn-agent-s==0.1.2)
#   Downloading anthropic-0.45.0-py3-none-any.whl.metadata (23 kB)
# Collecting fpdf==1.7.2 (from wyn-agent-s==0.1.2)
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Collecting google-search-results<3.0.0,>=2.4.2 (from wyn-agent-s==0.1.2)
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib<4.0.0,>=3.9.0 in /usr/local/lib/python3.11/dist-packages (from wyn-agent-s==0.1.2) (3.10.0)
# Requirement already satisfied: openai<2.0.0,>=1.44.1 in /usr/local/lib/python3.11/dist-packages (from wyn-agent-s==0.1.2) (1.81.0)
# Collecting python-docx==1.1.2 (from wyn-agent-s==0.1.2)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting serpapi<0.2.0,>=0.1.5 (from wyn-agent-s==0.1.2)
#   Downloading serpapi-0.1.5-py2.py3-none-any.whl.metadata (10 kB)
# Collecting twilio<10.0.0,>=9.3.0 (from wyn-agent-s==0.1.2)
#   Downloading twilio-9.6.1-py2.py3-none-any.whl.metadata (13 kB)
# Collecting web-browser==0.0.1 (from wyn-agent-s==0.1.2)
#   Downloading web_browser-0.0.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting yfinance==0.2.50 (from wyn-agent-s==0.1.2)
#   Downloading yfinance-0.2.50-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from anthropic==0.45.0->wyn-agent-s==0.1.2) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from anthropic==0.45.0->wyn-agent-s==0.1.2) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from anthropic==0.45.0->wyn-agent-s==0.1.2) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from anthropic==0.45.0->wyn-agent-s==0.1.2) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from anthropic==0.45.0->wyn-agent-s==0.1.2) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from anthropic==0.45.0->wyn-agent-s==0.1.2) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from anthropic==0.45.0->wyn-agent-s==0.1.2) (4.13.2)
# Collecting python3-Xlib (from PyAutoGUI==0.9.54->wyn-agent-s==0.1.2)
#   Downloading python3-xlib-0.15.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pymsgbox (from PyAutoGUI==0.9.54->wyn-agent-s==0.1.2)
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytweening>=1.0.4 (from PyAutoGUI==0.9.54->wyn-agent-s==0.1.2)
#   Downloading pytweening-1.2.0.tar.gz (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.2/171.2 kB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyscreeze>=0.1.21 (from PyAutoGUI==0.9.54->wyn-agent-s==0.1.2)
#   Downloading pyscreeze-1.0.1.tar.gz (27 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pygetwindow>=0.0.5 (from PyAutoGUI==0.9.54->wyn-agent-s==0.1.2)
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mouseinfo (from PyAutoGUI==0.9.54->wyn-agent-s==0.1.2)
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx==1.1.2->wyn-agent-s==0.1.2) (5.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from web-browser==0.0.1->wyn-agent-s==0.1.2) (0.45.1)
# Requirement already satisfied: requests==2.* in /usr/local/lib/python3.11/dist-packages (from web-browser==0.0.1->wyn-agent-s==0.1.2) (2.32.3)
# Collecting selenium==4.* (from web-browser==0.0.1->wyn-agent-s==0.1.2)
#   Downloading selenium-4.33.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: beautifulsoup4==4.* in /usr/local/lib/python3.11/dist-packages (from web-browser==0.0.1->wyn-agent-s==0.1.2) (4.13.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.50->wyn-agent-s==0.1.2) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.50->wyn-agent-s==0.1.2) (2.0.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.50->wyn-agent-s==0.1.2) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.50->wyn-agent-s==0.1.2) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.50->wyn-agent-s==0.1.2) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.50->wyn-agent-s==0.1.2) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.50->wyn-agent-s==0.1.2) (3.18.1)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.50->wyn-agent-s==0.1.2) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4==4.*->web-browser==0.0.1->wyn-agent-s==0.1.2) (2.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.*->web-browser==0.0.1->wyn-agent-s==0.1.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests==2.*->web-browser==0.0.1->wyn-agent-s==0.1.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.*->web-browser==0.0.1->wyn-agent-s==0.1.2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests==2.*->web-browser==0.0.1->wyn-agent-s==0.1.2) (2025.4.26)
# Collecting trio~=0.30.0 (from selenium==4.*->web-browser==0.0.1->wyn-agent-s==0.1.2)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium==4.*->web-browser==0.0.1->wyn-agent-s==0.1.2)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium==4.*->web-browser==0.0.1->wyn-agent-s==0.1.2) (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.0->wyn-agent-s==0.1.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.0->wyn-agent-s==0.1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.0->wyn-agent-s==0.1.2) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.0->wyn-agent-s==0.1.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.0->wyn-agent-s==0.1.2) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.0->wyn-agent-s==0.1.2) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.0->wyn-agent-s==0.1.2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.9.0->wyn-agent-s==0.1.2) (2.9.0.post0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.44.1->wyn-agent-s==0.1.2) (4.67.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from twilio<10.0.0,>=9.3.0->wyn-agent-s==0.1.2) (2.10.1)
# Requirement already satisfied: aiohttp>=3.8.4 in /usr/local/lib/python3.11/dist-packages (from twilio<10.0.0,>=9.3.0->wyn-agent-s==0.1.2) (3.11.15)
# Collecting aiohttp-retry>=2.8.3 (from twilio<10.0.0,>=9.3.0->wyn-agent-s==0.1.2)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.4->twilio<10.0.0,>=9.3.0->wyn-agent-s==0.1.2) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.4->twilio<10.0.0,>=9.3.0->wyn-agent-s==0.1.2) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.4->twilio<10.0.0,>=9.3.0->wyn-agent-s==0.1.2) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.4->twilio<10.0.0,>=9.3.0->wyn-agent-s==0.1.2) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.4->twilio<10.0.0,>=9.3.0->wyn-agent-s==0.1.2) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.4->twilio<10.0.0,>=9.3.0->wyn-agent-s==0.1.2) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.4->twilio<10.0.0,>=9.3.0->wyn-agent-s==0.1.2) (1.20.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yfinance==0.2.50->wyn-agent-s==0.1.2) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yfinance==0.2.50->wyn-agent-s==0.1.2) (0.5.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->anthropic==0.45.0->wyn-agent-s==0.1.2) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic==0.45.0->wyn-agent-s==0.1.2) (0.16.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance==0.2.50->wyn-agent-s==0.1.2) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->anthropic==0.45.0->wyn-agent-s==0.1.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->anthropic==0.45.0->wyn-agent-s==0.1.2) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->anthropic==0.45.0->wyn-agent-s==0.1.2) (0.4.1)
# Collecting pyrect (from pygetwindow>=0.0.5->PyAutoGUI==0.9.54->wyn-agent-s==0.1.2)
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.11/dist-packages (from mouseinfo->PyAutoGUI==0.9.54->wyn-agent-s==0.1.2) (1.9.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium==4.*->web-browser==0.0.1->wyn-agent-s==0.1.2) (2.4.0)
# Collecting outcome (from trio~=0.30.0->selenium==4.*->web-browser==0.0.1->wyn-agent-s==0.1.2)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium==4.*->web-browser==0.0.1->wyn-agent-s==0.1.2)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium==4.*->web-browser==0.0.1->wyn-agent-s==0.1.2) (1.7.1)
# Downloading wyn_agent_s-0.1.2-py3-none-any.whl (9.5 kB)
# Downloading anthropic-0.45.0-py3-none-any.whl (222 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 kB 22.4 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 25.0 MB/s eta 0:00:00
# Downloading web_browser-0.0.1-py3-none-any.whl (20 kB)
# Downloading yfinance-0.2.50-py2.py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 10.4 MB/s eta 0:00:00
# Downloading selenium-4.33.0-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 109.1 MB/s eta 0:00:00
# Downloading serpapi-0.1.5-py2.py3-none-any.whl (10 kB)
# Downloading twilio-9.6.1-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 85.7 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 42.8 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: fpdf, PyAutoGUI, google-search-results, pygetwindow, pyscreeze, pytweening, mouseinfo, pymsgbox, python3-Xlib, pyrect
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=a88b26e93fae6120b4df48b24123e3a09b56b02bca8bcd6633b09465357cc850
#   Stored in directory: /root/.cache/pip/wheels/65/4f/66/bbda9866da446a72e206d6484cd97381cbc7859a7068541c36
#   Building wheel for PyAutoGUI (pyproject.toml) ... done
#   Created wheel for PyAutoGUI: filename=pyautogui-0.9.54-py3-none-any.whl size=37684 sha256=e453a8b556d31aa6f01634cca078004182dbfafd5795d7feec54297e6f88ebea
#   Stored in directory: /root/.cache/pip/wheels/95/dc/b1/fe122b791e0db8bf439a0e6e1d2628e48f10bf430cae13521b
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32010 sha256=625531817bd25e3ad376b7a42500da95a7cd2c5f84c7e07859355230f19255c9
#   Stored in directory: /root/.cache/pip/wheels/6e/42/3e/aeb691b02cb7175ec70e2da04b5658d4739d2b41e5f73cd06f
#   Building wheel for pygetwindow (setup.py) ... done
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11063 sha256=0bc0d058696c1b0c93e24b68ac010c09dc866032bb24d7494931e76da0782819
#   Stored in directory: /root/.cache/pip/wheels/07/75/0b/7ca0b598eb4c21d43ba4bcc78a0538dfcf803a5997da33bc19
#   Building wheel for pyscreeze (pyproject.toml) ... done
#   Created wheel for pyscreeze: filename=pyscreeze-1.0.1-py3-none-any.whl size=14459 sha256=73faae2f5dbc6c31beb667da5c5d09e7aed0cdda901ad3a97d513c45946934a7
#   Stored in directory: /root/.cache/pip/wheels/cd/e3/dd/267b393d8e8f607e47194942740d080d9bfd835cd4375a3de1
#   Building wheel for pytweening (setup.py) ... done
#   Created wheel for pytweening: filename=pytweening-1.2.0-py3-none-any.whl size=8009 sha256=4be85dc5bb1c27f9923b7bcc6351d5ccb5fa2d48c54baeb1adec3a0ee95dacfa
#   Stored in directory: /root/.cache/pip/wheels/db/81/dc/0d61a3c9614f288e057ab63924e2a49edbeed4ffc916dcda1e
#   Building wheel for mouseinfo (setup.py) ... done
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10888 sha256=25427b4156fa84a3220a45256e2a77e7474d181af8d181607970e5c16cdfec8e
#   Stored in directory: /root/.cache/pip/wheels/20/0b/7f/939ac9ff785b09951c706150537572c00123412f260a6024f3
#   Building wheel for pymsgbox (pyproject.toml) ... done
#   Created wheel for pymsgbox: filename=pymsgbox-1.0.9-py3-none-any.whl size=7453 sha256=4993d34493f798ae1218a18f64f3810ec141c6fa9efd8ef337fe56be1a97291a
#   Stored in directory: /root/.cache/pip/wheels/85/92/63/e126ee5f33d8f2ed04f96e43ef5df7270a2f331848752e8662
#   Building wheel for python3-Xlib (setup.py) ... done
#   Created wheel for python3-Xlib: filename=python3_xlib-0.15-py3-none-any.whl size=109501 sha256=0a447d956471cb7c7d2d45a4dc8f9be06d1f03f9c1e84a6370e11299c8553f1b
#   Stored in directory: /root/.cache/pip/wheels/58/d2/1b/c2247396a6c5fbb1900ccf1ec3b73482d428b137dcdf1d99de
#   Building wheel for pyrect (setup.py) ... done
#   Created wheel for pyrect: filename=PyRect-0.2.0-py2.py3-none-any.whl size=11181 sha256=6f83b9cf719cc6fb9a081baa14f421e1cdf98a9af1c25ac2aee89261c8dafa3e
#   Stored in directory: /root/.cache/pip/wheels/c4/e9/fc/b7a666dd4f9a3168fb44d643079b41d36ddab52f470707e820
# Successfully built fpdf PyAutoGUI google-search-results pygetwindow pyscreeze pytweening mouseinfo pymsgbox python3-Xlib pyrect
# Installing collected packages: pytweening, python3-Xlib, pyrect, pymsgbox, fpdf, wsproto, python-docx, pyscreeze, pygetwindow, outcome, mouseinfo, trio, serpapi, PyAutoGUI, google-search-results, yfinance, trio-websocket, anthropic, aiohttp-retry, twilio, selenium, web-browser, wyn-agent-s
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.61
#     Uninstalling yfinance-0.2.61:
#       Successfully uninstalled yfinance-0.2.61
# Successfully installed PyAutoGUI-0.9.54 aiohttp-retry-2.9.1 anthropic-0.45.0 fpdf-1.7.2 google-search-results-2.4.2 mouseinfo-0.1.3 outcome-1.3.0.post0 pygetwindow-0.0.9 pymsgbox-1.0.9 pyrect-0.2.0 pyscreeze-1.0.1 python-docx-1.1.2 python3-Xlib-0.15 pytweening-1.2.0 selenium-4.33.0 serpapi-0.1.5 trio-0.30.0 trio-websocket-0.12.2 twilio-9.6.1 web-browser-0.0.1 wsproto-1.2.0 wyn-agent-s-0.1.2 yfinance-0.2.50

# %% [markdown]
# ## Run

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
SERPAPI_API_KEY = userdata.get('SERPAPI_API_KEY')

# %%
import os

# Import the agent
from wyn_agent_s.main import Agent_S

# Initialize and start the chat!
agent = Agent_S(
    openai_api_key=OPENAI_API_KEY,
    serpapi_key=SERPAPI_API_KEY
)

# Run the chat
agent.start_chat()
# Out:
# 👋 Welcome! Press 'EXIT' to quit the chat at any time.
# 👤 User: hi
# 🤖 Bot Response: Hello! How can I assist you today?
# 👀 No API call found in the event stream. Exiting.
# User: tell me joke
# 🤖 Bot Response: Sure, here's one for you:
#
# Why don't scientists trust atoms?
#
# Because they make up everything!
# 👀 No API call found in the event stream. Exiting.
# User: google search
# Match found for trigger: 'google search'
# 👀 Intent detected for API call: google_search
# Please provide engine: Google
# Please provide query: alzheimers for late 70s
# Please provide location: New York, NY
# Please provide num: 5
# Run google search API using:
# query=alzheimers for late 70s,
# location=New York, NY
# 👀 Results:
# | Title | Link | Snippet |
# | :--- | :--- | :--- |
# | The later stage of dementia | [Link](https://www.alzheimers.org.uk/about-dementia/symptoms-and-diagnosis/how-dementia-progresses/later-stages-dementia) | People with later-stage dementia will eventually need full-time care and support with daily living and personal care, such as eating, washing and dressing. |
# | What Are the Signs of Alzheimer's Disease? | [Link](https://www.nia.nih.gov/health/alzheimers-symptoms-and-diagnosis/what-are-signs-alzheimers-disease) | Signs of Mild Alzheimer's disease · Memory loss that disrupts daily life · Poor judgment, leading to bad decisions · Loss of spontaneity and sense ... |
# | Alzheimer's Disease Facts and Figures | [Link](https://www.alz.org/alzheimers-dementia/facts-figures) | People age 65 and older survive an average of four to eight years after a diagnosis of Alzheimer's, yet some live as long as 20 years with Alzheimer's. This ... |
# | LATE, Explained - Alzheimer's Disease Research Center | [Link](https://www.adrc.wisc.edu/dementia-matters/late-explained) | LATE, or Limbic-predominant Age-related TDP-43 Encephalopathy, is a newly-characterized type of dementia associated with abnormal clumps of a protein called ... |
#
# User: EXIT
# 👋 Thanks for chatting! Have a great day! 🌟
