# %% [markdown]
# ## Stock Market Timing / Buy Sell Signals
#
# This notebook we introduce buy / sell signals generated by Relative Strength Index (or [RSI](https://www.investopedia.com/terms/r/rsi.asp)).

# %%
# !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
# Out:
# Collecting git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#   Cloning https://github.com/yiqiao-yin/YinPortfolioManagement.git to c:\users\eagle\appdata\local\temp\pip-req-build-0i_75qmz
# Building wheels for collected packages: YinPortfolioManagement
#   Building wheel for YinPortfolioManagement (setup.py): started
#   Building wheel for YinPortfolioManagement (setup.py): finished with status 'done'
#   Created wheel for YinPortfolioManagement: filename=YinPortfolioManagement-1.0.0-py3-none-any.whl size=7571 sha256=61ed5053c6554af97c44c014b37b2d00b2f121e4ad3ba3dcc2929856b69043b2
#   Stored in directory: C:\Users\eagle\AppData\Local\Temp\pip-ephem-wheel-cache-o1exy88m\wheels\cc\50\76\5d86e12f8b54a575a6ebf7d3c1fbdee08aa170fa4a4d1218b1
# Successfully built YinPortfolioManagement
# Installing collected packages: YinPortfolioManagement
# Successfully installed YinPortfolioManagement-1.0.0
#   Running command git clone -q https://github.com/yiqiao-yin/YinPortfolioManagement.git 'C:\Users\eagle\AppData\Local\Temp\pip-req-build-0i_75qmz'

# %%
from YinCapital_forecast.modules import RSI_Timer

# %%
tmp1 = RSI_Timer(
    start_date =   '2018-01-01',
    end_date   =   '2021-07-15',
    tickers    =   'AAPL',
    pick_RSI   = 1,
    rsi_threshold_1 = 10,
    rsi_threshold_2 = 30,
    rsi_threshold_3 = 100,
    buy_threshold = 30,
    sell_threshold = 85 )
# Out:
# ------------------------------------------------------------------------------
# MANUAL:
# Try run the following line by line in a Python Notebook.
#
#     MANUAL: To install this python package, please use the following code.
#
#     # In a python notebook:
#     # !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#     # In a command line:
#     # pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#
#     # Run
#     start_date = '2010-01-01'
#     end_date   = '2020-01-18'
#     ticker = 'FB'
#     temp = YinsTimer(
#             start_date, end_date, ticker, figsize=(15,6), LB=-0.01, UB=0.01,
#             plotGraph=True, verbose=True, printManual=True, gotoSEC=True)
#
# Manual ends here.
# ------------------------------------------------------------------------------
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Ends here.
