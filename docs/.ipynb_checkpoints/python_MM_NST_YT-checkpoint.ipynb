# %% [markdown]
# # Money Management: Stock Price Forecasting Using Neural Sequence Translation
#
# Neural Sequence Translation (NST) is an tweak version of Recurrent Neural Network which not just forecasts a point in the future but an entire vector in the future. Just like [Neural Machine Translation](https://arxiv.org/abs/1409.0473), this notebook explores this upgrade philosophy and apply this idea in a singular stock data.
#
# Stock price today is probably dependent on:
# - The trend it has been folloing from the previous day.
# - The price it was traded at from previous day.
# - Some other factors that may affect stock price today.
#
# Generalize intuition from above to the following:
# - The previous cell state (i.e. the information that was present in the memory after the previous time step).
# - The previous hidden state (i.e. this is the same as the output of the previous cell).
# - The input at the current time step (i.e. the new information that is being fed in at that moment).
#
# In this notebook, we cover
# - Part 1 - Data Preprocessing
# - Part 2 - Construct NST Architecture
# - Part 3 - Predictions and Performance Visualization
#
# A Production of [Yin's Capital](www.YinsCapital.com)

# %% [markdown]
# ## Recurrent Neural Network (a sequential model)
#
# Given data $X$ and $Y$, we want to feed information forward into a time stamp. Then we form some belief and we make some initial predictions. We investigate our beliefs by looking at the loss function of the initial guesses and the real value. We update our model according to error we observed.
#
# ## Architecture: Feed-forward
#
# Consider data with time stamp
# $$X_{\langle 1 \rangle} \rightarrow X_{\langle 2 \rangle} \rightarrow \dots \rightarrow X_{\langle T \rangle}$$
# and feed-forward architecture pass information through exactly as the following:
# $$
# \text{Information in:} \rightarrow
# \begin{matrix}
# Y_{\langle 1 \rangle}, \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} & Y_{\langle 2 \rangle}, \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} &       & Y_{\langle T \rangle}, \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# X_{\langle 1 \rangle} \rightarrow    & X_{\langle 2 \rangle} \rightarrow    & \dots \rightarrow & X_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# w_{\langle 1 \rangle}, b_{0, \langle 1 \rangle}    & w_{\langle 2 \rangle}, b_{0, \langle 2 \rangle}    &       & w_{\langle T \rangle}, b_{0, \langle T \rangle} \\
# \end{matrix}
# \rightarrow
# \text{Form beliefs about } Y_{\langle T \rangle}
# $$
# while the educated guesses $\hat{Y}_{\langle T \rangle}$ are our beliefs about real $Y$ at time stamp $T$.
#
# ## Architecture: Feed-backward
#
# Let us clearly define our loss function to make sure we have a proper grip of our mistakes.
# $$\mathcal{L} = \sum_t \sum_k L(\hat{y}_{\langle t,k \rangle} - y_{\langle t,k \rangle})^2$$
# and we can compute the gradient
# $$\triangledown = \frac{\partial \mathcal{L}}{\partial a}$$
# and then with respect with parameters $w$ and $b$
# $$\frac{\partial \triangledown}{\partial w}, \frac{\partial \triangledown}{\partial a}$$
# and now with perspective of where we make our mistakes according to our parameters we can go backward
# $$
# \text{Information in:} \leftarrow
# \underbrace{
# \begin{matrix}
# Y_{\langle 1 \rangle}, \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} & Y_{\langle 2 \rangle}, \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} &       & Y_{\langle T \rangle}, \{\hat{Y}_{\langle 1 \rangle}, ..., \hat{Y}_{\langle k \rangle}\} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# X_{\langle 1 \rangle} \leftarrow    & X_{\langle 2 \rangle} \leftarrow    & \dots \leftarrow & X_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# w'_{\langle 1 \rangle}, b'_{0, \langle 1 \rangle}    & w'_{\langle 2 \rangle}, b'_{0, \langle 2 \rangle}    &       & w'_{\langle T \rangle}, b'_{0, \langle T \rangle} \\
# \end{matrix}}_{\text{Update: } w, b \text{ with } w', b'}
# \leftarrow
# \text{Total Loss: } \mathcal{L} (\hat{y}, y)
# $$
# and the *update* action in the above architecture is dependent on your optimizer specified in the algorithm.

# %%
# library
import pandas as pd 
import numpy as np
import yfinance as yf

# %%
# set parameters
start_date       =   '2013-01-01'
end_date         =   '2021-01-02'
ticker           =   'AAPL' # apple stock data
w = 1
h = 5

# %%
stockData = yf.download(ticker, start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stockData.head(2)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2013-01-02  19.779285  19.821428  19.343929  19.608213  16.985447  560518000
# 2013-01-03  19.567142  19.631071  19.321428  19.360714  16.771053  352965200

# %%
stockData = stockData.iloc[:,:5]
stockData.head(2)
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2013-01-02  19.779285  19.821428  19.343929  19.608213  16.985447
# 2013-01-03  19.567142  19.631071  19.321428  19.360714  16.771053

# %%
Y = stockData.iloc[1::, ]
Y.head(2)
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2013-01-03  19.567142  19.631071  19.321428  19.360714  16.771053
# 2013-01-04  19.177500  19.236786  18.779642  18.821428  16.303900

# %%
X = stockData.iloc[0:int(stockData.shape[0]-1)]
X.head(2)
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2013-01-02  19.779285  19.821428  19.343929  19.608213  16.985447
# 2013-01-03  19.567142  19.631071  19.321428  19.360714  16.771053

# %%
Y.tail(2)
# Out:
#                   Open        High         Low       Close   Adj Close
# Date
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.094650
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  132.069473

# %%
X.tail(2)
# Out:
#                   Open        High         Low       Close   Adj Close
# Date
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.239273
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.094650

# %%
cutoff = 0.8
X_train = X.iloc[0:round(X.shape[0]*cutoff), ]
X_test = X.iloc[round(X.shape[0]*cutoff):X.shape[0], ]

# %%
y_train = Y.iloc[0:round(Y.shape[0]*cutoff), ]
y_test = Y.iloc[round(Y.shape[0]*cutoff):Y.shape[0], ]

# %%
X_train = np.array(X_train).reshape(X_train.shape[0], w, h)
X_test = np.array(X_test).reshape(X_test.shape[0], w, h)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1611, 1, 5)
# (403, 1, 5)
# (1611, 5)
# (403, 5)

# %%
# import some functions from keras library
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
y_train.shape[1]
# Out:
# 5

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (w, h)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 128))
regressor.add(Dense(units = 64))
regressor.add(Dense(units = 32))
regressor.add(Dense(units = y_train.shape[1]))

# %%
regressor.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 1, 50)             11200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 50)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 50)             20200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 50)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 128)            6528
# _________________________________________________________________
# dense_3 (Dense)              (None, 1, 64)             8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 1, 32)             2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 1, 5)              165
# =================================================================
# Total params: 48,429
# Trainable params: 48,429
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressor.compile(optimizer = "adam", loss = "mean_squared_error")

# %%
regressor.fit(X_train, y_train, epochs=50, batch_size = 64)
# Out:
# Epoch 1/50
# 26/26 [==============================] - 0s 2ms/step - loss: 928.0976
# Epoch 2/50
# 26/26 [==============================] - 0s 2ms/step - loss: 200.9908
# Epoch 3/50
# 26/26 [==============================] - 0s 3ms/step - loss: 134.0357
# Epoch 4/50
# 26/26 [==============================] - 0s 2ms/step - loss: 129.9542
# Epoch 5/50
# 26/26 [==============================] - 0s 3ms/step - loss: 129.3517
# Epoch 6/50
# 26/26 [==============================] - 0s 3ms/step - loss: 128.3710
# Epoch 7/50
# 26/26 [==============================] - 0s 3ms/step - loss: 129.0491
# Epoch 8/50
# 26/26 [==============================] - 0s 3ms/step - loss: 126.4846
# Epoch 9/50
# 26/26 [==============================] - 0s 3ms/step - loss: 126.2484
# Epoch 10/50
# 26/26 [==============================] - 0s 2ms/step - loss: 128.3790
# Epoch 11/50
# 26/26 [==============================] - 0s 2ms/step - loss: 124.6139
# Epoch 12/50
# 26/26 [==============================] - 0s 3ms/step - loss: 124.7436
# Epoch 13/50
# 26/26 [==============================] - 0s 3ms/step - loss: 123.7889
# Epoch 14/50
# 26/26 [==============================] - 0s 3ms/step - loss: 124.9750
# Epoch 15/50
# 26/26 [==============================] - 0s 2ms/step - loss: 123.1926
# Epoch 16/50
# 26/26 [==============================] - 0s 2ms/step - loss: 123.6672
# Epoch 17/50
# 26/26 [==============================] - 0s 2ms/step - loss: 125.0985
# Epoch 18/50
# 26/26 [==============================] - 0s 2ms/step - loss: 123.9402
# Epoch 19/50
# 26/26 [==============================] - 0s 2ms/step - loss: 121.9047
# Epoch 20/50
# 26/26 [==============================] - 0s 2ms/step - loss: 121.2118
# Epoch 21/50
# 26/26 [==============================] - 0s 3ms/step - loss: 122.0483
# Epoch 22/50
# 26/26 [==============================] - 0s 3ms/step - loss: 122.0734
# Epoch 23/50
# 26/26 [==============================] - 0s 3ms/step - loss: 121.1437
# Epoch 24/50
# 26/26 [==============================] - 0s 2ms/step - loss: 121.4824
# Epoch 25/50
# 26/26 [==============================] - 0s 3ms/step - loss: 120.9369
# Epoch 26/50
# 26/26 [==============================] - 0s 3ms/step - loss: 121.5136
# Epoch 27/50
# 26/26 [==============================] - 0s 3ms/step - loss: 122.0812
# Epoch 28/50
# 26/26 [==============================] - 0s 3ms/step - loss: 120.7257
# Epoch 29/50
# 26/26 [==============================] - 0s 3ms/step - loss: 120.7923
# Epoch 30/50
# 26/26 [==============================] - 0s 2ms/step - loss: 121.5957
# Epoch 31/50
# 26/26 [==============================] - 0s 3ms/step - loss: 119.7554
# Epoch 32/50
# 26/26 [==============================] - 0s 3ms/step - loss: 122.8664
# Epoch 33/50
# 26/26 [==============================] - 0s 3ms/step - loss: 120.2582
# Epoch 34/50
# 26/26 [==============================] - 0s 3ms/step - loss: 121.2678
# Epoch 35/50
# 26/26 [==============================] - 0s 3ms/step - loss: 121.2194
# Epoch 36/50
# 26/26 [==============================] - 0s 3ms/step - loss: 124.4621
# Epoch 37/50
# 26/26 [==============================] - 0s 3ms/step - loss: 120.3440
# Epoch 38/50
# 26/26 [==============================] - 0s 3ms/step - loss: 120.0115
# Epoch 39/50
# 26/26 [==============================] - 0s 3ms/step - loss: 119.4009
# Epoch 40/50
# 26/26 [==============================] - 0s 3ms/step - loss: 121.2222
# Epoch 41/50
# 26/26 [==============================] - 0s 3ms/step - loss: 122.7525
# Epoch 42/50
# 26/26 [==============================] - 0s 2ms/step - loss: 119.6221
# Epoch 43/50
# 26/26 [==============================] - 0s 2ms/step - loss: 119.8904
# Epoch 44/50
# 26/26 [==============================] - 0s 2ms/step - loss: 119.5563
# Epoch 45/50
# 26/26 [==============================] - 0s 2ms/step - loss: 119.5593
# Epoch 46/50
# 26/26 [==============================] - 0s 2ms/step - loss: 120.6864
# Epoch 47/50
# 26/26 [==============================] - 0s 3ms/step - loss: 120.3853
# Epoch 48/50
# 26/26 [==============================] - 0s 3ms/step - loss: 120.2097
# Epoch 49/50
# 26/26 [==============================] - 0s 3ms/step - loss: 121.9030
# Epoch 50/50
# 26/26 [==============================] - 0s 3ms/step - loss: 123.0474

# %%
predicted_stock_price = regressor.predict(X_test)

# %%
real_stock_price = y_test

# %%
predicted_stock_price = np.array(
    predicted_stock_price).reshape(predicted_stock_price.shape[0], predicted_stock_price.shape[2])

# %%
predicted_stock_price = pd.DataFrame(predicted_stock_price)

# %%
predicted_stock_price.columns = real_stock_price.columns
predicted_stock_price.index = real_stock_price.index

# %%
predicted_stock_price.head(2)
# Out:
#                  Open       High        Low      Close  Adj Close
# Date
# 2019-05-30  31.444645  31.855648  31.328463  31.484409  29.605070
# 2019-05-31  31.444386  31.855404  31.328419  31.484047  29.604692

# %%
import mplfinance as mpf

# %%
s = mpf.make_mpf_style(base_mpf_style='charles', rc={'font.size': 6})
fig = mpf.figure(figsize=(10, 7), style=s) # pass in the self defined style to the whole canvas
ax = fig.add_subplot(2,1,1) # main candle stick chart subplot, you can also pass in the self defined style here only for this subplot
av = fig.add_subplot(2,1,2, sharex=ax)  # volume chart subplot

mpf.plot(real_stock_price, type = 'candle', style = 'yahoo', ax=ax, volume=False)
mpf.plot(predicted_stock_price, type = 'candle', style = 'yahoo', ax=av)
# Out:
# <Mpf_Figure size 1000x700 with 2 Axes>

# %%
from YinCapital_forecast.modules import Neural_Sequence_Translation

# %%
tmp = Neural_Sequence_Translation(
        start_date       =   '2014-01-01',
        end_date         =   '2021-01-01',
        ticker           =   'AAPL',
        w                =   1,
        h                =   5,
        cutoff           =   0.8,
        numOfHiddenLayer =   3,
        l1_units         =   128*4,
        l2_units         =   128*3,
        l3_units         =   64*3,
        l4_units         =   30,
        l5_units         =   10,
        dropOutRate       =  0.3,
        optimizer        =   'adam',
        loss             =   'mean_squared_error',
        epochs           =   120,
        batch_size       =   64,
        plotGraph        =   False,
        useMPLFinancePlot=   True,
        verbose          =   True )
# Out:
# ------------------------------------------------------------------------------
#
#             MANUAL: To install this python package, please use the following code.
#
#             # In a python notebook:
#             # !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#             # In a command line:
#             # pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#
#             # Run
#             tmp = RNN_Regressor(
#                 start_date       =   '2013-01-01',
#                 end_date         =   '2021-01-01',
#                 ticker           =   'AAPL',
#                 w                =   1,
#                 h                =   5,
#                 cutoff           =   0.8,
#                 numOfHiddenLayer =   3,
#                 numOfDense       =   2,
#                 l1_units         =   50,
#                 l2_units         =   50,
#                 l2_units         =   50,
#                 l3_units         =   50,
#                 l4_units         =   30,
#                 l5_units         =   10,
#                 dropOutRate       =  0.2,
#                 optimizer        =   'adam',
#                 loss             =   'mean_squared_error',
#                 useDice          =   True,
#                 epochs           =   50,
#                 batch_size       =   64,
#                 plotGraph        =   True,
#                 useMPLFinancePlot=   True,
#                 verbose          =   True )
#
#             # Cite
#             # All Rights Reserved. © Yiqiao Yin
#
# ------------------------------------------------------------------------------
# [*********************100%***********************]  1 of 1 completed
# (1410, 1, 5)
# (352, 1, 5)
# (1410, 5)
# (352, 5)
# --------------------------------------------
# Let us investigate the sequential models.
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 1, 512)            1060864
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1, 512)            0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 1, 384)            1377792
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 1, 384)            0
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 192)               443136
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 192)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               98816
# _________________________________________________________________
# dense_22 (Dense)             (None, 384)               196992
# _________________________________________________________________
# dense_23 (Dense)             (None, 5)                 1925
# =================================================================
# Total params: 3,179,525
# Trainable params: 3,179,525
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------
# Time Consumption (in sec): 0.8171777725219727
# Time Consumption (in min): 0.01
# Time Consumption (in hr): 0.0 2
# --------------------------------------------
# Epoch 1/120
# 23/23 [==============================] - 0s 15ms/step - loss: 504.5901
# Epoch 2/120
# 23/23 [==============================] - 0s 15ms/step - loss: 72.6237
# Epoch 3/120
# 23/23 [==============================] - 0s 16ms/step - loss: 16.1627
# Epoch 4/120
# 23/23 [==============================] - 0s 16ms/step - loss: 9.1389
# Epoch 5/120
# 23/23 [==============================] - 0s 16ms/step - loss: 9.1859
# Epoch 6/120
# 23/23 [==============================] - 0s 16ms/step - loss: 8.3040
# Epoch 7/120
# 23/23 [==============================] - 0s 16ms/step - loss: 13.7348
# Epoch 8/120
# 23/23 [==============================] - 0s 16ms/step - loss: 6.7401
# Epoch 9/120
# 23/23 [==============================] - 0s 16ms/step - loss: 13.9295
# Epoch 10/120
# 23/23 [==============================] - 0s 16ms/step - loss: 7.6902
# Epoch 11/120
# 23/23 [==============================] - 0s 16ms/step - loss: 6.4493
# Epoch 12/120
# 23/23 [==============================] - 0s 15ms/step - loss: 10.0624
# Epoch 13/120
# 23/23 [==============================] - 0s 14ms/step - loss: 6.3902
# Epoch 14/120
# 23/23 [==============================] - 0s 15ms/step - loss: 9.1528
# Epoch 15/120
# 23/23 [==============================] - 0s 16ms/step - loss: 9.2637
# Epoch 16/120
# 23/23 [==============================] - 0s 15ms/step - loss: 6.9099
# Epoch 17/120
# 23/23 [==============================] - 0s 15ms/step - loss: 6.7379
# Epoch 18/120
# 23/23 [==============================] - 0s 15ms/step - loss: 8.3285
# Epoch 19/120
# 23/23 [==============================] - 0s 15ms/step - loss: 5.0853
# Epoch 20/120
# 23/23 [==============================] - 0s 16ms/step - loss: 5.4479
# Epoch 21/120
# 23/23 [==============================] - 0s 16ms/step - loss: 5.4179
# Epoch 22/120
# 23/23 [==============================] - 0s 15ms/step - loss: 6.0922
# Epoch 23/120
# 23/23 [==============================] - 0s 16ms/step - loss: 5.3991
# Epoch 24/120
# 23/23 [==============================] - 0s 15ms/step - loss: 5.7904
# Epoch 25/120
# 23/23 [==============================] - 0s 15ms/step - loss: 5.5876
# Epoch 26/120
# 23/23 [==============================] - 0s 16ms/step - loss: 4.6439
# Epoch 27/120
# 23/23 [==============================] - 0s 15ms/step - loss: 6.9566
# Epoch 28/120
# 23/23 [==============================] - 0s 16ms/step - loss: 5.4633
# Epoch 29/120
# 23/23 [==============================] - 0s 15ms/step - loss: 7.5299
# Epoch 30/120
# 23/23 [==============================] - 0s 15ms/step - loss: 6.5684
# Epoch 31/120
# 23/23 [==============================] - 0s 15ms/step - loss: 6.2390
# Epoch 32/120
# 23/23 [==============================] - 0s 15ms/step - loss: 5.4933
# Epoch 33/120
# 23/23 [==============================] - 0s 14ms/step - loss: 5.4563
# Epoch 34/120
# 23/23 [==============================] - 0s 15ms/step - loss: 7.8642
# Epoch 35/120
# 23/23 [==============================] - 0s 15ms/step - loss: 6.7737
# Epoch 36/120
# 23/23 [==============================] - 0s 14ms/step - loss: 9.3039
# Epoch 37/120
# 23/23 [==============================] - 0s 15ms/step - loss: 5.5368
# Epoch 38/120
# 23/23 [==============================] - 0s 15ms/step - loss: 4.6211
# Epoch 39/120
# 23/23 [==============================] - 0s 15ms/step - loss: 5.9617
# Epoch 40/120
# 23/23 [==============================] - 0s 15ms/step - loss: 4.1721
# Epoch 41/120
# 23/23 [==============================] - 0s 15ms/step - loss: 5.0505
# Epoch 42/120
# 23/23 [==============================] - 0s 15ms/step - loss: 4.6895
# Epoch 43/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.9841
# Epoch 44/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.7660
# Epoch 45/120
# 23/23 [==============================] - 0s 15ms/step - loss: 4.6890
# Epoch 46/120
# 23/23 [==============================] - 0s 15ms/step - loss: 3.9414
# Epoch 47/120
# 23/23 [==============================] - 0s 15ms/step - loss: 5.1686
# Epoch 48/120
# 23/23 [==============================] - 0s 16ms/step - loss: 4.6379
# Epoch 49/120
# 23/23 [==============================] - 0s 15ms/step - loss: 11.7916
# Epoch 50/120
# 23/23 [==============================] - 0s 15ms/step - loss: 7.3922
# Epoch 51/120
# 23/23 [==============================] - 0s 15ms/step - loss: 4.3944
# Epoch 52/120
# 23/23 [==============================] - 0s 15ms/step - loss: 3.9204
# Epoch 53/120
# 23/23 [==============================] - 0s 15ms/step - loss: 4.8511
# Epoch 54/120
# 23/23 [==============================] - 0s 15ms/step - loss: 4.9551
# Epoch 55/120
# 23/23 [==============================] - 0s 15ms/step - loss: 4.7986
# Epoch 56/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.6225
# Epoch 57/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.5342
# Epoch 58/120
# 23/23 [==============================] - 0s 16ms/step - loss: 5.0345
# Epoch 59/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.9816
# Epoch 60/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.7172
# Epoch 61/120
# 23/23 [==============================] - 0s 16ms/step - loss: 4.0157
# Epoch 62/120
# 23/23 [==============================] - 0s 15ms/step - loss: 3.1142
# Epoch 63/120
# 23/23 [==============================] - 0s 16ms/step - loss: 4.2045
# Epoch 64/120
# 23/23 [==============================] - 0s 16ms/step - loss: 5.6935
# Epoch 65/120
# 23/23 [==============================] - 0s 15ms/step - loss: 3.5140
# Epoch 66/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.7750
# Epoch 67/120
# 23/23 [==============================] - 0s 15ms/step - loss: 3.6813
# Epoch 68/120
# 23/23 [==============================] - 0s 15ms/step - loss: 3.6301
# Epoch 69/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.7219
# Epoch 70/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.0066
# Epoch 71/120
# 23/23 [==============================] - 0s 16ms/step - loss: 4.3054
# Epoch 72/120
# 23/23 [==============================] - 0s 17ms/step - loss: 3.4925
# Epoch 73/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.2174
# Epoch 74/120
# 23/23 [==============================] - 0s 16ms/step - loss: 2.9631
# Epoch 75/120
# 23/23 [==============================] - 0s 16ms/step - loss: 2.6507
# Epoch 76/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.3932
# Epoch 77/120
# 23/23 [==============================] - 0s 16ms/step - loss: 5.1700
# Epoch 78/120
# 23/23 [==============================] - 0s 16ms/step - loss: 5.1877
# Epoch 79/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.1612
# Epoch 80/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.5863
# Epoch 81/120
# 23/23 [==============================] - 0s 16ms/step - loss: 2.8221
# Epoch 82/120
# 23/23 [==============================] - 0s 16ms/step - loss: 3.2076
# Epoch 83/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.9262
# Epoch 84/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.9867
# Epoch 85/120
# 23/23 [==============================] - 0s 16ms/step - loss: 2.4123
# Epoch 86/120
# 23/23 [==============================] - 0s 16ms/step - loss: 2.5523
# Epoch 87/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.5775
# Epoch 88/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.9871
# Epoch 89/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.2672
# Epoch 90/120
# 23/23 [==============================] - 0s 17ms/step - loss: 2.1528
# Epoch 91/120
# 23/23 [==============================] - 0s 17ms/step - loss: 2.1639
# Epoch 92/120
# 23/23 [==============================] - 0s 16ms/step - loss: 2.3200
# Epoch 93/120
# 23/23 [==============================] - 0s 16ms/step - loss: 1.9764
# Epoch 94/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.0300
# Epoch 95/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.0311
# Epoch 96/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.1238
# Epoch 97/120
# 23/23 [==============================] - 0s 15ms/step - loss: 3.4462
# Epoch 98/120
# 23/23 [==============================] - 0s 14ms/step - loss: 2.9613
# Epoch 99/120
# 23/23 [==============================] - 0s 14ms/step - loss: 3.0065
# Epoch 100/120
# 23/23 [==============================] - 0s 15ms/step - loss: 1.9821
# Epoch 101/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.0511
# Epoch 102/120
# 23/23 [==============================] - 0s 15ms/step - loss: 1.7568
# Epoch 103/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.2807
# Epoch 104/120
# 23/23 [==============================] - 0s 16ms/step - loss: 2.6122
# Epoch 105/120
# 23/23 [==============================] - 0s 15ms/step - loss: 1.9088
# Epoch 106/120
# 23/23 [==============================] - 0s 15ms/step - loss: 1.9622
# Epoch 107/120
# 23/23 [==============================] - 0s 15ms/step - loss: 3.8932
# Epoch 108/120
# 23/23 [==============================] - 0s 15ms/step - loss: 1.6866
# Epoch 109/120
# 23/23 [==============================] - 0s 15ms/step - loss: 1.9412
# Epoch 110/120
# 23/23 [==============================] - 0s 14ms/step - loss: 1.7824
# Epoch 111/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.3286
# Epoch 112/120
# 23/23 [==============================] - 0s 15ms/step - loss: 1.8147
# Epoch 113/120
# 23/23 [==============================] - 0s 16ms/step - loss: 1.7235
# Epoch 114/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.2361
# Epoch 115/120
# 23/23 [==============================] - 0s 16ms/step - loss: 1.7183
# Epoch 116/120
# 23/23 [==============================] - 0s 15ms/step - loss: 1.8050
# Epoch 117/120
# 23/23 [==============================] - 0s 15ms/step - loss: 2.6213
# Epoch 118/120
# 23/23 [==============================] - 0s 15ms/step - loss: 1.5211
# Epoch 119/120
# 23/23 [==============================] - 0s 15ms/step - loss: 5.7221
# Epoch 120/120
# 23/23 [==============================] - 0s 15ms/step - loss: 1.9303
# Time Consumption: 48.20237731933594
# <Mpf_Figure size 1000x700 with 2 Axes>
