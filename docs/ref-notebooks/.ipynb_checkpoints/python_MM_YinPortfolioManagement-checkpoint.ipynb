# %% [markdown]
# # Yin's Capital Product
#
# This notebook walks readers through the procedure of installing *YinPortfolioManagement*. Here we introduce the following usages.
#
# - Installation
# - Use RNN3 Regressor
#
# All rights reserved to Yiqiao Yin.

# %% [markdown]
# ## Installation

# %%
# !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git

# %% [markdown]
# ## Usage of RNN3 Regressor
#
# What is LSTM or RNN?
#
# ## Recurrent Neural Network (a sequential model)
#
# Given data $X$ and $Y$, we want to feed information forward into a time stamp. Then we form some belief and we make some initial predictions. We investigate our beliefs by looking at the loss function of the initial guesses and the real value. We update our model according to error we observed.
#
# ## Architecture: Feed-forward
#
# Consider data with time stamp
# $$X_{\langle 1 \rangle} \rightarrow X_{\langle 2 \rangle} \rightarrow \dots \rightarrow X_{\langle T \rangle}$$
# and feed-forward architecture pass information through exactly as the following:
# $$
# \text{Information in:} \rightarrow
# \begin{matrix}
# Y_{\langle 1 \rangle}, \hat{Y}_{\langle 1 \rangle} & Y_{\langle 2 \rangle}, \hat{Y}_{\langle 2 \rangle} &       & Y_{\langle T \rangle}, \hat{Y}_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# X_{\langle 1 \rangle} \rightarrow    & X_{\langle 2 \rangle} \rightarrow    & \dots \rightarrow & X_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# w_{\langle 1 \rangle}, b_{0, \langle 1 \rangle}    & w_{\langle 2 \rangle}, b_{0, \langle 2 \rangle}    &       & w_{\langle T \rangle}, b_{0, \langle T \rangle} \\
# \end{matrix}
# \rightarrow
# \text{Form beliefs about } Y_{\angle T \rangle}
# $$
# while the educated guesses $\hat{Y}_{\langle T \rangle}$ are our beliefs about real $Y$ at time stamp $T$.
#
# ## Architecture: Feed-backward
#
# Let us clearly define our loss function to make sure we have a proper grip of our mistakes.
# $$\mathcal{L} = \sum_t L(\hat{y}_{\langle t \rangle} - y_t)^2$$
# and we can compute the gradient
# $$\triangledown = \frac{\partial \mathcal{L}}{\partial a}$$
# and then with respect with parameters $w$ and $b$
# $$\frac{\partial \triangledown}{\partial w}, \frac{\partial \triangledown}{\partial a}$$
# and now with perspective of where we make our mistakes according to our parameters we can go backward
# $$
# \text{Information in:} \leftarrow
# \underbrace{
# \begin{matrix}
# Y_{\langle 1 \rangle}, \hat{Y}_{\langle 1 \rangle} & Y_{\langle 2 \rangle}, \hat{Y}_{\langle 2 \rangle} &       & Y_{\langle T \rangle}, \hat{Y}_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# X_{\langle 1 \rangle} \leftarrow    & X_{\langle 2 \rangle} \leftarrow    & \dots \leftarrow & X_{\langle T \rangle} \\
# \uparrow               & \uparrow               &       & \uparrow \\
# w'_{\langle 1 \rangle}, b'_{0, \langle 1 \rangle}    & w'_{\langle 2 \rangle}, b'_{0, \langle 2 \rangle}    &       & w'_{\langle T \rangle}, b'_{0, \langle T \rangle} \\
# \end{matrix}}_{\text{Update: } w, b \text{ with } w', b'}
# \leftarrow
# \text{Total Loss: } \mathcal{L} (\hat{y}, y)
# $$
# and the *update* action in the above architecture is dependent on your optimizer specified in the algorithm.

# %%
from YinCapital_forecast.modules import RNN_Regressor

# %%
tmp = RNN_Regressor(
    start_date =   '2013-01-01',
    end_date   =   '2021-07-14',
    tickers    =   'AAPL',
    numberOfPastDays = 50,
    cutoff     =   0.9,
    numOfHiddenLayer = 2,
    l1_units   =   50,
    l2_units   =   50,
    l3_units   =   50,
    dropOutRate = 0.3,
    optimizer  =   'adam',
    loss       =   'mean_squared_error',
    epochs     =   15,
    batch_size =   64,
    plotGraph  =   True,
    verbose    =   True )
# Out:
# ------------------------------------------------------------------------------
#
#             MANUAL: To install this python package, please use the following code.
#
#             # In a python notebook:
#             # !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#             # In a command line:
#             # pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#
#             # Run
#             tmp = RNN_Regressor(
#                 start_date       =   '2013-01-01',
#                 end_date         =   '2019-12-6',
#                 tickers          =   'AAPL',
#                 numberOfPastDays = 100,
#                 cutoff           =   0.8,
#                 numOfHiddenLayer = 3,
#                 l1_units         =   50,
#                 l2_units         =   50,
#                 l3_units         =   50,
#                 l4_units         =   30,
#                 l5_units         =   10,
#                 dropOutRate       =  0.2,
#                 optimizer        =   'adam',
#                 loss             =   'mean_squared_error',
#                 epochs           =   50,
#                 batch_size       =   64,
#                 plotGraph        =   True,
#                 verbose          =   True )
#
#             # Cite
#             # All Rights Reserved. © Yiqiao Yin
#
# ------------------------------------------------------------------------------
# [*********************100%***********************]  1 of 1 completed
# --------------------------------------------------------------------
# Shape for data frame in training set:
# Shape of X: (1882, 50, 1) ; Shape of Y: 1882
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Shape for data frame in testing set:
# Shape of X: (164, 50, 1) : Shape of Y: 164
# --------------------------------------------------------------------
# --------------------------------------------
# Let us investigate the sequential models.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 50, 50)            10400
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 50, 50)            0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------
# Time Consumption (in sec): 0.39394688606262207
# Time Consumption (in min): 0.01
# Time Consumption (in hr): 0.0 2
# --------------------------------------------
# Epoch 1/15
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0071
# Epoch 2/15
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0012
# Epoch 3/15
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0011: 0s - loss: 0.001
# Epoch 4/15
# 30/30 [==============================] - 1s 20ms/step - loss: 9.7991e-04
# Epoch 5/15
# 30/30 [==============================] - 1s 19ms/step - loss: 9.5275e-04
# Epoch 6/15
# 30/30 [==============================] - 1s 19ms/step - loss: 9.9615e-04
# Epoch 7/15
# 30/30 [==============================] - 1s 19ms/step - loss: 9.4634e-04
# Epoch 8/15
# 30/30 [==============================] - 1s 19ms/step - loss: 8.8987e-04
# Epoch 9/15
# 30/30 [==============================] - 1s 19ms/step - loss: 8.4083e-04
# Epoch 10/15
# 30/30 [==============================] - 1s 19ms/step - loss: 8.7050e-04
# Epoch 11/15
# 30/30 [==============================] - 1s 19ms/step - loss: 7.1616e-04
# Epoch 12/15
# 30/30 [==============================] - 1s 19ms/step - loss: 6.8280e-04
# Epoch 13/15
# 30/30 [==============================] - 1s 20ms/step - loss: 8.3066e-04
# Epoch 14/15
# 30/30 [==============================] - 1s 20ms/step - loss: 7.3381e-04
# Epoch 15/15
# 30/30 [==============================] - 1s 20ms/step - loss: 5.5673e-04
# Time Consumption: 11.82218885421753
# ---------------------------------------------------------------------------------
# Root Mean Square Error is 5.17 for test set.
# ------------------
# Interpretation:
# ------------------
# On the test set, the performance of this LSTM architecture guesses
# AAPL stock price on average within the error of $5.17 dollars.
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## A Deeper RNN: RNN5
#
# A curious question is the the following: does test set performance get better when we increase the number of hidden layers in a RNN architecture?

# %%
tmp = RNN_Regressor(
    start_date =   '2013-01-01',
    end_date   =   '2021-07-14',
    tickers    =   'AAPL',
    numberOfPastDays = 120,
    cutoff     =   0.9,
    numOfHiddenLayer = 5,
    l1_units   =   50,
    l2_units   =   50,
    l3_units   =   50,
    dropOutRate = 0.3,
    optimizer  =   'adam',
    loss       =   'mean_squared_error',
    epochs     =   15,
    batch_size =   64,
    plotGraph  =   True,
    verbose    =   True )
# Out:
# ------------------------------------------------------------------------------
#
#             MANUAL: To install this python package, please use the following code.
#
#             # In a python notebook:
#             # !pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#             # In a command line:
#             # pip install git+https://github.com/yiqiao-yin/YinPortfolioManagement.git
#
#             # Run
#             tmp = RNN_Regressor(
#                 start_date       =   '2013-01-01',
#                 end_date         =   '2019-12-6',
#                 tickers          =   'AAPL',
#                 numberOfPastDays = 100,
#                 cutoff           =   0.8,
#                 numOfHiddenLayer = 3,
#                 l1_units         =   50,
#                 l2_units         =   50,
#                 l3_units         =   50,
#                 l4_units         =   30,
#                 l5_units         =   10,
#                 dropOutRate       =  0.2,
#                 optimizer        =   'adam',
#                 loss             =   'mean_squared_error',
#                 epochs           =   50,
#                 batch_size       =   64,
#                 plotGraph        =   True,
#                 verbose          =   True )
#
#             # Cite
#             # All Rights Reserved. © Yiqiao Yin
#
# ------------------------------------------------------------------------------
# [*********************100%***********************]  1 of 1 completed
# --------------------------------------------------------------------
# Shape for data frame in training set:
# Shape of X: (1812, 120, 1) ; Shape of Y: 1812
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Shape for data frame in testing set:
# Shape of X: (94, 120, 1) : Shape of Y: 94
# --------------------------------------------------------------------
# --------------------------------------------
# Let us investigate the sequential models.
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_19 (LSTM)               (None, 120, 50)           10400
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 120, 50)           0
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 120, 50)           20200
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 120, 50)           0
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 120, 50)           20200
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 120, 50)           0
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 120, 30)           9720
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 120, 30)           0
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 10)                1640
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 62,171
# Trainable params: 62,171
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------
# Time Consumption (in sec): 0.9733138084411621
# Time Consumption (in min): 0.02
# Time Consumption (in hr): 0.0 2
# --------------------------------------------
# Epoch 1/15
# 29/29 [==============================] - 3s 116ms/step - loss: 0.0115
# Epoch 2/15
# 29/29 [==============================] - 3s 110ms/step - loss: 0.0041
# Epoch 3/15
# 29/29 [==============================] - 3s 110ms/step - loss: 0.0035
# Epoch 4/15
# 29/29 [==============================] - 3s 110ms/step - loss: 0.0030
# Epoch 5/15
# 29/29 [==============================] - 3s 111ms/step - loss: 0.0032
# Epoch 6/15
# 29/29 [==============================] - 3s 111ms/step - loss: 0.0028
# Epoch 7/15
# 29/29 [==============================] - 3s 111ms/step - loss: 0.0026
# Epoch 8/15
# 29/29 [==============================] - 3s 110ms/step - loss: 0.0026
# Epoch 9/15
# 29/29 [==============================] - 3s 110ms/step - loss: 0.0025
# Epoch 10/15
# 29/29 [==============================] - 3s 115ms/step - loss: 0.0023
# Epoch 11/15
# 29/29 [==============================] - 3s 116ms/step - loss: 0.0023
# Epoch 12/15
# 29/29 [==============================] - 3s 114ms/step - loss: 0.0021
# Epoch 13/15
# 29/29 [==============================] - 3s 116ms/step - loss: 0.0023
# Epoch 14/15
# 29/29 [==============================] - 3s 116ms/step - loss: 0.0020
# Epoch 15/15
# 29/29 [==============================] - 3s 119ms/step - loss: 0.0018
# Time Consumption: 56.92929816246033
# ---------------------------------------------------------------------------------
# Root Mean Square Error is 6.98 for test set.
# ------------------
# Interpretation:
# ------------------
# On the test set, the performance of this LSTM architecture guesses
# AAPL stock price on average within the error of $6.98 dollars.
# ---------------------------------------------------------------------------------

# %% [markdown]
# Ends here.
